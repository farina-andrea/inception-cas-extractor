# %% [markdown]
# # Retrieve annotations

# %% [markdown]
# ### XML Parsing Function
# This function takes an XML file as input and parses it using the `lxml` library. It returns the parsed XML object for further processing.

# %%
from lxml import etree as ET

import os
import sys
path=os.getcwd()

def get_xml(xml_input):
    parser = ET.XMLParser(remove_comments=False)
    xml = ET.parse(xml_input, parser=parser)
    return xml

# %% [markdown]
# ### Load and Process XMI Files
# This section of the notebook loads XMI files and processes the annotations contained within them. Specifically, it extracts and stores token annotations, which will be mapped to unique identifiers for further analysis.

# %%
import csv  
from cassis import *  

# Function to load a Common Analysis Structure (CAS) from an XMI file
def load_cas(file_input):
    """
    This function loads a Common Analysis Structure (CAS) from an XMI file.
    
    Arguments:
    file_input : str : Path to the XMI file to be loaded
    
    Returns:
    cassis.cas.Cas : Loaded CAS object
    """
    # Open typesystem.xml to load the type system
    f = open('typesystem.xml', 'rb')  
    typesystem = load_typesystem(f)  # Load the type system from the XML file
    
    # Open the XMI file to load the CAS
    fxmi = open(file_input, 'rb')  
    cas = load_cas_from_xmi(fxmi, typesystem=typesystem)  # Load the CAS from the XMI file
    return cas  # Return the loaded CAS

# List of all input XMI files
all_files = ['Caesar, De bello Gallico 1-4.xmi', 'Virgil, Aeneid.xmi']

# Abbreviated names for the input files
files_abbreviated = ['Caes', 'Virg']

id2tok = dict()  # Dictionary to store IDs mapped to tokens
count = 0  # Initialize count variable for tracking iterations

for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    print(file_input)  # Printing the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    # Looping through each 'Actionality' annotation in the CAS
    for relation in cas.select('webanno.custom.Actionality'):
        # Looping through each token covered by the 'Actionality' annotation
        for token in cas.select_covered('webanno.custom.Actionality', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            
            # Option to limit output: print every 100th token
            # To print all tokens, comment out the line below and uncomment the one after
            if count % 100 == 0:  # Print every 100th token (can be removed if you want all tokens)
                print(f"ID: {id}, Token: {tok}")  # Print the token ID and its text
            
            count = count + 1  # Incrementing the count
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            id2tok[id] = tok  # Storing the token text in the dictionary with the token ID as the key

            #Uncomment the following line to print all tokens if needed (instead of limiting to 100th token)
            #print(f"ID: {id}, Token: {tok}")  # Print every token (this line will show all tokens)
# Out:
# Caesar, De bello Gallico 1-4.xmi
# ID: 1498, Token: exirent
# ID: 78841, Token: circumventas
# Virgil, Aeneid.xmi
# ID: 28254, Token: succurrere
# ID: 171793, Token: inibo
# ID: 331311, Token: egressisque
# ID: 436869, Token: succurrere

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Creating a DataFrame from the items in id2tok dictionary

# %%
tokenid_df = pd.DataFrame([(k, v) for k, v in id2tok.items()], columns=["ID", "VERB TOKEN"]) #where 'tokenid_df includes the token id and the token'

tokenid_df
# Out:
#              ID   VERB TOKEN
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
# [504 rows x 2 columns]

# %% [markdown]
# ## Morphological features

# %% [markdown]
# #### Morphological Features Extraction and Storage

# %%
list_morphological_features = []  # Initializing an empty list to store morphological features
pred2_morphological_features = dict()  # Initializing an empty dictionary to store predicted morphological features mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'MorphologicalFeatures' annotation in the CAS
    for relation in cas.select('de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.morph.MorphologicalFeatures'):
        # Looping through each token covered by the 'MorphologicalFeatures' annotation
        for token in cas.select_covered('de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.morph.MorphologicalFeatures', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            morphological_feature = relation.value  # Getting the morphological feature value
            
            # Checking if the ID already exists in pred2mf dictionary
            if id in pred2_morphological_features:
                # If ID exists, append the new morphological feature to the existing list of features
                list_morphological_features = pred2_morphological_features[id] + morphological_feature
                pred2_morphological_features[id] = list_morphological_features
            else:
                # If ID doesn't exist, store the morphological feature directly
                pred2_morphological_features[id] = morphological_feature

print(pred2_morphological_features)
# Out:
# {'1498Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin|Voice=Act', '4296Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act', '4578Caes': 'Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|VerbFor=Gdv|Voice=Act', '4854Caes': 'Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '4978Caes': 'Tense=Pres|VerbForm=Inf|Voice=Act', '5366Caes': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Pass', '5732Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act', '5997Caes': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act', '6831Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin|Voice=Act', '7012Caes': 'Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '7293Caes': 'Tense=Pres|VerbForm=Inf|Voice=Act', '8498Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act', '9426Caes': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act', '9649Caes': 'Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '10407Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin|Voice=Act', '10617Caes': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act', '10862Caes': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act', '10890Caes': 'Mood=Ind|Number=Sing|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '10931Caes': 'Case=Nom|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass', '11152Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '11818Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin|Voice=Act', '12323Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '21567Caes': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act', '24504Caes': 'Case=Nom|Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass', '24513Caes': 'Tense=Pres|VerbForm=Inf|Voice=Act', '25610Caes': 'Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act', '26036Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '26225Caes': 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act', '26268Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '26640Caes': 'Case=Nom|Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass', '27386Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin|Voice=Act', '27831Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '28359Caes': 'Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act', '29918Caes': 'Tense=Past|VerbForm=Inf|Voice=Act', '30767Caes': 'Tense=Past|VerbForm=Inf|Voice=Act', '31365Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin|Voice=Act', '33967Caes': 'Tense=Pres|VerbForm=Inf|Voice=Act', '34210Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin|Voice=Act', '34348Caes': 'Case=Nom|Gender=Neut|Number=Sing|Tense=Pres|VerbFor=Gdv|Voice=Pass', '36546Caes': 'Case=Nom|Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass', '36804Caes': 'Mood=Subj|Number=Sing|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '37047Caes': 'Mood=Subj|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin|Voice=Pass', '37157Caes': 'Mood=Subj|Number=Plur|Person=3|Tense=Pqp|VerbForm=Fin|Voice=Act', '37517Caes': 'Tense=Pres|VerbForm=Inf|Voice=Act', '38986Caes': 'Case=Acc|Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass', '41443Caes': 'Case=Nom|Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass', '46744Caes': 'Tense=Pres|VerbForm=Inf|Voice=Act', '46852Caes': 'Tense=Past|VerbForm=Inf|Voice=Act', '48088Caes': 'Case=Acc|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass', '50312Caes': 'Case=Acc|Gender=Masc|Number=Plur|Tense=Pres|VerbForm=Part|Voice=Pass', '52574Caes': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act', '53622Caes': 'Case=Nom|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass', '56162Caes': 'Mood=Ind|Number=Plur|Person=3|Tense= ...

# %% [markdown]
# #### Creating DataFrame for Morphological Features

# %%
morphological_features_df = pd.DataFrame([(k,v) for k,v in pred2_morphological_features.items()], columns=["ID", "MORPHOLOGICAL FEATURES"]) #where 'morphological_features_df' is a dataframe containing token IDs and morphological features
morphological_features_df
# Out:
#              ID                             MORPHOLOGICAL FEATURES
# 0      1498Caes  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...
# 1      4296Caes  Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...
# 2      4578Caes  Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...
# 3      4854Caes  Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...
# 4      4978Caes                  Tense=Pres|VerbForm=Inf|Voice=Act
# ..          ...                                                ...
# 499  435595Virg  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...
# 500  436869Virg                  Tense=Pres|VerbForm=Inf|Voice=Act
# 501  438653Virg                  Tense=Pres|VerbForm=Inf|Voice=Act
# 502  440736Virg  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...
# 503  441937Virg  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Token IDs with Morphological Features

# %%
id_morphological_features_df = tokenid_df.merge(morphological_features_df, on='ID', how='left') #where 'id_morphological_features_df' merges 'tokenid_df' and 'morphological_features_df'
id_morphological_features_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act
# ..                                                 ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...
#
# [504 rows x 3 columns]

# %% [markdown]
# ## Lemma

# %% [markdown]
# #### Extracting Lemmas from CAS Annotations

# %%
list_lemmas = []  # Initializing an empty list to store lemmas
pred2_lemmas = dict()  # Initializing an empty dictionary to store predicted lemmas mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Lemma' annotation in the CAS
    for relation in cas.select('de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Lemma'):
        # Looping through each token covered by the 'Lemma' annotation
        for token in cas.select_covered('de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Lemma', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            lemma = relation.value  # Getting the lemma value
            
            # Checking if the ID already exists in pred2_lemmas dictionary
            if id in pred2_lemmas:
                # If ID exists, append the new lemma to the existing list of lemmas
                list_lemmas = pred2_lemmas[id] + lemma
                pred2_lemmas[id] = list_lemmas
            else:
                # If ID doesn't exist, store the lemma directly
                pred2_lemmas[id] = lemma

print(pred2_lemmas)
# Out:
# {'1463Caes': 'de', '1466Caes': 'finis', '1498Caes': 'exeo', '4281Caes': 'ex', '4283Caes': 'finis', '4296Caes': 'exeo', '4560Caes': 'ad', '4569Caes': 'periculum', '4578Caes': 'subeo', '4587Caes': 'sum', '4805Caes': 'qui', '4837Caes': 'in', '4840Caes': 'ager', '4854Caes': 'transeo', '4962Caes': 'iter', '4973Caes': 'domus', '4978Caes': 'exeo', '5323Caes': 'Rhodanus', '5366Caes': 'transeo', '5709Caes': 'ad', '5712Caes': 'ripa', '5732Caes': 'convenio', '5986Caes': 'ad', '5989Caes': 'Genava', '5997Caes': 'pervenio', '6806Caes': 'miles', '6831Caes': 'convenio', '6995Caes': 'qui', '6999Caes': 'ex', '7002Caes': 'provincia', '7012Caes': 'convenio', '7293Caes': 'transeo', '8498Caes': 'transeo', '9371Caes': 'in', '9374Caes': 'finis', '9426Caes': 'pervenio', '9630Caes': 'in', '9643Caes': 'finis', '9649Caes': 'pervenio', '10386Caes': 'in', '10389Caes': 'Santoni', '10398Caes': 'Helvetii', '10407Caes': 'pervenio', '10576Caes': 'is', '10579Caes': 'Helvetii', '10617Caes': 'transeo', '10848Caes': 'ad', '10855Caes': 'pars', '10862Caes': 'pervenio', '10871Caes': 'qui', '10883Caes': 'flumen', '10890Caes': 'transeo', '10902Caes': 'is', '10931Caes': 'adgredior', '11131Caes': 'pagus', '11147Caes': 'domus', '11152Caes': 'exeo', '11811Caes': 'flumen', '11818Caes': 'transeo', '12312Caes': 'qui', '12316Caes': 'flumen', '12323Caes': 'transeo', '21537Caes': 'Considius', '21560Caes': 'ad', '21563Caes': 'is', '21567Caes': 'accurro', '24479Caes': 'noster', '24487Caes': 'ab', '24490Caes': 'latus', '24504Caes': 'adgredior', '24513Caes': 'circumvenio', '25581Caes': 'in', '25584Caes': 'finis', '25610
# 3       4281Caes       ex
# 4       4283Caes    finis
# ...          ...      ...
# 1178  440708Virg     ille
# 1179  440736Virg    subeo
# 1180  441917Virg      per
# 1181  441937Virg  transeo
# 1182  441945Virg    femur
#
# [1183 rows x 2 columns]

# %% [markdown]
# #### Merging Token IDs, Morphological Features, and Lemmas

# %%
id_lemmas_df = id_morphological_features_df.merge(lemmas_df, on='ID', how='left') #where 'id_lemmas_df' merges 'id_morphological_features_df' and 'lemmas_df'
id_lemmas_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
# [504 rows x 4 columns]

# %% [markdown]
# ## Sentence

# %% [markdown]
# #### Extracting Sentences from CAS Annotations

# %%
list_sentences = []  # Initializing an empty list to store sentences
pred2_sentences = dict()  # Initializing an empty dictionary to store predicted sentences mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Includes' relation in the CAS
    for relation in cas.select('webanno.custom.Includes'):
        dep = relation.Dependent  # Getting the dependent token of the relation
        tokdep = dep.get_covered_text()  # Getting the text covered by the dependent token
        id = str(dep.begin) + file_input_abbr  # Creating a unique ID for the dependent token based on its offset and file abbreviation
        list_sentences.append(str(tokdep))  # Appending the text of the dependent token to the list of sentences
        
        gov = relation.Governor  # Getting the governor token of the relation
        sentence = gov.get_covered_text()  # Getting the text covered by the governor token
        
        # Checking if the ID already exists in pred2_sentences dictionary
        if id in pred2_sentences:
            # If ID exists, append the new token text to the existing list of tokens representing the sentence
            list_sentences = pred2_sentences[id] + sentence
            pred2_sentences[id] = list_sentences
        else:
            # If ID doesn't exist, store the token text directly
            pred2_sentences[id] = sentence

print(pred2_sentences)
# Out:
# {'1498Caes': 'Pisone consulibus regni cupiditate inductus coniurationem nobilitatis fecit et civitati persuasit ut de finibus suis cum omnibus copiis exirent', '4296Caes': 'Post eius mortem nihilo minus Helvetii id quod constituerant facere conantur, ut e finibus suis exeant', '4578Caes': 'frumentum omne, praeter quod secum portaturi erant, comburunt, ut domum reditionis spe sublata paratiores ad omnia pericula subeunda essent', '4854Caes': 'Persuadent Rauracis et Tulingis et Latobrigis finitimis, uti eodem usi consilio oppidis suis vicisque exustis una cum iis proficiscantur, Boiosque, qui trans Rhenum incoluerant et in agrum Noricum transierant Noreiamque oppugnabant, receptos ad se socios sibi adsciscunt', '4978Caes': 'Erant omnino itinera duo, quibus itineribus domo exire possent', '5366Caes': 'alterum per provinciam nostram, multo facilius atque expeditius, propterea quod inter fines Helvetiorum et Allobrogum, qui nuper pacati erant, Rhodanus fluit isque non nullis locis vado transitur', '5732Caes': 'Omnibus rebus ad profectionem comparatis diem dicunt, qua die ad ripam Rhodani omnes conveniant', '5997Caes': 'Caesari cum id nuntiatum esset, eos per provinciam nostram iter facere conari, maturat ab urbe proficisci et quam maximis potest itineribus in Galliam ulteriorem contendit et ad Genavam pervenit', '6831Caes': 'Tamen, ut spatium intercedere posset dum milites quos imperaverat convenirent, legatis respondit diem se ad deliberandum sumpturum', '7012Caes': 'Interea ea legione quam secum habebat militibusque, qui ex provincia convenerant, a lacu Lemanno, qui in flumen Rhodanum influit, ad montem Iuram, qui fines Sequanorum ab Helvetiis dividit', '7293Caes': 'Eo opere perfecto praesidia disponit, castella communit, quo facilius, si se invito transire conentur, prohibere possit', '8498Caes': 'Sequani, ne itinere Helvetios prohibeant, Helvetii, ut sine maleficio et iniuria transeant', '9426Caes': 'Compluribus his proeliis pulsis ab Ocelo, quod est oppidum citerioris provinciae extremum, in fines Vocontiorum ulterioris provinciae die septimo pervenit', '9649Caes': 'Helvetii iam per angustias et fines Sequanorum suas copias traduxerant et in Haeduorum fines pervenerant eorumque agros populabantur', '10407Caes': 'Quibus rebus adductus Caesar non expectandum sibi statuit dum, omnibus, fortunis sociorum consumptis, in Santonos Helvetii pervenirent', '10617Caes': 'Id Helvetii ratibus ac lintribus iunctis transibant', '10862Caes': 'Ubi per exploratores Caesar certior factus est tres iam partes copiarum Helvetios id flumen traduxisse, quartam vero partem citra flumen Ararim reliquam esse, de tertia vigilia cum legionibus tribus e castris profectus ad eam partem pervenit quae nondum flumen transierat', '10890Caes': 'Ubi per exploratores Caesar certior factus est tres iam partes copiarum Helvetios id flumen traduxisse, quartam vero partem citra flumen Ararim reliquam esse, de tertia vigilia cum legionibus tribus e castris profectus ad eam partem pervenit quae nondum flumen transierat', '10931Caes': 'Eos impeditos et inopinantes adgressus magnam partem eorum concidit', '11152Caes': 'Hic pagus unus, cum domo exisset', '11818Caes': 'Helvetii repentino eius adventu commoti cum id quod ipsi diebus XX aegerrime confecerant, ut flumen transirent, illum uno die fecisse intellegerent, legatos ad eum mittunt', '12323Caes': 'Quod improviso unum pagum adortus esset, cum ii qui flumen transissent suis auxilium ferre non possent, ne ob eam rem aut suae magnopere virtuti tribueret aut ipsos despiceret', '21567Caes': 'Prima luce, cum summus mons a [Lucio] Labieno teneretur, ipse ab hostium castris non longius mille et quingentis passibus abesset neque, ut postea ex captivis comperit, aut ipsius adventus aut Labieni cognitus esset, Considius equo admisso ad eum accurrit, dicit montem, quem a Labieno occupari voluerit, ab hostibus teneri', '24504Caes': 'Capto monte et succedentibus nostris, Boi et Tulingi, qui hominum milibus circiter XV agmen hostium  ...

# %% [markdown]
# #### Creating DataFrame for Sentences

# %%
sentences_df = pd.DataFrame([(k,v) for k,v in pred2_sentences.items()], columns=["ID", "SENTENCE"]) #where 'sentences_df' is a dataframe containing token IDs and the whole sentences including the verb tokens
sentences_df
# Out:
#              ID                                           SENTENCE
# 0      1498Caes  Pisone consulibus regni cupiditate inductus co...
# 1      4296Caes  Post eius mortem nihilo minus Helvetii id quod...
# 2      4578Caes  frumentum omne, praeter quod secum portaturi e...
# 3      4854Caes  Persuadent Rauracis et Tulingis et Latobrigis ...
# 4      4978Caes  Erant omnino itinera duo, quibus itineribus do...
# ..          ...                                                ...
# 499  435595Virg  Dum nititur acer et instat, rursus in aurigae ...
# 500  436869Virg  Iuturnam misero, fateor, succurrere fratri sua...
# 501  438653Virg  Harum unam celerem demisit ab aethere summo Iu...
# 502  440736Virg  Vix illud lecti bis sex cervice subirent, qual...
# 503  441937Virg                  Per medium stridens transit femur
#
# [504 rows x 2 columns]

# %%
id_sentences_df = id_lemmas_df.merge(sentences_df, on='ID', how='left') #where 'id_sentences_df' merges 'id_lemmas_df' and 'sentences_df'
id_sentences_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE
# 0    Pisone consulibus regni cupiditate inductus co...
# 1    Post eius mortem nihilo minus Helvetii id quod...
# 2    frumentum omne, praeter quod secum portaturi e...
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...
# 4    Erant omnino itinera duo, quibus itineribus do...
# ..                                                 ...
# 499  Dum nititur acer et instat, rursus in aurigae ...
# 500  Iuturnam misero, fateor, succurrere fratri sua...
# 501  Harum unam celerem demisit ab aethere summo Iu...
# 502  Vix illud lecti bis sex cervice subirent, qual...
# 503                  Per medium stridens transit femur
#
# [504 rows x 5 columns]

# %% [markdown]
# #### Merging Token IDs, Lemmas, Morphological Features, and Sentences

# %% [markdown]
# ## Actionality

# %% [markdown]
# #### Extracting Actionality from CAS Annotations

# %%
list_actionality = []  # Initializing an empty list to store actionality values
pred2_actionality = dict()  # Initializing an empty dictionary to store predicted actionality values mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Actionality' annotation in the CAS
    for relation in cas.select('webanno.custom.Actionality'):
        # Looping through each token covered by the 'Actionality' annotation
        for token in cas.select_covered('webanno.custom.Actionality', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            actionality = relation.Actionality  # Getting the actionality value
            
            # Checking if the ID already exists in pred2_actionality dictionary
            if id in pred2_actionality:
                # If ID exists, append the new actionality to the existing list of actionalities
                list_actionality = pred2_actionality[id] + actionality
                pred2_actionality[id] = list_actionality
            else:
                # If ID doesn't exist, store the actionality directly
                pred2_actionality[id] = actionality

print(pred2_actionality)
# Out:
# {'1498Caes': 'Activity', '4296Caes': 'Activity', '4578Caes': 'Achievement', '4854Caes': 'Achievement', '4978Caes': 'Activity', '5366Caes': 'Accomplishment', '5732Caes': 'Accomplishment', '5997Caes': 'Accomplishment', '6831Caes': 'Activity', '7012Caes': 'Accomplishment', '7293Caes': 'Accomplishment', '8498Caes': 'Activity', '9426Caes': 'Accomplishment', '9649Caes': 'Accomplishment', '10407Caes': 'Accomplishment', '10617Caes': 'Activity', '10862Caes': 'Accomplishment', '10890Caes': 'Accomplishment', '10931Caes': 'Accomplishment', '11152Caes': 'Achievement', '11818Caes': 'Accomplishment', '12323Caes': 'Accomplishment', '21567Caes': 'Accomplishment', '24504Caes': 'Accomplishment', '24513Caes': 'Accomplishment', '25610Caes': 'Accomplishment', '26036Caes': 'Achievement', '26225Caes': 'Accomplishment', '26268Caes': 'Accomplishment', '26640Caes': 'Achievement', '27386Caes': 'Accomplishment', '27831Caes': 'Achievement', '28359Caes': 'Accomplishment', '29918Caes': 'Accomplishment', '30767Caes': 'Achievement', '31365Caes': 'Accomplishment', '33967Caes': 'Accomplishment', '34210Caes': 'Activity', '34348Caes': 'Achievement', '36546Caes': 'Activity', '36804Caes': 'State', '37047Caes': 'Activity', '37157Caes': 'Achievement', '37517Caes': 'Accomplishment', '38986Caes': 'Activity', '41443Caes': 'Accomplishment', '46744Caes': 'Accomplishment', '46852Caes': 'Accomplishment', '48088Caes': 'Achievement', '50312Caes': 'Accomplishment', '52574Caes': 'Accomplishment', '53622Caes': 'Accomplishment', '56162Caes': 'Accomplishment', '56208Caes': 'Accompl
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Sentences and Actionality DataFrames

# %%
id_actionality_df = id_sentences_df.merge(actionality_df, on='ID', how='left') #where 'id_actionality_df' merges 'id_sentences_df' and 'actionality_df'
id_actionality_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
# [504 rows x 6 columns]

# %% [markdown]
# ## Verb class

# %% [markdown]
# #### Extracting Verb Class from CAS Annotations

# %%
list_verbclass = []  # Initializing an empty list to store verb classes
pred2_verbclass = dict()  # Initializing an empty dictionary to store predicted verb classes mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Motionclass' annotation in the CAS
    for relation in cas.select('webanno.custom.Motionclass'):
        # Looping through each token covered by the 'Motionclass' annotation
        for token in cas.select_covered('webanno.custom.Motionclass', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            verbclass = relation.Motionclass  # Getting the verb class value
            
            # Checking if the ID already exists in pred2_verbclass dictionary
            if id in pred2_verbclass:
                # If ID exists, append the new verb class to the existing list of verb classes
                list_verbclass = pred2_verbclass[id] + verbclass
                pred2_verbclass[id] = list_verbclass
            else:
                # If ID doesn't exist, store the verb class directly
                pred2_verbclass[id] = verbclass

print(pred2_verbclass)
# Out:
# {'1498Caes': 'ESCAPE-51.1', '4296Caes': 'ESCAPE-51.1', '4578Caes': 'MARVEL-31.3', '4854Caes': 'ESCAPE-51.1', '4978Caes': 'ESCAPE-51.1', '5366Caes': 'ESCAPE-51.1', '5732Caes': 'HERD-47.5.2', '5997Caes': 'ESCAPE-51.1', '6831Caes': 'HERD-47.5.2', '7012Caes': 'HERD-47.5.2', '7293Caes': 'ESCAPE-51.1', '8498Caes': 'ESCAPE-51.1', '9426Caes': 'ESCAPE-51.1', '9649Caes': 'ESCAPE-51.1', '10407Caes': 'ESCAPE-51.1', '10617Caes': 'ESCAPE-51.1', '10862Caes': 'ESCAPE-51.1', '10890Caes': 'ESCAPE-51.1', '10931Caes': 'ATTACK-60.1', '11152Caes': 'REMOVE-10.1', '11818Caes': 'ESCAPE-51.1', '12323Caes': 'ESCAPE-51.1', '21567Caes': 'RUN-51.3.2', '24504Caes': 'ATTACK-60.1', '24513Caes': 'ESCAPE-51.1', '25610Caes': 'ESCAPE-51.1', '26036Caes': 'MEEET-36.3', '26225Caes': 'ESCAPE-51.1', '26268Caes': 'LEAVE-51.2', '26640Caes': 'ESCAPE-51.1', '27386Caes': 'ESCAPE-51.1', '27831Caes': 'ESCAPE-51.1', '28359Caes': 'HERD-47.5.2', '29918Caes': 'ESCAPE-51.1', '30767Caes': 'ESCAPE-51.1', '31365Caes': 'ESCAPE-51.1', '33967Caes': 'ESCAPE-51.1', '34210Caes': 'ESCAPE-51.1', '34348Caes': 'CONFRONT-98', '36546Caes': 'BATTLE-36.4-1', '36804Caes': 'CORRESPOND-36.1', '37047Caes': 'BATTLE-36.4-1', '37157Caes': 'ESCAPE-51.1', '37517Caes': 'ESCAPE-51.1', '38986Caes': 'BATTLE-36.4-1', '41443Caes': 'BATTLE-36.4-1', '46744Caes': 'ESCAPE-51.1', '46852Caes': 'ESCAPE-51.1', '48088Caes': 'LEAVE-51.2', '50312Caes': 'ESCAPE-51.1', '52574Caes': 'HERD-47.5.2', '53622Caes': 'ES
': 'ESCAPE-51.1', '106355Caes': 'LEAVE-51.2', '108403Caes': 'RUN-51.3.2', '110964Caes': 'ESCAPE-51.1', '111487Caes': 'ESCAPE-51.1', '111782Caes': 'ESCAPE-51.1', '111980Caes': 'HERD-47.5.2', '112893Caes': 'ESCAPE-51.1', '113030Caes': 'RUN-51.3.2', '114154Caes': 'ESCAPE-51.1', '114211Caes': 'ESCAPE-51.1', '115967Caes': 'ESCAPE-51.1', '117032Caes': 'ES ...

# %% [markdown]
# #### Creating DataFrame for Verb Class

# %%
verbclass_df = pd.DataFrame([(k,v) for k,v in pred2_verbclass.items()], columns=["ID", "VERB CLASS"]) #where 'verbclass_df' is a dataframe containing token IDs and motion clases of the verb tokens
verbclass_df
# Out:
#              ID         VERB CLASS
# 0      1498Caes        ESCAPE-51.1
# 1      4296Caes        ESCAPE-51.1
# 2      4578Caes        MARVEL-31.3
# 3      4854Caes        ESCAPE-51.1
# 4      4978Caes        ESCAPE-51.1
# ..          ...                ...
# 499  435595Virg         RUN-51.3.2
# 500  436869Virg          HELP-72.1
# 501  438653Virg         RUN-51.3.2
# 502  440736Virg  PUT_DIRECTION-9.4
# 503  441937Virg        ESCAPE-51.1
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Actionality and Verb Class DataFrames

# %%
id_verbclass_df = id_actionality_df.merge(verbclass_df, on='ID', how='left') #where 'id_verbclass_df' merges 'id_actionality_df' and 'verbclass_df'
id_verbclass_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY  \
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
#             VERB CLASS
# 0          ESCAPE-51.1
# 1          ESCAPE-51.1
# 2          MARVEL-31.3
# 3          ESCAPE-51.1
# 4          ESCAPE-51.1
# ..                 ...
# 499         RUN-51.3.2
# 500          HELP-72.1
# 501         RUN-51.3.2
# 502  PUT_DIRECTION-9.4
# 503        ESCAPE-51.1
#
# [504 rows x 7 columns]

# %% [markdown]
# ## Literal meaning

# %% [markdown]
# #### Extracting Literal Meaning Values

# %%
list_literalmeanings = []  # Initializing an empty list to store literal meanings
pred2_literalmeaning = dict()  # Initializing an empty dictionary to store predicted literal meanings mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Literalmeaning' annotation in the CAS
    for relation in cas.select('webanno.custom.Literalmeaning'):
        # Looping through each token covered by the 'Literalmeaning' annotation
        for token in cas.select_covered('webanno.custom.Literalmeaning', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            literalmeaning = relation.Literalmeaning  # Getting the literal meaning value
            
            # Checking if the ID already exists in pred2_literalmeaning dictionary
            if id in pred2_literalmeaning:
                # If ID exists, append the new literal meaning to the existing list of literal meanings
                list_literalmeanings = pred2_literalmeaning[id] + literalmeaning
                pred2_literalmeaning[id] = list_literalmeanings
            else:
                # If ID doesn't exist, store the literal meaning directly
                pred2_literalmeaning[id] = literalmeaning

print(pred2_literalmeaning)
# Out:
# {'1498Caes': True, '4296Caes': True, '4578Caes': False, '4854Caes': True, '4978Caes': True, '5366Caes': True, '5732Caes': True, '5997Caes': True, '6831Caes': True, '7012Caes': True, '7293Caes': True, '8498Caes': True, '9426Caes': True, '9649Caes': True, '10407Caes': True, '10617Caes': True, '10862Caes': True, '10890Caes': True, '10931Caes': False, '11152Caes': False, '11818Caes': True, '12323Caes': True, '21567Caes': True, '24504Caes
# %% [markdown]
# #### Creating DataFrame for Literal Meanings

# %%
literal_meaning_df = pd.DataFrame([(k,v) for k,v in pred2_literalmeaning.items()], columns=["ID", "LITERAL MEANING"])  #where 'literal_meaning_df' is a dataframe containing token IDs and (Boolean) literal meanings of the verb tokens
literal_meaning_df
# Out:
#              ID  LITERAL MEANING
# 0      1498Caes             True
# 1      4296Caes             True
# 2      4578Caes            False
# 3      4854Caes             True
# 4      4978Caes             True
# ..          ...              ...
# 499  435595Virg             True
# 500  436869Virg            False
# 501  438653Virg            False
# 502  440736Virg            False
# 503  441937Virg             True
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Verb Class and Literal Meaning DataFrames

# %%
id_literal_meaning_df = id_verbclass_df.merge(literal_meaning_df, on='ID', how='left') #where 'id_literal_meaning_df' merges 'id_verbclass_df' and 'literal_meaning_df'
id_literal_meaning_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY  \
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
#             VERB CLASS  LITERAL MEANING
# 0          ESCAPE-51.1             True
# 1          ESCAPE-51.1             True
# 2          MARVEL-31.3            False
# 3          ESCAPE-51.1             True
# 4          ESCAPE-51.1             True
# ..                 ...              ...
# 499         RUN-51.3.2             True
# 500          HELP-72.1            False
# 501         RUN-51.3.2            False
# 502  PUT_DIRECTION-9.4            False
# 503        ESCAPE-51.1             True
#
# [504 rows x 8 columns]

# %% [markdown]
# ## Verb stem

# %% [markdown]
# #### Extracting Verb Stem Values

# %%
list_verbstem = []  # Initializing an empty list to store verb stems
pred2_verbstem = dict()  # Initializing an empty dictionary to store predicted verb stems mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Verbstem' annotation in the CAS
    for relation in cas.select('webanno.custom.Verbstem'):
        # Looping through each token covered by the 'Verbstem' annotation
        for token in cas.select_covered('webanno.custom.Verbstem', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            verbstem = relation.Verbstem  # Getting the verb stem value
            
            # Checking if the ID already exists in pred2_verbstem dictionary
            if id in pred2_verbstem:
                # If ID exists, append the new verb stem to the existing list of verb stems
                list_verbstem = pred2_verbstem[id] + verbstem
                pred2_verbstem[id] = list_verbstem
            else:
                # If ID doesn't exist, store the verb stem directly
                pred2_verbstem[id] = verbstem

print(pred2_verbstem)
# Out:
# {'1498Caes': 'present stem', '4296Caes': 'present stem', '4578Caes': 'present stem', '4854Caes': 'perfect stem', '4978Caes': 'present stem', '5366Caes': 'present stem', '5732Caes': 'present stem', '5997Caes': 'present stem', '6831Caes': 'present stem', '7012Caes': 'perfect stem', '7293Caes': 'present stem', '8498Caes': 'present stem', '9426Caes': 'present stem', '9649Caes': 'perfect stem', '10407Caes': 'present stem', '10617Caes': 'present stem', '10862Caes': 'perfect stem', '10890Caes': 'perfect stem', '10931Caes': 'supine stem', '11152Caes': 'perfect stem', '11818Caes': 'present stem', '12323Caes': 'perfect stem', '21567Caes': 'present stem', '24504Caes': 'supine stem', '24513Caes': 'present stem', '25610Caes': 'perfect stem', '26036Caes': 'perfect stem', '26225Caes': 'perfect stem', '26268Caes': 'perfect stem', '26640Caes': 'supine stem',
# %%
verbstem_df = pd.DataFrame([(k,v) for k,v in pred2_verbstem.items()], columns=["ID", "VERB STEM"]) #where 'verbstem_df' is a dataframe containing token IDs and verb stems of the verb tokens
verbstem_df
# Out:
#              ID     VERB STEM
# 0      1498Caes  present stem
# 1      4296Caes  present stem
# 2      4578Caes  present stem
# 3      4854Caes  perfect stem
# 4      4978Caes  present stem
# ..          ...           ...
# 499  435595Virg  present stem
# 500  436869Virg  present stem
# 501  438653Virg  present stem
# 502  440736Virg  present stem
# 503  441937Virg  present stem
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Literal Meaning and Verb Stem DataFrames

# %%
id_verbstem_df = id_literal_meaning_df.merge(verbstem_df, on='ID', how='left') #where 'id_verbstem_df' merges 'id_literal_meaning_df' and 'verbstem_df'
id_verbstem_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY  \
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
#             VERB CLASS  LITERAL MEANING     VERB STEM
# 0          ESCAPE-51.1             True  present stem
# 1          ESCAPE-51.1             True  present stem
# 2          MARVEL-31.3            False  present stem
# 3          ESCAPE-51.1             True  perfect stem
# 4          ESCAPE-51.1             True  present stem
# ..                 ...              ...           ...
# 499         RUN-51.3.2             True  present stem
# 500          HELP-72.1            False  present stem
# 501         RUN-51.3.2            False  present stem
# 502  PUT_DIRECTION-9.4            False  present stem
# 503        ESCAPE-51.1             True  present stem
#
# [504 rows x 9 columns]

# %% [markdown]
# ## Preverb

# %% [markdown]
# #### Extracting Preverb Values

# %%
list_preverbs = []  # Initializing an empty list to store preverbs
pred2_preverbs = dict()  # Initializing an empty dictionary to store predicted preverbs mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Preverb' annotation in the CAS
    for relation in cas.select('webanno.custom.Preverb'):
        # Looping through each token covered by the 'Preverb' annotation
        for token in cas.select_covered('webanno.custom.Preverb', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            preverb = relation.Prev  # Getting the preverb value
            
            # Checking if the ID already exists in pred2_preverbs dictionary
            if id in pred2_preverbs:
                # If ID exists, append the new preverb to the existing list of preverbs
                list_preverbs = pred2_preverbs[id] + preverb
                pred2_preverbs[id] = list_preverbs
            else:
                # If ID doesn't exist, store the preverb directly
                pred2_preverbs[id] = preverb

print(pred2_preverbs)
# Out:
# {'1498Caes': 'ex', '4296Caes': 'ex', '4578Caes': 'sub', '4854Caes': 'trans', '4978Caes': 'ex', '5366Caes': 'trans', '5732Caes': 'cum', '5997Caes': 'per', '6831Caes': 'cum', '7012Caes': 'cum', '7293Caes': 'trans', '8498Caes': 'trans', '9426Caes': 'per', '9649Caes': 'per', '10407Caes': 'per', '10617Caes': 'trans', '10862Caes': 'per', '10890Caes': 'trans', '10931Caes': 'ad', '11152Caes': 'ex', '11818Caes': 'trans', '12323Caes': 'trans', '21567Caes': 'ad', '24504Caes': 'ad', '24513Caes': 'circum', '25610Caes': 'per', '26036Caes': 'cum', '26225Caes': 'per', '26268Caes': 'per', '26640Caes': 'ex', '27386Caes': 'trans', '27831Caes': 'ex', '28359Caes': 'cum', '29918Caes': 'trans', '30767Caes': 'pro', '31365Caes': 'trans', '33967Caes': 'trans', '34210Caes': 'ex', '34348Caes': 'ob', '36546Caes': 'cum', '36804Caes': 'cum', '37047Caes': 'cum', '37157Caes': 'sub', '
135874Caes': 'pro', '136747Caes': 'ex', '137342Caes': 'ob', '137469Caes': 'ex', '138342Caes': 'ex', '138943Caes': 'cum', '140508Caes': 'cum', '140959Caes': 'trans', '142066Caes': 'in', '143342Caes': 'per', '144404Caes': 'ex', '145197Caes': 'per', '145680Caes': 'cum', '432Virg': 'ad', '7706Virg': 'sub', '7737Virg': 'ex', '8862Virg': 'ab', '11990Virg': 'trans', '13785Virg': 'ex', '16238Virg': 'cum', '17473Virg': 'ad',  ...

# %% [markdown]
# #### Creating DataFrame for Preverb

# %%
preverbs_df = pd.DataFrame([(k,v) for k,v in pred2_preverbs.items()], columns=["ID", "PREVERB"]) #where 'preverbs_df' is a dataframe containing token IDs and preverbs of the verb tokens
preverbs_df
# Out:
#              ID PREVERB
# 0      1498Caes      ex
# 1      4296Caes      ex
# 2      4578Caes     sub
# 3      4854Caes   trans
# 4      4978Caes      ex
# ..          ...     ...
# 499  435595Virg     pro
# 500  436869Virg     sub
# 501  438653Virg      ob
# 502  440736Virg     sub
# 503  441937Virg   trans
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Verb Stem and Preverb DataFrames

# %%
id_preverbs_df = id_verbstem_df.merge(preverbs_df, on='ID', how='left') #where 'id_preverbs_df' merges 'id_verbstem_df' and 'preverbs_df'
id_preverbs_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY  \
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
#             VERB CLASS  LITERAL MEANING     VERB STEM PREVERB
# 0          ESCAPE-51.1             True  present stem      ex
# 1          ESCAPE-51.1             True  present stem      ex
# 2          MARVEL-31.3            False  present stem     sub
# 3          ESCAPE-51.1             True  perfect stem   trans
# 4          ESCAPE-51.1             True  present stem      ex
# ..                 ...              ...           ...     ...
# 499         RUN-51.3.2             True  present stem     pro
# 500          HELP-72.1            False  present stem     sub
# 501         RUN-51.3.2            False  present stem      ob
# 502  PUT_DIRECTION-9.4            False  present stem     sub
# 503        ESCAPE-51.1             True  present stem   trans
#
# [504 rows x 10 columns]

# %% [markdown]
# ## Preverb semantics

# %% [markdown]
# #### Extracting Preverb Semantics values

# %%
list_preverb_semantics = []  # Initializing an empty list to store preverb semantics
pred2_preverb_semantics = dict()  # Initializing an empty dictionary to store predicted preverb semantics mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'SemPrev' annotation in the CAS
    for relation in cas.select('webanno.custom.SemPrev'):
        # Looping through each token covered by the 'SemPrev' annotation
        for token in cas.select_covered('webanno.custom.SemPrev', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            preverb_semantics = relation.Preverbsemantics  # Getting the preverb semantics value
            
            # Checking if the ID already exists in pred2_preverb_semantics dictionary
            if id in pred2_preverb_semantics:
                # If ID exists, append the new preverb semantics to the existing list of preverb semantics
                list_preverb_semantics = pred2_preverb_semantics[id] + preverb_semantics 
                pred2_preverb_semantics[id] = list_preverb_semantics
            else:
                # If ID doesn't exist, store the preverb semantics directly
                pred2_preverb_semantics[id] = preverb_semantics

print(pred2_preverb_semantics)
# Out:
# {'1498Caes': uima_cas_StringArray(xmiID=None, elements=['out'], type=Type(name=uima.cas.StringArray)), '4296Caes': uima_cas_StringArray(xmiID=None, elements=['out'], type=Type(name=uima.cas.StringArray)), '4578Caes': uima_cas_StringArray(xmiID=None, elements=['under'], type=Type(name=uima.cas.StringArray)), '4854Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '4978Caes': uima_cas_StringArray(xmiID=None, elements=['out'], type=Type(name=uima.cas.StringArray)), '5366Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '5732Caes': uima_cas_StringArray(xmiID=None, elements=['together'], type=Type(name=uima.cas.StringArray)), '5997Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '6831Caes': uima_cas_StringArray(xmiID=None, elements=['together'], type=Type(name=uima.cas.StringArray)), '7012Caes': uima_cas_StringArray(xmiID=None, elements=['together'], type=Type(name=uima.cas.StringArray)), '7293Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '8498Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '9426Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '9649Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '10407Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '10617Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '10862Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '10890Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '10931Caes': uima_cas_StringArray(xmiID=None, elements=['(malefactive)', 'to'], type=Type(name=uima.cas.StringArray)), '11152Caes': uima_cas_StringArray(xmiID=None, elements=['out'], type=Type(name=uima.cas.StringArray)), '11818Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '12323Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '21567Caes': uima_cas_StringArray(xmiID=None, elements=['to'], type=Type(name=uima.cas.StringArray)), '24504Caes': uima_cas_StringArray(xmiID=None, elements=['(malefactive)', 'to'], type=Type(name=uima.cas.StringArray)), '24513Caes': uima_cas_StringArray(xmiID=None, elements=['around'], type=Type(name=uima.cas.StringArray)), '25610Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '26036Caes': uima_cas_StringArray(xmiID=None, elements=['together with'], type=Type(name=uima.cas.StringArray)), '26225Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '26268Caes': uima_cas_StringArray(xmiID=None, elements=['completely'], type=Type(name=uima.cas.StringArray)), '26640Caes': uima_cas_StringArray(xmiID=None, elements=['away'], type=Type(name=uima.cas.StringArray)), '27386Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '27831Caes': uima_cas_StringArray(xmiID=None, elements=['out'], type=Type(name=uima.cas.StringArray)), '28359Caes': uima_cas_StringArray(xmiID=None, elements=['together'], type=Type(name=uima.cas.StringArray)), '29918Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '30767Caes': uima_cas_StringArray(xmiID=None, elements=['forth'], type=Type(name=uima.cas.StringArray)), '31365Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '33967Caes': uima_cas_StringArray(xmiID=None, elements=['across'], type=Type(name=uima.cas.StringArray)), '34210Caes': uima_cas_StringArray(xmiID=N ...

# %% [markdown]
# #### Extracting Preverb Semantics Values Removing Unwanted Characters

# %%
list_preverb_semantics = []  # Initializing an empty list to store preverb semantics

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'SemPrev' annotation in the CAS
    for relation in cas.select('webanno.custom.SemPrev'):
        preverb_semantics = relation.Preverbsemantics  # Getting the preverb semantics value
        # Append the preverb semantics to the list after removing unwanted characters
        preverb_semantics_str = ', '.join(preverb_semantics.elements)  # Joining the elements of StringArray
        list_preverb_semantics.append(preverb_semantics_str)  # Appending the preverb semantics to the list

print(list_preverb_semantics)
# Out:
# ['out', 'out', 'under', 'across', 'out', 'across', 'together', 'completely', 'together', 'together', 'across', 'across', 'completely', 'completely', 'completely', 'across', 'completely', 'across', '(malefactive), to', 'out', 'across', 'across', 'to', '(malefactive), to', 'around', 'completely', 'together with', 'completely', 'completely', 'away', 'across', 'out', 'together', 'across', 'forth', 'across', 'across', 'away', 'against', '(malefactive), together', 'together', '(malefactive), together', 'under', 'across', '(malefactive), together', '(malefactive), together', 'across', 'across', 'away', 'around', 'together', 'onwards', 'completely', 'across', 'into', 'forward', '(idea of destruction/death), across', 'into', 'completely', 'into', 'together', 'to', 'around', 'across', 'across', '(malefactive), to', 'across', '(malefactive), to', 'across', 'across', 'around', 'across', 'onwards', 'together', 'away', 'completely', 'together', 'away', 'forth', 'completely', 'into', 'completely', 'across', 'together', 'forth', 'downwards', 'together', 'downwards', 'completely', 'against', 'completely', 'into', 'across', 'across', 'onwards', 'together', 'around', '(malefactive), to', 'across', 'away', 'around', 'under', '(malefactive), to', 'across', 'towards', 'out', 'into', 'together', 'into', 'across', 'downwards', 'completely', 'downwards', 'against', 'to', 'around', 'against', 'into', 'to', 'into', 'to', 'across', 'together', 'together', 'together', 'together', 'completely', 'together', 'across', 'completely', 'completely', 'forth', 'together', 'around', 'completely', 'around', 'together', 'completely', 'out', 'across', 'across', 'towards', 'completely', 'across', 'across', 'onwards', 'across', 'into', 'against', 'together', 'onwards', 'together', 'around', 'completely', 'across', 'completely', '(idea of destruction/death), across', 'across', 'across', 'across', 'across', 'across', 'across', 'together', 'to', 'to', 'together', 'to', 'out', 'onwards', 'out', 'together', 'onwards', 'out', 'onwards', 'away', 'against', 'out', 'out', 'together', 'together', 'across', 'into', 'along', 'away', 'completely', 'together', 'to', 'to, under', 'out', 'away', 'through', 'out', 'together', 'to', 'to, under', 'away', '(malefactive), together', '(malefactive), together with', 'into', 'under', 'completely', 'against', 'together', 'away', 'downwards', 'across', 'to', 'under', 'away', 'onwards', 'together', 'under', 'under', 'around', 'away', '(malefactive), together', '(idea of destruction/death), across', '(malefactive), towards', '(idea of destruction/death), across', 'under', 'to', 'towards', 'out', 'under', 'under', 'up, from under', 'completely', 'into', '(idea of destruction/death), across', 'away', 'under', 'out', 'behind', 'away', 'away', 'in', 'into', 'together', 'to', 'out', 'against', 'into, under', 'around', 'away', 'to', 'onwards', 'to', 'into', 'into', 'away', 'against', 'away', 'to', 'to', '(idea of destruction/death), across', 'to', 'to', 'into', 'completely', 'onwards', 'downwards', 'completely', 'over', 'across', 'away', 'to', 'to', '(idea of destruction/death), across', '(idea of destruction/death), across', 'downwards', 'against', 'against', 'into', 'away', 'away', 'away', 'to', 'before', 'to', 'forward', 'downwards', 'over', 'to', 'together', 'away', 'away', 'away', 'past', 'behind', 'to, under', 'to', 'away', 'to', 'together', 'out', 'across', 'over', 'into', 'downwards', 'into', 'towards', 'to', 'out', 'into', 'to', 'around', 'in', 'under', 'over', 'to', 'in', 'to', 'to', 'against', 'to', 'to', 'through', 'completely', 'against', 'away', 'over', 'after', 'over', 'around', 'into', 'through', 'to', 'to', 'to', 'towards, under', 'to', 'into', 'together', 'to', 'into', 'together', 'away', 'away', 'together', 'together', 'together', 'to', 'into', 'away', 'to', 'into', 'out', 'out', 'in', 'out', 'onwards', 'to', 'to', 'over', 'onwards', 'to', 'to, under', 'together', 'across', '(malefactive), together', 'completely', 'into', 'towards', ' ...

# %% [markdown]
# #### Extracting Token IDs from Actionality Annotations
# Note that any other span layer can be used.

# %%
list_token_ids = []  # Initializing an empty list to store token IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Actionality' annotation in the CAS
    for relation in cas.select('webanno.custom.Actionality'):
        # Looping through each token covered by the 'Actionality' annotation
        for token in cas.select_covered('webanno.custom.Actionality', relation):
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
'48145Virg', '48241Virg', '49770Virg', '50132Virg', '51144Virg', '51805Virg', '52297Virg', '52346Virg', '53177Virg', '54217Virg', '54718Virg', '54916Virg', '56245Virg', '59141Virg', '59228Virg', '59803Virg', '62403Virg', '62863Virg', '64240Virg', '64250Virg', '65760Virg', '65999Virg', '66493Virg', '68857Virg', '69560Virg', '69709Virg', '70805Virg', '71379Virg', '71716Virg', '73590Virg', '73713Virg', '73793Virg', '80521Virg', '82245Virg', '83144Virg', '83462Virg', '86033Virg', '87458Virg', '87664Virg', '87795Virg', '88198Virg', '90216Virg', '90398Virg', '92904Virg', '97057Virg', '104583Virg', '106171Virg', '106849Virg', '107640Virg', '108134Virg', '108891Virg', '109468Virg', '109948Virg', '113059Virg', '114612Virg', '116498Virg', '123434Virg', '124355Virg', '133403Virg', '133638Virg', '134189Virg', '135444Virg', '138905Virg', '140556Virg', '141091Virg', '141273Virg', '141744Virg', '142211Virg', '142989Virg', '143030Virg', '143385Virg', '146166Virg', '146482Virg', '147001Virg', '147545Virg', '147939Virg', '148092Virg', '148425Virg', '149019Virg', '149322Virg', '150806Virg', '153567Virg', '154152Virg', '155882Virg', '155986Virg', '157561Virg', '158232Virg', '159975Virg', '161170Virg', '171793Virg ...

# %% [markdown]
# #### Creating a dictionary where each token ID from idlist is mapped to its corresponding preverb semantics from list_preverb_semantics

# %%
pred2_preverb_semantics = {list_token_ids[i]: list_preverb_semantics[i] for i in range(len(list_token_ids))}
pred2_preverb_semantics
# Out:
# {'1498Caes': 'out',
#  '4296Caes': 'out',
#  '4578Caes': 'under',
#  '4854Caes': 'across',
#  '4978Caes': 'out',
#  '5366Caes': 'across',
#  '5732Caes': 'together',
#  '5997Caes': 'completely',
#  '6831Caes': 'together',
#  '7012Caes': 'together',
#  '7293Caes': 'across',
#  '8498Caes': 'across',
#  '9426Caes': 'completely',
#  '9649Caes': 'completely',
#  '10407Caes': 'completely',
#  '10617Caes': 'across',
#  '10862Caes': 'completely',
#  '10890Caes': 'across',
#  '10931Caes': '(malefactive), to',
#  '11152Caes': 'out',
#  '11818Caes': 'across',
#  '12323Caes': 'across',
#  '21567Caes': 'to',
#  '24504Caes': '(malefactive), to',
#  '24513Caes': 'around',
#  '25610Caes': 'completely',
#  '26036Caes': 'together with',
#  '26225Caes': 'completely',
#  '26268Caes': 'completely',
#  '26640Caes': 'away',
#  '27386Caes': 'across',
#  '27831Caes': 'out',
#  '28359Caes': 'together',
#  '29918Caes': 'across',
#  '30767Caes': 'forth',
#  '31365Caes': 'across',
#  '33967Caes': 'across',
#  '34210Caes': 'away',
#  '34348Caes': 'against',
#  '36546Caes': '(malefactive), together',
#  '36804Caes': 'together',
#  '37047Caes': '(malefactive), together',
#  '37157Caes': 'under',
#  '37517Caes': 'across',
#  '38986Caes': '(malefactive), together',
#  '41443Caes': '(malefactive), together',
#  '46744Caes': 'across',
#  '46852Caes': 'across',
#  '48088Caes': 'away',
#  '50312Caes': 'around',
#  '52574Caes': 'together',
#  '53622Caes': 'onwards',
#  '56162Caes': 'completely',
#  '56208Caes': 'across',
#  '56243Caes': 'into',
#  '56345Caes': 'forward',
#  '56583Caes': '(idea of destruction/death), across',
#  '58654Caes': 'into',
#  '59161Caes': 'completely',
#  '60301Caes': 'into',
#  '61670Caes': 'together',
#  '63933Caes': 'to',
#  '64997Caes': 'around',
#  '65326Caes': 'across',
#  '65391Caes': 'across',
#  '65423Caes': '(malefactive), to',
#  '65528Caes': 'across',
#  '66243Caes': '(malefactive), to',
#  '66324Caes': 'across',
#  '66389Caes': 'across',
#  '66411Caes': 'around',
#  '66489Caes': 'across',
#  '66567Caes': 'onwards',
#  '66805Caes': 'together',
#  '67219Caes': 'away',
#  '67317Caes': 'completely',
#  '68853Caes': 'together',
#  '69478Caes': 'away',
#  '70242Caes': 'forth',
#  '70802Caes': 'completely',
#  '71412Caes': 'into',
#  '72211Caes': 'completely',
#  '74081Caes': 'across',
#  '74551Caes': 'together',
#  '74664Caes': 'forth',
#  '74785Caes': 'downwards',
#  '75094Caes': 'together',
#  '75892Caes': 'downwards',
#  '75926Caes': 'completely',
#  '76251Caes': 'against',
#  '76487Caes': 'completely',
#  '77252Caes': 'into',
#  '77316Caes': 'across',
#  '77401Caes': 'across',
#  '77454Caes': 'onwards',
#  '77631Caes': 'together',
#  '77984Caes': 'around',
#  '78212Caes': '(malefactive), to',
#  '78345Caes': 'across',
#  '78384Caes': 'away',
#  '78841Caes': 'around',
#  '79714Caes': 'under',
#  '81306Caes': '(malefactive), to',
#  '81803Caes': 'across',
#  '81859Caes': 'towards',
#  '85712Caes': 'out',
#  '85792Caes': 'into',
#  '86330Caes': 'together',
#  '87400Caes': 'into',
#  '88780Caes': 'across',
#  '89385Caes': 'downwards',
#  '90378Caes': 'completely',
#  '90684Caes': 'downwards',
#  '90903Caes': 'against',
#  '91683Caes': 'to',
#  '92258Caes': 'around',
#  '92706Caes': 'against',
#  '93136Caes': 'into',
#  '93203Caes': 'to',
#  '95973Caes': 'into',
#  '97054Caes': 'to',
#  '97169Caes': 'across',
#  '97624Caes': 'together',
#  '99409Caes': 'together',
#  '100171Caes': 'together',
#  '102324Caes': 'together',
#  '102818Caes': 'completely',
#  '103209Caes': 'together',
#  '104069Caes': 'across',
#  '105194Caes': 'completely',
#  '106032Caes': 'completely',
#  '106355Caes': 'forth',
#  '108403Caes': 'together',
#  '110964Caes': 'around',
#  '111487Caes': 'completely',
#  '111782Caes': 'around',
#  '111980Caes': 'together',
#  '112893Caes': 'completely',
#  '113030Caes': 'out',
#  '114154Caes': 'across',
#  '114211Caes': 'across',
#  '115967Caes': 'towards',
#  '117032Caes': 'completely',
#  '117294Caes': 'across',
#  '117394Caes': 'across',
#  '117506Caes': 'onwards',
#  '117858Caes': 'across',
#  '118479Caes': 'into',
#  '118665Caes': 'against',
#  '121658Caes': 'together',
#  '121689Caes': 'onwards',
#  '122305Caes': 'together',
#  '123522Caes': 'around',
#  '124898Caes': 'completely',
#  '125531Caes': 'across',
#  '125781Caes': 'completely',
#  '125934Caes': '(idea of destruction/death), across',
#  '126380Caes': 'across',
#  '126596Caes': 'across',
#  '126731Caes': 'across',
#  '127053Caes': 'across',
#  '127799Caes': 'across',
#  '127832Caes': 'across',
#  '130412Caes': 'together',
#  '131258Caes': 'to',
#  '131412Caes': 'to',
#  '132195Caes': 'together',
#  '132754Caes': 'to',
#  '132936Caes': 'out',
#  '134386Caes': 'onwards',
#  '134764Caes': 'out',
#  '134834Caes': 'together',
#  '135306Caes': 'onwards',
#  '135522Caes': 'out',
#  '135874Caes': 'onwards',
#  '136747Caes': 'away',
#  '137342Caes': 'against',
#  '137469Caes': 'out',
#  '138342Caes': 'out',
#  '138943Caes': 'together',
#  '140508Caes': 'together',
#  '140959Caes': 'across',
#  '142066Caes': 'into',
#  '143342Caes': 'along',
#  '144404Caes': 'away',
#  '145197Caes': 'completely',
#  '145680Caes': 'together',
#  '432Virg': 'to',
#  '7706Virg': 'to, under',
#  '7737Virg': 'out',
#  '8862Virg': 'away',
#  '11990Virg': 'through',
#  '13785Virg': 'out',
#  '16238Virg': 'together',
#  '17473Virg': 'to',
#  '18006Virg': 'to, under',
#  '18671Virg': 'away',
#  '21365Virg': '(malefactive), together',
#  '22177Virg': '(malefactive), together with',
#  '23365Virg': 'into',
#  '28254Virg': 'under',
#  '29798Virg': 'completely',
#  '30509Virg': 'against',
#  '31255Virg': 'together',
#  '34874Virg': 'away',
#  '35620Virg': 'downwards',
#  '37459Virg': 'across',
#  '41276Virg': 'to',
#  '43573Virg': 'under',
#  '43993Virg': 'away',
#  '44602Virg': 'onwards',
#  '48145Virg': 'together',
#  '48241Virg': 'under',
#  '49770Virg': 'under',
#  '50132Virg': 'around',
#  '51144Virg': 'away',
#  '51805Virg': '(malefactive), together',
#  '52297Virg': '(idea of destruction/death), across',
#  '52346Virg': '(malefactive), towards',
#  '53177Virg': '(idea of destruction/death), across',
#  '54217Virg': 'under',
#  '54718Virg': 'to',
#  '54916Virg': 'towards',
#  '56245Virg': 'out',
#  '59141Virg': 'under',
#  '59228Virg': 'under',
#  '59803Virg': 'up, from under',
#  '62403Virg': 'completely',
#  '62863Virg': 'into',
#  '64240Virg': '(idea of destruction/death), across',
#  '64250Virg': 'away',
#  '65760Virg': 'under',
#  '65999Virg': 'out',
#  '66493Virg': 'behind',
#  '68857Virg': 'away',
#  '69560Virg': 'away',
#  '69709Virg': 'in',
#  '70805Virg': 'into',
#  '71379Virg': 'together',
#  '71716Virg': 'to',
#  '73590Virg': 'out',
#  '73713Virg': 'against',
#  '73793Virg': 'into, under',
#  '80521Virg': 'around',
#  '82245Virg': 'away',
#  '83144Virg': 'to',
#  '83462Virg': 'onwards',
#  '86033Virg': 'to',
#  '87458Virg': 'into',
#  '87664Virg': 'into',
#  '87795Virg': 'away',
#  '88198Virg': 'against',
#  '90216Virg': 'away',
#  '90398Virg': 'to',
#  '92904Virg': 'to',
#  '97057Virg': '(idea of destruction/death), across',
#  '104583Virg': 'to',
#  '106171Virg': 'to',
#  '106849Virg': 'into',
#  '107640Virg': 'completely',
#  '108134Virg': 'onwards',
#  '108891Virg': 'downwards',
#  '109468Virg': 'completely',
#  '109948Virg': 'over',
#  '113059Virg': 'across',
#  '114612Virg': 'away',
#  '116498Virg': 'to',
#  '123434Virg': 'to',
#  '124355Virg': '(idea of destruction/death), across',
#  '133403Virg': '(idea of destruction/death), across',
#  '133638Virg': 'downwards',
#  '134189Virg': 'against',
#  '135444Virg': 'against',
#  '138905Virg': 'into',
#  '140556Virg': 'away',
#  '141091Virg': 'away',
#  '141273Virg': 'away',
#  '141744Virg': 'to',
#  '142211Virg': 'before',
#  '142989Virg': 'to',
#  '143030Virg': 'forward',
#  '143385Virg': 'downwards',
#  '146166Virg': 'over',
#  '146482Virg': 'to',
#  '147001Virg': 'together',
#  '147545Virg': 'away',
#  '147939Virg': 'away',
#  '148092Virg': 'away',
#  '148425Virg': 'past',
#  '149019Virg': 'behind',
#  '149322Virg': 'to, under',
#  '150806Virg': 'to',
#  '153567Virg': 'away',
#  '154152Virg': 'to',
#  '155882Virg': 'together',
#  '155986Virg': 'out',
#  '157561Virg': 'across',
#  '158232Virg': 'over',
#  '159975Virg': 'into',
#  '161170Virg': 'downwards',
#  '171793Virg': 'into',
#  '172598Virg': 'towards',
#  '173466Virg': 'to',
#  '173621Virg': 'out',
#  '175538Virg': 'into',
#  '178081Virg': 'to',
#  '178845Virg': 'around',
#  '178923Virg': 'in',
#  '179216Virg': 'under',
#  '179933Virg': 'over',
#  '180403Virg': 'to',
#  '189518Virg': 'in',
#  '189796Virg': 'to',
#  '190311Virg': 'to',
#  '194445Virg': 'against',
#  '196965Virg': 'to',
#  '199193Virg': 'to',
#  '201167Virg': 'through',
#  '201653Virg': 'completely',
#  '204262Virg': 'against',
#  '204513Virg': 'away',
#  '209024Virg': 'over',
#  '209511Virg': 'after',
#  '211455Virg': 'over',
#  '211949Virg': 'around',
#  '211997Virg': 'into',
#  '214128Virg': 'through',
#  '214495Virg': 'to',
#  '217132Virg': 'to',
#  '219889Virg': 'to',
#  '220630Virg': 'towards, under',
#  '220908Virg': 'to',
#  '222054Virg': 'into',
#  '223419Virg': 'together',
#  '225199Virg': 'to',
#  '226630Virg': 'into',
#  '227586Virg': 'together',
#  '230693Virg': 'away',
#  '232956Virg': 'away',
#  '236580Virg': 'together',
#  '237732Virg': 'together',
#  '239357Virg': 'together',
#  '242250Virg': 'to',
#  '243200Virg': 'into',
#  '246097Virg': 'away',
#  '249161Virg': 'to',
#  '251661Virg': 'into',
#  '252649Virg': 'out',
#  '253105Virg': 'out',
#  '253927Virg': 'in',
#  '255168Virg': 'out',
#  '255307Virg': 'onwards',
#  '255317Virg': 'to',
#  '263177Virg': 'to',
#  '263464Virg': 'over',
#  '264714Virg': 'onwards',
#  '265711Virg': 'to',
#  '265861Virg': 'to, under',
#  '266821Virg': 'together',
#  '267152Virg': 'across',
#  '270477Virg': '(malefactive), together',
#  '271603Virg': 'completely',
#  '272498Virg': 'into',
#  '273887Virg': 'towards',
#  '274288Virg': 'over',
#  '275733Virg': 'out',
#  '278664Virg': 'in',
#  '280427Virg': 'in',
#  '280463Virg': 'together with',
#  '287152Virg': 'across',
#  '295134Virg': 'under',
#  '296146Virg': 'away',
#  '296659Virg': '(malefactive), to',
#  '297527Virg': 'against, to',
#  '298771Virg': 'towards, under',
#  '299424Virg': 'away',
#  '299873Virg': 'across',
#  '300266Virg': 'under',
#  '300658Virg': 'across',
#  '303460Virg': 'out',
#  '307599Virg': 'to',
#  '310327Virg': 'away',
#  '312935Virg': 'forward',
#  '313368Virg': 'away',
#  '314287Virg': 'together',
#  '315136Virg': 'out',
#  '315248Virg': 'into',
#  '315495Virg': 'away',
#  '315938Virg': 'under',
#  '316843Virg': 'together',
#  '317870Virg': 'together',
#  '318980Virg': '(malefactive), together with',
#  '319097Virg': 'to',
#  '323697Virg': 'into',
#  '325250Virg': 'into',
#  '325275Virg': 'to',
#  '328440Virg': 'against',
#  '328539Virg': 'in',
#  '330527Virg': 'across',
#  '331278Virg': 'against',
#  '331311Virg': 'out',
#  '333759Virg': 'to',
#  '334105Virg': 'to',
#  '334418Virg': 'to',
#  '334455Virg': 'to',
#  '334790Virg': '(malefactive), together',
#  '335260Virg': 'up, from under',
#  '337038Virg': 'together',
#  '337952Virg': 'together',
#  '338198Virg': '(malefactive), together',
#  '338908Virg': 'together',
#  '339076Virg': 'to',
#  '339308Virg': 'to',
#  '339833Virg': 'completely',
#  '340312Virg': 'over',
#  '341530Virg': 'to',
#  '341593Virg': 'under',
#  '341806Virg': 'to',
#  '342042Virg': 'under',
#  '342842Virg': 'together',
#  '344986Virg': 'through, under',
#  '346282Virg': '(idea of destruction/death), across',
#  '348660Virg': 'away',
#  '349601Virg': 'together',
#  '350829Virg': '(malefactive), together with',
#  '351569Virg': 'against',
#  '352881Virg': 'over',
#  '353048Virg': 'into',
#  '353870Virg': 'across',
#  '354451Virg': 'up',
#  '354559Virg': 'away',
#  '355594Virg': 'under',
#  '357204Virg': 'away',
#  '357988Virg': 'towards',
#  '358823Virg': 'to',
#  '364594Virg': '(malefactive), together',
#  '367798Virg': 'completely',
#  '370405Virg': 'into',
#  '372429Virg': 'together with',
#  '374312Virg': 'under',
#  '375726Virg': 'away',
#  '381217Virg': 'downwards',
#  '381596Virg': 'against',
#  '381797Virg': '(malefactive), to',
#  '382911Virg': '(malefactive), to',
#  '383814Virg': 'in',
#  '386460Virg': 'onwards',
#  '386671Virg': '(malefactive), towards',
#  '387178Virg': 'forward',
#  '387496Virg': '(malefactive), together',
#  '387753Virg': 'to',
#  '389348Virg': 'to',
#  '390022Virg': 'to',
#  '390807Virg': 'into',
#  '391464Virg': 'past',
#  '391512Virg': '(malefactive), together',
#  '392954Virg': 'away',
#  '393342Virg': '(malefactive), towards',
#  '393422Virg': 'around',
#  '393528Virg': 'onwards',
#  '395407Virg': 'together',
#  '395567Virg': 'against',
#  '396317Virg': 'away',
#  '396723Virg': '(malefactive), towards',
#  '397667Virg': 'away',
#  '397899Virg': 'together',
#  '398815Virg': 'away',
#  '399820Virg': 'out',
#  '399871Virg': 'into',
#  '400199Virg': 'into',
#  '400912Virg': '(malefactive), together',
#  '404158Virg': 'before',
#  '407054Virg': 'together with',
#  '408595Virg': 'together',
#  '410205Virg': 'onwards',
#  '412317Virg': 'forward',
#  '412923Virg': 'forward',
#  '413525Virg': 'to',
#  '413679Virg': 'together',
#  '414488Virg': '(malefactive), together with',
#  '416065Virg': 'to',
#  '418556Virg': 'under',
#  '418671Virg': 'towards',
#  '419546Virg': 'forward',
#  '421254Virg': 'together',
#  '421505Virg': 'under',
#  '421643Virg': 'across',
#  '421860Virg': 'over',
#  '422984Virg': 'together with',
#  '423273Virg': '(malefactive), together',
#  '424445Virg': 'against',
#  '425637Virg': 'together',
#  '426027Virg': 'together with',
#  '428401Virg': 'against',
#  '432530Virg': '(malefactive), towards',
#  '432841Virg': 'together',
#  '433256Virg': 'under',
#  '434538Virg': 'to',
#  '434996Virg': 'together with',
#  '435595Virg': 'forward',
#  '436869Virg': 'under',
#  '438653Virg': 'to',
#  '440736Virg': 'under',
#  '441937Virg': 'across'}

# %% [markdown]
# #### Creating DataFrame for Preverb Semantics

# %%
preverb_semantics_df = pd.DataFrame([(k,v) for k,v in pred2_preverb_semantics.items()], columns=["ID", "PREVERB SEMANTICS"]) #where 'preverb_semantics_df' is a dataframe containing token IDs and preverb semantics of the verb tokens
preverb_semantics_df
# Out:
#              ID PREVERB SEMANTICS
# 0      1498Caes               out
# 1      4296Caes               out
# 2      4578Caes             under
# 3      4854Caes            across
# 4      4978Caes               out
# ..          ...               ...
# 499  435595Virg           forward
# 500  436869Virg             under
# 501  438653Virg                to
# 502  440736Virg             under
# 503  441937Virg            across
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Preverb Semantics and Verb Stem DataFrames

# %%
id_preverb_semantics_df = id_preverbs_df.merge(preverb_semantics_df, on='ID', how='left') #where 'id_preverb_semantics_df' merges 'id_preverbs_df' and 'preverb_semantics_df'
id_preverb_semantics_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY  \
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
#             VERB CLASS  LITERAL MEANING     VERB STEM PREVERB  \
# 0          ESCAPE-51.1             True  present stem      ex
# 1          ESCAPE-51.1             True  present stem      ex
# 2          MARVEL-31.3            False  present stem     sub
# 3          ESCAPE-51.1             True  perfect stem   trans
# 4          ESCAPE-51.1             True  present stem      ex
# ..                 ...              ...           ...     ...
# 499         RUN-51.3.2             True  present stem     pro
# 500          HELP-72.1            False  present stem     sub
# 501         RUN-51.3.2            False  present stem      ob
# 502  PUT_DIRECTION-9.4            False  present stem     sub
# 503        ESCAPE-51.1             True  present stem   trans
#
#     PREVERB SEMANTICS
# 0                 out
# 1                 out
# 2               under
# 3              across
# 4                 out
# ..                ...
# 499           forward
# 500             under
# 501                to
# 502             under
# 503            across
#
# [504 rows x 11 columns]

# %% [markdown]
# ## Verb semantics

# %% [markdown]
# #### Extracting Verb Semantics Values

# %%
list_synsets = []  # Initializing an empty list to store semantic classes
tok2_synsets = dict()  # Initializing an empty dictionary to store predicted semantic classes mapped to IDs
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'SemClass' annotation in the CAS
    for relation in cas.select('webanno.custom.SemClass'):
        # Looping through each token covered by the 'SemClass' annotation
        for token in cas.select_covered('webanno.custom.SemClass', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            synset = relation.Synsets  # Getting the semantic class value
            
            # Checking if the ID already exists in tok2_synsets dictionary
            if id in tok2_synsets:
                # If ID exists, append the new semantic class to the existing list of semantic classes
                list_synsets = tok2_synsets[id] + synset 
                tok2_synsets[id] = list_synsets
            else:
                # If ID doesn't exist, store the semantic class directly
                tok2_synsets[id] = synset

print(tok2_synsets)
# Out:
# {'1466Caes': uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray)), '1498Caes': uima_cas_StringArray(xmiID=None, elements=['v#01376117 move out of; as of a room, a country, a bus, etc.'], type=Type(name=uima.cas.StringArray)), '4283Caes': uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray)), '4296Caes': uima_cas_StringArray(xmiID=None, elements=['v#01376117 move out of; as of a room, a country, a bus, etc.'], type=Type(name=uima.cas.StringArray)), '4569Caes': uima_cas_StringArray(xmiID=None, elements=['n#10428324 a source of danger'], type=Type(name=uima.cas.StringArray)), '4578Caes': uima_cas_StringArray(xmiID=None, elements=['v#01444459 undergo or suffer'], type=Type(name=uima.cas.StringArray)), '4840Caes': uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray)), '4854Caes': uima_cas_StringArray(xmiID=None, elements=['v#01253107 change location; move, travel, or proceed'], type=Type(name=uima.cas.StringArray)), '4962Caes': uima_cas_StringArray(xmiID=None, elements=['n#03243979 an open way (generally public) for travel or transportation'], type=Type(name=uima.cas.StringArray)), '4973Caes': uima_cas_StringArray(xmiID=None, elements=['n#06277165 the country where you were born'], type=Type(name=uima.cas.StringArray)), '4978Caes': uima_cas_StringArray(xmiID=None, elements=['v#01371248 go away from a place'], type=Type(name=uima.cas.StringArray)), '5323Caes': uima_cas_StringArray(xmiID=None, elements=['n#06789983 a large natural stream of water (larger than a creek)'], type=Type(name=uima.cas.StringArray)), '5366Caes': uima_cas_StringArray(xmiID=None, elements=['v#01401176 go across or through'], type=Type(name=uima.cas.StringArray)), '5712Caes': uima_cas_StringArray(xmiID=None, elements=['n#06800223 sloping land (especially the slope beside a body of water)'], type=Type(name=uima.cas.StringArray)), '5732Caes': uima_cas_StringArray(xmiID=None, elements=['v#01654097 collect in one place'], type=Type(name=uima.cas.StringArray)), '5989Caes': uima_cas_StringArray(xmiID=None, elements=['n#06588141 a city in southwestern Switzerland at the western end of Lake Geneva; the Palace of Nations originally housed the League of Nations and is now the European headquarters for the United Nations', 'n#06287351 a large and densely populated urban area; may include several independent administrative districts'], type=Type(name=uima.cas.StringArray)), '5997Caes': uima_cas_StringArray(xmiID=None, elements=['v#01368651 reach a destination; arrive by movement or by making progress'], type=Type(name=uima.cas.StringArray)), '6806Caes': uima_cas_StringArray(xmiID=None, elements=['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '6831Caes': uima_cas_StringArray(xmiID=None, elements=['v#01654097 collect in one place'], type=Type(name=uima.cas.StringArray)), '6995Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '7002Caes': uima_cas_StringArray(xmiID=None, elements=['n#09535912 a territorial possession controlled by a ruling state'], type=Type(name=uima.cas.StringArray)), '7012Caes': uima_cas_StringArray(xmiID=None, elements=['v#01654097 collect in one place'], type=Type(name=uima.cas.StringArray)), '7293Caes': uima_cas_StringArray(xmiID=None, elements=['v#01401176 go across or through'], type=Type(name=uima.cas.StringArray)), '8498Caes': uima_cas_StringArray(xmiID=None, elements=['v#01253107 change location; move, travel, or proceed'], type=Type(name=uima.cas.StringArray)), '9374Caes': uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray)), '9426Caes': uima_cas_StringArray(xmiID=None, elements=['v#01368651 reach ...

# %% [markdown]
# #### Extracting Verb Semantics Values Removing Unwanted Characters

# %%
list_synsets = []  # Initializing an empty list to store synsets

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'SemClass' annotation in the CAS
    for relation in cas.select('webanno.custom.SemClass'):
        synset = relation.Synsets  # Getting the synset value
        # Extracting the useful information from the StringArray elements
        synset_values = [element.strip().strip("'") for element in synset.elements]
        # Appending the synset values as a sublist
        list_synsets.append(synset_values)

print(list_synsets)
# Out:
# [['n#06299747 the territory occupied by a nation'], ['v#01376117 move out of; as of a room, a country, a bus, etc.'], ['n#06299747 the territory occupied by a nation'], ['v#01376117 move out of; as of a room, a country, a bus, etc.'], ['n#10428324 a source of danger'], ['v#01444459 undergo or suffer'], ['n#06299747 the territory occupied by a nation'], ['v#01253107 change location; move, travel, or proceed'], ['n#03243979 an open way (generally public) for travel or transportation'], ['n#06277165 the country where you were born'], ['v#01371248 go away from a place'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['v#01401176 go across or through'], ['n#06800223 sloping land (especially the slope beside a body of water)'], ['v#01654097 collect in one place'], ['n#06588141 a city in southwestern Switzerland at the western end of Lake Geneva; the Palace of Nations originally housed the League of Nations and is now the European headquarters for the United Nations', 'n#06287351 a large and densely populated urban area; may include several independent administrative districts'], ['v#01368651 reach a destination; arrive by movement or by making progress'], ['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being'], ['v#01654097 collect in one place'], ['n#00004123 a human being'], ['n#09535912 a territorial possession controlled by a ruling state'], ['v#01654097 collect in one place'], ['v#01401176 go across or through'], ['v#01253107 change location; move, travel, or proceed'], ['n#06299747 the territory occupied by a nation'], ['v#01368651 reach a destination; arrive by movement or by making progress'], ['n#06299747 the territory occupied by a nation'], ['v#01368651 reach a destination; arrive by movement or by making progress'], ['n#00004123 a human being'], ['n#00004123 a human being'], ['v#01368651 reach a destination; arrive by movement or by making progress'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#00004123 a human being'], ['v#01401176 go across or through'], ['n#06095787 an army unit large enough to sustain combat', 'n#00004123 a human being'], ['v#01368651 reach a destination; arrive by movement or by making progress'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['v#01401176 go across or through'], ['n#00004123 a human being'], ['v#00760028 attack someone physically or emotionally'], ['n#06296283 a small administrative division of a country'], ['n#06277165 the country where you were born'], ['v#01388242 make a division or separation'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['v#01401176 go across or through'], ['n#00004123 a human being'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['v#01401176 go across or through'], ['n#00004123 a human being'], ['n#00004123 a human being'], ['v#01410345 run or move very quickly or hastily'], ['n#00004123 a human being'], ['n#06261108 the side of military or naval formation'], ['v#00760028 attack someone physically or emotionally'], ['v#01428651 go around the flank of (an opposing army)'], ['n#06299747 the territory occupied by a nation'], ['v#01368651 reach a destination; arrive by movement or by making progress'], ['n#00004123 a human being'], ['v#01382085 meet'], ['r#00106274 to or toward that place; away from the speaker'], ['v#01368651 reach a destination; arrive by movement or by making progress'], ['n#07583414 a person who is owned by someone', 'n#00004123 a human being'], ['n#07583414 a person who is owned by someone', 'n#00004123 a human being'], ['n#00004123 a human being'], ['v#L1326119 desert (a cause, a country or an army), often in order to join the opposing cause, country, or army'], ['n#02372560 temporary living quarters specially built by the army for soldiers'], ['v#01371248 go away from a place'], ['n#00004123 a human being'], ['n#06299747 the territory occupied by a nation'], ['n#09534064 wealth r ...

# %% [markdown]
# #### Extracting Token IDs from Synset Annotations (Verbs and Nouns)

# %%
list_token_synsets_ids = []  # Initializing an empty list to store IDs of tokens annotated with a synset (i.e., verbs and nouns)
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'SemClass' annotation in the CAS
    for relation in cas.select('webanno.custom.SemClass'):
        # Looping through each token covered by the 'SemClass' annotation
        for token in cas.select_covered('webanno.custom.SemClass', relation):
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '10576Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '10579Caes': ['n#00004123 a human being'],
#  '10617Caes': ['v#01401176 go across or through'],
#  '10855Caes': ['n#06095787 an army unit large enough to sustain combat',
#   'n#00004123 a human being'],
#  '10862Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '10883Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '10890Caes': ['v#01401176 go across or through'],
#  '10902Caes': ['n#00004123 a human being'],
#  '10931Caes': ['v#00760028 attack someone physically or emotionally'],
#  '11131Caes': ['n#06296283 a small administrative division of a country'],
#  '11147Caes': ['n#06277165 the country where you were born'],
#  '11152Caes': ['v#01388242 make a division or separation'],
#  '11811Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '11818Caes': ['v#01401176 go across or through'],
#  '12312Caes': ['n#00004123 a human being'],
#  '12316Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '12323Caes': ['v#01401176 go across or through'],
#  '21537Caes': ['n#00004123 a human being'],
#  '21563Caes': ['n#00004123 a human being'],
#  '21567Caes': ['v#01410345 run or move very quickly or hastily'],
#  '24479Caes': ['n#00004123 a human being'],
#  '24490Caes': ['n#06261108 the side of military or naval formation'],
#  '24504Caes': ['v#00760028 attack someone physically or emotionally'],
#  '24513Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '25584Caes': ['n#06299747 the territory occupied by a nation'],
#  '25610Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '26021Caes': ['n#00004123 a human being'],
#  '26036Caes': ['v#01382085 meet'],
#  '26206Caes': ['r#00106274 to or toward that place; away from the speaker'],
#  '26225Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '26250Caes': ['n#07583414 a person who is owned by someone',
#   'n#00004123 a human being'],
#  '26257Caes': ['n#07583414 a person who is owned by someone',
#   'n#00004123 a human being'],
#  '26264Caes': ['n#00004123 a human being'],
#  '26268Caes': ['v#L1326119 desert (a cause, a country or an army), often in order to join the opposing cause, country, or army'],
#  '26620Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '26640Caes': ['v#01371248 go away from a place'],
#  '27313Caes': ['n#00004123 a human being'],
#  '27357Caes': ['n#06299747 the territory occupied by a nation'],
#  '27380Caes': ['n#09534064 wealth reckoned in terms of money'],
#  '27386Caes': ['v#01253107 change location; move, travel, or proceed'],
#  '27818Caes': ['n#06259974 a select company of people'],
#  '27826Caes': ['n#06277165 the country where you were born'],
#  '27831Caes': ['v#01376117 move out of; as of a room, a country, a bus, etc.'],
#  '28307Caes': ['n#07211391 a person appointed to represent or act on behalf of others',
#   'n#00004123 a human being'],
#  '28339Caes': ['n#00004123 a human being'],
#  '28359Caes': ['v#01654097 collect in one place'],
#  '29911Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '29918Caes': ['v#01401176 go across or through'],
#  '30752Caes': ['n#00004123 a human being'],
#  '30758Caes': ['n#06299747 the territory occupied by a nation'],
#  '30767Caes': ['v#01420490 to run away'],
#  '31358Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '31365Caes': ['v#01401176 go across or through'],
#  '33960Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '33967Caes': ['v#01401176 go across or through'],
#  '34199Caes': ['n#09535912 a territorial possession controlled by a ruling state'],
#  '34210Caes': ['v#01262245 move away from a place into another direction'],
#  '34348Caes': ['v#01658906 be in charge of, act on, or dispose of'],
#  '36546Caes': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '36804Caes': ['v#01566369 be agreeable or suitable'],
#  '37047Caes': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '37146Caes': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '37157Caes': ['v#01376901 to come or go into'],
#  '37510Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '37517Caes': ['v#01401176 go across or through'],
#  '38986Caes': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '41434Caes': ['n#00004123 a human being'],
#  '41443Caes': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '46737Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '46744Caes': ['v#01401176 go across or through'],
#  '46852Caes': ['v#01401176 go across or through'],
#  '46862Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '48037Caes': ['n#06089493 an organization of military land forces',
#   'n#00004123 a human being'],
#  '48080Caes': ['n#10019535 an international boundary or the area along such a boundary'],
#  '48088Caes': ['v#01371248 go away from a place'],
#  '50279Caes': ['n#00004123 a human being'],
#  '50286Caes': ['n#00004123 a human being'],
#  '50312Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '52549Caes': ['n#00004123 a human being'],
#  '52574Caes': ['v#01654097 collect in one place'],
#  '53614Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '53622Caes': ['v#01360914 move ahead; travel onward'],
#  '56119Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '56146Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '56162Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '56208Caes': ['v#01335172 travel through water'],
#  '56233Caes': ['n#02304226 a small vessel for travel on water'],
#  '56243Caes': ['v#01538749 come upon, as if by accident; meet with'],
#  '56302Caes': ['n#00004123 a human being'],
#  '56342Caes': ['r#00106088 in or at that place'],
#  '56345Caes': ['v#01420490 to run away'],
#  '56564Caes': ['n#00004123 a human being'],
#  '56583Caes': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '58654Caes': ['v#01778989 have a beginning, in a temporal, spatial, or evaluative sense'],
#  '58660Caes': ['n#10946199 the warmest season of the year'],
#  '59146Caes': ['n#06299747 the territory occupied by a nation'],
#  '59161Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '60295Caes': ['n#10019535 an international boundary or the area along such a boundary'],
#  '60301Caes': ['v#01376901 to come or go into'],
#  '61656Caes': ['n#06069615 assembly possessing high legislative powers',
#   'n#00004123 a human being'],
#  '61667Caes': ['n#00004123 a human being'],
#  '61670Caes': ['v#01654097 collect in one place'],
#  '63929Caes': ['r#00490593 to what place, purpose, or end'],
#  '63933Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '64927Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '64992Caes': ['n#00004123 a human being'],
#  '64997Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '65311Caes': ['n#06786830 low-lying wet land with grassy vegetation; usually is a transition zone between land and water'],
#  '65326Caes': ['v#01401176 go across or through'],
#  '65391Caes': ['v#01401176 go across or through'],
#  '65423Caes': ['v#00760028 attack someone physically or emotionally'],
#  '65528Caes': ['v#01401176 go across or through'],
#  '66208Caes': ['n#06088783 an opposing military force',
#   'n#00004123 a human being'],
#  '66225Caes': ['n#00004123 a human being'],
#  '66235Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '66243Caes': ['v#00760028 attack someone physically or emotionally'],
#  '66295Caes': ['n#04056524 the dead body of a human being'],
#  '66324Caes': ['v#01304824 travel across or pass over'],
#  '66385Caes': ['n#00004123 a human being'],
#  '66389Caes': ['v#01401176 go across or through'],
#  '66402Caes': ['n#06210014 troops trained to fight on horseback',
#   'n#00004123 a human being'],
#  '66411Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '66481Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '66489Caes': ['v#01401176 go across or through'],
#  '66550Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '66567Caes': ['v#01360914 move ahead; travel onward'],
#  '66797Caes': ['r#L2533591 from any or all places'],
#  '66805Caes': ['v#01654097 collect in one place'],
#  '67211Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '67219Caes': ['v#01371248 go away from a place'],
#  '67311Caes': ['n#06262813 the country or state or city where you live'],
#  '67317Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '68818Caes': ['n#06082225 a large gathering of people',
#   'n#00004123 a human being'],
#  '68831Caes': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '68853Caes': ['v#01654097 collect in one place'],
#  '69471Caes': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'],
#  '69478Caes': ['v#01371248 go away from a place'],
#  '70231Caes': ['n#06299747 the territory occupied by a nation'],
#  '70242Caes': ['v#01420490 to run away'],
#  '70785Caes': ['n#06299747 the territory occupied by a nation'],
#  '70802Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '71412Caes': ['v#00404522 get to know or become aware of'],
#  '72203Caes': ['n#00004123 a human being'],
#  '72211Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '74027Caes': ['n#06210014 troops trained to fight on horseback',
#   'n#00004123 a human being'],
#  '74074Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '74081Caes': ['v#01401176 go across or through'],
#  '74514Caes': ['n#10851114 some point or period in time'],
#  '74551Caes': ['v#00235191 come to pass; occur'],
#  '74664Caes': ['v#01410345 run or move very quickly or hastily'],
#  '74778Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '74785Caes': ['v#01410345 run or move very quickly or hastily'],
#  '75089Caes': ['n#03601056 weaponry used in fighting or hunting'],
#  '75094Caes': ['v#01383758 move as a crowd or in a group'],
#  '75800Caes': ['n#00004123 a human being'],
#  '75892Caes': ['v#01410345 run or move very quickly or hastily'],
#  '75909Caes': ['n#06141923 a large military unit'],
#  '75926Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '76239Caes': ['n#00004123 a human being'],
#  '76251Caes': ['v#01538749 come upon, as if by accident; meet with'],
#  '76455Caes': ['n#00004123 a human being'],
#  '76475Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '76487Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '77252Caes': ['v#01538749 come upon, as if by accident; meet with'],
#  '77316Caes': ['v#01401176 go across or through'],
#  '77401Caes': ['v#01401176 go across or through'],
#  '77410Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '77440Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '77454Caes': ['v#01360914 move ahead; travel onward'],
#  '77631Caes': ['v#01381620 get or come together'],
#  '77975Caes': ['n#06141923 a large military unit', 'n#00004123 a human being'],
#  '77984Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '78055Caes': ['n#06210014 troops trained to fight on horseback',
#   'n#00004123 a human being'],
#  '78203Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '78212Caes': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '78338Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '78345Caes': ['v#01401176 go across or through'],
#  '78384Caes': ['v#01371248 go away from a place'],
#  '78817Caes': ['n#06141923 a large military unit'],
#  '78841Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '79709Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '79714Caes': ['v#01262658 move toward, travel toward something or somebody or approach something or somebody'],
#  '81246Caes': ['n#00004123 a human being'],
#  '81298Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '81306Caes': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '81803Caes': ['v#01401176 go across or through'],
#  '81823Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '81859Caes': ['v#01262658 move toward, travel toward something or somebody or approach something or somebody'],
#  '81879Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '85691Caes': ['n#07591125 an enlisted man or woman who serves in an army',
#   'n#00004123 a human being'],
#  '85705Caes': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'],
#  '85712Caes': ['v#01376117 move out of; as of a room, a country, a bus, etc.'],
#  '85792Caes': ['v#00471542 reach, make, or come to a decision about something'],
#  '85819Caes': ['n#00105760 the act of making up your mind about something'],
#  '86317Caes': ['n#02741769 a fortified place where troops are stationed'],
#  '86327Caes': ['r#00106274 to or toward that place; away from the speaker'],
#  '86330Caes': ['v#01383758 move as a crowd or in a group'],
#  '87400Caes': ['v#01778989 have a beginning, in a temporal, spatial, or evaluative sense'],
#  '87414Caes': ['n#10946199 the warmest season of the year'],
#  '88754Caes': ['n#10876395 time for Earth to make a complete rotation on its axis'],
#  '88780Caes': ['v#01418612 pass by, as of time'],
#  '89366Caes': ["n#03998008 elevation esp above sea level or the earth's surface"],
#  '89378Caes': ['n#06730976 a long depression in the surface of the land that usually contains a river'],
#  '89385Caes': ['v#01410345 run or move very quickly or hastily'],
#  '90375Caes': ['r#00106274 to or toward that place; away from the speaker'],
#  '90378Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '90646Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '90664Caes': ['n#06370070 a place within a region identified relative to a center or reference location'],
#  '90684Caes': ['v#01410345 run or move very quickly or hastily'],
#  '90900Caes': ['r#00106274 to or toward that place; away from the speaker'],
#  '90903Caes': ['v#01410345 run or move very quickly or hastily'],
#  '91609Caes': ['n#00004123 a human being'],
#  '91676Caes': ['n#00004123 a human being'],
#  '91683Caes': ['v#01410345 run or move very quickly or hastily'],
#  '92258Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '92706Caes': ['v#01562883 find unexpectedly'],
#  '92717Caes': ['n#05437110 an event'],
#  '93136Caes': ['v#01778989 have a beginning, in a temporal, spatial, or evaluative sense'],
#  '93142Caes': ['n#10946591 the coldest season of the year'],
#  '93194Caes': ['n#06080139 the people who inhabit a territory or state'],
#  '93203Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '95973Caes': ['v#00471542 reach, make, or come to a decision about something'],
#  '95980Caes': ['n#00105760 the act of making up your mind about something'],
#  '97029Caes': ['n#00004123 a human being'],
#  '97054Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '97162Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '97169Caes': ['v#01401176 go across or through'],
#  '97562Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '97570Caes': ['n#00004123 a human being'],
#  '97584Caes': ['n#00004123 a human being'],
#  '97613Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '97624Caes': ['v#01654097 collect in one place'],
#  '99409Caes': ['v#01382085 meet'],
#  '100162Caes': ['n#06154325 a group of warships organized as a tactical unit'],
#  '100171Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '102234Caes': ['n#05959071 young people collectively',
#   'n#00004123 a human being'],
#  '102244Caes': ['n#07442529 a man who is old', 'n#00004123 a human being'],
#  '102321Caes': ['r#00106274 to or toward that place; away from the speaker'],
#  '102324Caes': ['v#01654097 collect in one place'],
#  '102801Caes': ['n#06299747 the territory occupied by a nation'],
#  '102818Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '103150Caes': ['n#06082225 a large gathering of people',
#   'n#00004123 a human being'],
#  '103160Caes': ['r#L2533591 from any or all places'],
#  '103209Caes': ['v#01654097 collect in one place'],
#  '104062Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '104069Caes': ['v#01253107 change location; move, travel, or proceed'],
#  '105194Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '106021Caes': ['n#06358701 the extended spatial location of something',
#   'n#06529316 a region of southwestern France between Bordeaux and the Pyrenees'],
#  '106032Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '106316Caes': ['n#00004123 a human being'],
#  '106355Caes': ['v#01420490 to run away'],
#  '108390Caes': ['n#03601056 weaponry used in fighting or hunting'],
#  '108395Caes': ['n#07591125 an enlisted man or woman who serves in an army',
#   'n#00004123 a human being'],
#  '108403Caes': ['v#01383758 move as a crowd or in a group'],
#  '110964Caes': ['v#00765369 lay siege to'],
#  '110983Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '111476Caes': ['n#02715844 walls or mounds used around a stronghold to strengthen it'],
#  '111487Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '111782Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '111957Caes': ['n#06358701 the extended spatial location of something',
#   'n#06529316 a region of southwestern France between Bordeaux and the Pyrenees'],
#  '111967Caes': ['n#06358701 the extended spatial location of something'],
#  '111980Caes': ['v#01654097 collect in one place'],
#  '112865Caes': ['n#04515071 the first part or section of something'],
#  '112893Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '113014Caes': ['n#06684175 a portion of a natural object'],
#  '113030Caes': ['v#01410345 run or move very quickly or hastily'],
#  '114147Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '114154Caes': ['v#01401176 go across or through'],
#  '114211Caes': ['v#01401176 go across or through'],
#  '115923Caes': ['n#00004123 a human being'],
#  '115967Caes': ['v#01262658 move toward, travel toward something or somebody or approach something or somebody'],
#  '117025Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '117032Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '117294Caes': ['v#01401176 go across or through'],
#  '117394Caes': ['v#01401176 go across or through'],
#  '117501Caes': ['n#06348591 an established line of travel or access'],
#  '117506Caes': ['v#01360914 move ahead; travel onward'],
#  '117851Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '117858Caes': ['v#01401176 go across or through'],
#  '118470Caes': ['n#00105760 the act of making up your mind about something'],
#  '118479Caes': ['v#00471542 reach, make, or come to a decision about something'],
#  '118638Caes': ['n#00004123 a human being'],
#  '118658Caes': ['n#00626011 the waging of armed conflict against an enemy'],
#  '118665Caes': ['v#01614361 take action with respect to (someone or something)'],
#  '121643Caes': ['n#00004123 a human being'],
#  '121658Caes': ['v#01382085 meet'],
#  '121689Caes': ['v#01360914 move ahead; travel onward'],
#  '122305Caes': ['v#01654097 collect in one place'],
#  '123522Caes': ['v#01428651 go around the flank of (an opposing army)'],
#  '124891Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '124898Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '125524Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '125531Caes': ['v#01401176 go across or through'],
#  '125754Caes': ['n#06297988 a place where two things come together'],
#  '125781Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '125934Caes': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '126368Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '126380Caes': ['v#01401176 go across or through'],
#  '126589Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '126596Caes': ['v#01401176 go across or through'],
#  '126725Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '126731Caes': ['v#01401176 go across or through'],
#  '127045Caes': ['n#06299747 the territory occupied by a nation',
#   'n#06524425 an ancient region of western Europe that included northern Italy and France and Belgium and part of Germany and the Netherlands'],
#  '127053Caes': ['v#01253107 change location; move, travel, or proceed'],
#  '127792Caes': ['n#06829293 a major European river carrying more traffic than any other river in the world; flows into the North Sea',
#   'n#06789983 a large natural stream of water (larger than a creek)'],
#  '127799Caes': ['v#01401176 go across or through'],
#  '127832Caes': ['v#01401176 go across or through'],
#  '130406Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '130412Caes': ['v#01654097 collect in one place'],
#  '131250Caes': ['n#06741251 a land mass (smaller than a continent) that is surrounded by water'],
#  '131258Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '131407Caes': ['r#00106274 to or toward that place; away from the speaker'],
#  '131412Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '132085Caes': ['r#00105584 to this place (especially toward the speaker)'],
#  '132089Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '132095Caes': ['r#L2533591 from any or all places'],
#  '132116Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '132195Caes': ['v#01654097 collect in one place'],
#  '132754Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '132760Caes': ['n#06299747 the territory occupied by a nation'],
#  '132927Caes': ['n#00004123 a human being'],
#  '132931Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '132936Caes': ['v#01376459 leave a vehicle, aircraft, etc.'],
#  '134354Caes': ['n#06210014 troops trained to fight on horseback',
#   'n#00004123 a human being'],
#  '134379Caes': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '134386Caes': ['v#01360914 move ahead; travel onward'],
#  '134764Caes': ['v#01376459 leave a vehicle, aircraft, etc.'],
#  '134825Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '134831Caes': ['r#00106274 to or toward that place; away from the speaker'],
#  '134834Caes': ['v#01654097 collect in one place'],
#  '135301Caes': ['n#06351684 the precise location of something; a spatially limited location'],
#  '135306Caes': ['v#01360914 move ahead; travel onward'],
#  '135506Caes': ['n#00004123 a human being'],
#  '135514Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '135522Caes': ['v#01376459 leave a vehicle, aircraft, etc.'],
#  '135868Caes': ['n#10650211 a clear colorless odorless tasteless liquid'],
#  '135874Caes': ['v#01360914 move ahead; travel onward'],
#  '136725Caes': ['n#05437110 an event'],
#  '136729Caes': ['n#06141923 a large military unit'],
#  '136747Caes': ['v#00235191 come to pass; occur'],
#  '137335Caes': ['n#03401168 any distinctive flag'],
#  '137342Caes': ['v#01562883 find unexpectedly'],
#  '137464Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '137469Caes': ['v#01376459 leave a vehicle, aircraft, etc.'],
#  '138325Caes': ['n#00004123 a human being'],
#  '138337Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '138342Caes': ['v#01376459 leave a vehicle, aircraft, etc.'],
#  '138922Caes': ['n#07311393 a person who is in charge',
#   'n#00004123 a human being'],
#  '138935Caes': ['r#L2533591 from any or all places'],
#  '138943Caes': ['v#01654097 collect in one place'],
#  '140478Caes': ['n#00004123 a human being'],
#  '140499Caes': ['n#00004123 a human being'],
#  '140508Caes': ['v#01654097 collect in one place'],
#  '140948Caes': ['n#06299747 the territory occupied by a nation'],
#  '140959Caes': ['v#01253107 change location; move, travel, or proceed'],
#  '142066Caes': ['v#00471542 reach, make, or come to a decision about something'],
#  '142073Caes': ['n#00105760 the act of making up your mind about something'],
#  '143334Caes': ['n#03152394 a long (usually round) rod of wood or metal or plastic'],
#  '143342Caes': ['v#01410345 run or move very quickly or hastily'],
#  '144394Caes': ['n#10427326 the condition of being susceptible to harm or injury'],
#  '144404Caes': ['v#00551826 avoid and stay away from deliberately; stay clear of'],
#  '145185Caes': ['n#06401522 the European mainland'],
#  '145197Caes': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '145654Caes': ['n#07391044 an adult male person (as opposed to a woman)',
#   'n#00004123 a human being'],
#  '145680Caes': ['v#01654097 collect in one place'],
#  '432Virg': ['v#01379952 reach a destination, either real or abstract'],
#  '438Virg': ['n#10096231 temporary loss of strength and energy resulting from hard physical or mental work'],
#  '7655Virg': ['r#00105584 to this place (especially toward the speaker)'],
#  '7706Virg': ['v#01376901 to come or go into'],
#  '7737Virg': ['v#01348051 go ashore'],
#  '8862Virg': ['v#01371248 go away from a place'],
#  '11990Virg': ['v#01418612 pass by, as of time'],
#  '12010Virg': ['n#10946591 the coldest season of the year'],
#  '13785Virg': ['v#01376117 move out of; as of a room, a country, a bus, etc.'],
#  '16238Virg': ['v#01654097 collect in one place'],
#  '17473Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '17483Virg': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '18006Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '18012Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '18655Virg': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'],
#  '18671Virg': ['v#01262245 move away from a place into another direction'],
#  '21365Virg': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '21376Virg': ['n#00004123 a human being'],
#  '22171Virg': ['n#07391044 an adult male person (as opposed to a woman)',
#   'n#00004123 a human being'],
#  '22177Virg': ['v#00739748 battle or contend against in or as if in a battle'],
#  '23365Virg': ['v#01376901 to come or go into'],
#  '28246Virg': ['n#00004123 a human being'],
#  '28254Virg': ['v#01737682 help in a difficult situation'],
#  '29795Virg': ['n#06861622 any supernatural being worshipped as controlling some part of the world or some aspect of life or who is the personification of a force'],
#  '29798Virg': ['v#01420490 to run away'],
#  '30509Virg': ['v#01670845 come between so as to be hindrance or obstacle'],
#  '31224Virg': ['n#00004123 a human being'],
#  '31246Virg': ['n#05959071 young people collectively'],
#  '31255Virg': ['v#01654097 collect in one place'],
#  '34874Virg': ['v#01371248 go away from a place'],
#  '35599Virg': ['n#00004123 a human being'],
#  '35620Virg': ['v#01410345 run or move very quickly or hastily'],
#  '35632Virg': ['n#02262475 a stronghold into which people could go for shelter during a battle'],
#  '37459Virg': ['v#01379952 reach a destination, either real or abstract'],
#  '37471Virg': ['n#04128276 the sense organ for hearing and equilibrium'],
#  '37485Virg': ['n#04778525 a language unit by which a person or thing is known'],
#  '41276Virg': ['v#01617829 take upon oneself; act presumptuously, without permission'],
#  '43573Virg': ['v#01737682 help in a difficult situation'],
#  '43967Virg': ['n#03331403 a place of worship hallowed by association with some sacred thing or person'],
#  '43984Virg': ['n#01247280 limbless scaly elongate reptile; some are venomous'],
#  '43993Virg': ['v#01420490 to run away'],
#  '44597Virg': ['n#02202438 a device that very useful for a particular job'],
#  '44602Virg': ['v#01360914 move ahead; travel onward'],
#  '48145Virg': ['v#01410345 run or move very quickly or hastily'],
#  '48159Virg': ['n#02262475 a stronghold into which people could go for shelter during a battle'],
#  '48241Virg': ["v#00490178 come to one's mind; suggest itself"],
#  '49770Virg': ['v#01737682 help in a difficult situation'],
#  '49782Virg': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '50118Virg': ['n#10885886 the time after sunset and before sunrise while it is dark outside'],
#  '50132Virg': ['v#01848681 be around'],
#  '51117Virg': ['n#00004123 a human being'],
#  '51144Virg': ['v#01371248 go away from a place'],
#  '51805Virg': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '52297Virg': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '52346Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '53177Virg': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '54217Virg': ['v#01737682 help in a difficult situation'],
#  '54228Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '54587Virg': ['n#03523510 a structure taller than its diameter; can stand alone or be attached to a larger building'],
#  '54718Virg': ['v#00758805 take the initiative and go on the offensive'],
#  '54911Virg': ['n#00004123 a human being'],
#  '54916Virg': ['v#01262658 move toward, travel toward something or somebody or approach something or somebody'],
#  '56239Virg': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '56245Virg': ['v#01418065 flow or run over (a limit or brim)'],
#  '59141Virg': ["v#00490178 come to one's mind; suggest itself"],
#  '59163Virg': ['n#03685812 the visual appearance of something or someone'],
#  '59228Virg': ["v#00490178 come to one's mind; suggest itself"],
#  '59243Virg': ['n#00004123 a human being'],
#  '59803Virg': ['v#01790203 come into existence or develop'],
#  '59809Virg': ['n#05588321 intense anger (usually on an epic scale)'],
#  '62403Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '62416Virg': ['n#02590878 a horizontal piece of wood or stone that forms the bottom of a doorway and offer support when passing through a doorway'],
#  '62863Virg': ['v#01538749 come upon, as if by accident; meet with'],
#  '64240Virg': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '64250Virg': ['v#01371248 go away from a place'],
#  '65755Virg': ['n#00004123 a human being'],
#  '65760Virg': ['v#00828871 be the support of'],
#  '65994Virg': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '65999Virg': ['v#01376117 move out of; as of a room, a country, a bus, etc.'],
#  '66493Virg': ['v#01363279 to travel behind, go after, come after'],
#  '66499Virg': ["n#07681186 a married woman; a man's partner in marriage",
#   'n#00004123 a human being'],
#  '68857Virg': ['v#00235191 come to pass; occur'],
#  '69554Virg': ['n#04311223 the (prehensile) extremity of the superior limb'],
#  '69560Virg': ['v#01419809 escape, either physically or mentally'],
#  '69568Virg': ['n#03685812 the visual appearance of something or someone'],
#  '69709Virg': ["v#01456625 perceive with any or all of one's senses"],
#  '70805Virg': ['v#00239960 take the first step or steps in carrying out an action'],
#  '71379Virg': ['v#01252435 stop moving or become immobilized'],
#  '71394Virg': ['n#04197156 the fluid (red in vertebrates) that is pumped by the heart'],
#  '71702Virg': ['n#03308216 a long rod or pole (especially the handle of an implement or the body of a weapon like a spear or arrow)'],
#  '71716Virg': ["v#00831185 hold firmly, usually with one's hands"],
#  '73590Virg': ['v#01376459 leave a vehicle, aircraft, etc.'],
#  '73629Virg': ['n#00004123 a human being'],
#  '73713Virg': ['v#01382085 meet'],
#  '73787Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '73793Virg': ['v#01376901 to come or go into'],
#  '80492Virg': ['n#05985893 a group of birds'],
#  '80505Virg': ['n#01661246 animal hunted or caught for food'],
#  '80521Virg': ['v#01322256 travel through the air; be airborne'],
#  '82245Virg': ['v#00551242 stay clear from; keep away from; keep out of the way of someone or something'],
#  '82255Virg': ['n#06700541 a steep rugged rock or cliff'],
#  '83135Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '83144Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '83462Virg': ['v#01360914 move ahead; travel onward'],
#  '83473Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '86027Virg': ['n#07668085 a person with unusual powers of foresight',
#   'n#00004123 a human being'],
#  '86033Virg': ['v#00608070 speak to'],
#  '87458Virg': ['v#01538749 come upon, as if by accident; meet with'],
#  '87470Virg': ['n#08572627 a deciduous tree of the genus Quercus; has acorns and lobed leaves'],
#  '87479Virg': ['n#01893422 an adult female hog'],
#  '87654Virg': ['n#06861200 the ultimate agency that predetermines the course of events (often personified as a woman)'],
#  '87659Virg': ['n#03856995 a manner of performance'],
#  '87664Virg': ['v#01515833 get something or somebody for a specific purpose'],
#  '87711Virg': ['n#06299747 the territory occupied by a nation'],
#  '87741Virg': ['n#06801063 the land along the edge of a body of water (a lake or ocean or river)'],
#  '87795Virg': ['v#00551242 stay clear from; keep away from; keep out of the way of someone or something'],
#  '88191Virg': ['n#06948078 (synecdoche) a part of a person is used to refer to a person',
#   'n#00004123 a human being'],
#  '88198Virg': ['v#00293860 come into sight or view'],
#  '90216Virg': ['v#01371248 go away from a place'],
#  '90398Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '90404Virg': ['n#07506812 a woman prophet', 'n#00004123 a human being'],
#  '92876Virg': ['n#06249735 a connected series of events or actions or developments'],
#  '92904Virg': ['v#01379952 reach a destination, either real or abstract'],
#  '97057Virg': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '104575Virg': ['n#03331403 a place of worship hallowed by association with some sacred thing or person'],
#  '104583Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '106171Virg': ['v#00608070 speak to'],
#  '106182Virg': ['n#06888584 a female deity'],
#  '106190Virg': ['n#06888584 a female deity'],
#  '106849Virg': ['v#00239960 take the first step or steps in carrying out an action'],
#  '106858Virg': ['n#06888584 a female deity'],
#  '107602Virg': ['n#06737795 an underground enclosure with access from the surface of the ground or from the sea'],
#  '107612Virg': ['n#00004123 a human being'],
#  '107617Virg': ['n#07168973 an officer in command of a military unit',
#   'n#00004123 a human being'],
#  '107640Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '108134Virg': ['v#01360914 move ahead; travel onward'],
#  '108884Virg': ['n#01913145 any of numerous agile ruminants related to sheep but having a beard and straight horns'],
#  '108891Virg': ['v#01410345 run or move very quickly or hastily'],
#  '108901Virg': ['n#06726012 a long narrow range of hills'],
#  '109430Virg': ['n#06737795 an underground enclosure with access from the surface of the ground or from the sea'],
#  '109440Virg': ['n#00004123 a human being'],
#  '109445Virg': ['n#07168973 an officer in command of a military unit',
#   'n#00004123 a human being'],
#  '109468Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '109948Virg': ['v#01253107 change location; move, travel, or proceed'],
#  '109962Virg': ["n#06667942 the solid part of the earth's surface"],
#  '113059Virg': ['v#01322256 travel through the air; be airborne'],
#  '113066Virg': ['n#06749470 a visible mass of water or ice particles suspended at a considerable altitude'],
#  '114612Virg': ['v#01371248 go away from a place'],
#  '116491Virg': ['n#06761922 any celestial body visible (as a point of light) from the Earth at night'],
#  '116498Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '123434Virg': ['v#00608070 speak to'],
#  '123443Virg': ['n#07579801 a female person who has the same parents as another person',
#   'n#00004123 a human being'],
#  '124351Virg': ['r#L1557107 in what place'],
#  '124355Virg': ['v#00938146 ruin completely'],
#  '133403Virg': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '133555Virg': ['n#06888584 a female deity'],
#  '133572Virg': ['n#06749007 outer space as viewed from the earth'],
#  '133638Virg': ['v#01296593 move along rapidly and lightly; skim or dart'],
#  '134189Virg': ['v#00293860 come into sight or view'],
#  '134198Virg': ["n#06667942 the solid part of the earth's surface"],
#  '135444Virg': ['v#00320978 act or move at high speed'],
#  '135453Virg': ['n#00004123 a human being'],
#  '138905Virg': ['v#00733885 become a participant; be involved in'],
#  '138921Virg': ['n#00757193 a struggle between rivals'],
#  '140556Virg': ['v#01410345 run or move very quickly or hastily'],
#  '140625Virg': ['n#00004123 a human being'],
#  '141068Virg': ['r#00490593 to what place, purpose, or end'],
#  '141091Virg': ['v#01253107 change location; move, travel, or proceed'],
#  '141260Virg': ['r#00490593 to what place, purpose, or end'],
#  '141273Virg': ['v#01253107 change location; move, travel, or proceed'],
#  '141726Virg': ['n#02814667 a mechanical device by which a vessel is steered'],
#  '141744Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '142211Virg': ['v#01364150 move ahead (of others) in time or space'],
#  '142221Virg': ['n#02840815 the frame or body of ship'],
#  '142979Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '142989Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '143021Virg': ['n#06740258 a submerged ridge of rock or coral near the surface of the water'],
#  '143030Virg': ['v#01853436 jut out or project in space'],
#  '143283Virg': ['n#00004123 a human being'],
#  '143378Virg': ['n#06781925 a division of an ocean or a large body of salt water partially enclosed by land'],
#  '143385Virg': ['v#01261115 travel by ship on (a body of water)'],
#  '146147Virg': ['n#01247280 limbless scaly elongate reptile; some are venomous'],
#  '146166Virg': ['v#00072443 injure or kill by running over, as with a car'],
#  '146482Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '146488Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '146993Virg': ['r#L2533591 from any or all places'],
#  '147001Virg': ['v#01654097 collect in one place'],
#  '147509Virg': ['n#00004123 a human being'],
#  '147545Virg': ['v#01371248 go away from a place'],
#  '147939Virg': ['v#01262245 move away from a place into another direction'],
#  '148092Virg': ['v#01371248 go away from a place'],
#  '148425Virg': ['v#01400792 travel past, as of a vehicle'],
#  '149011Virg': ['n#00004123 a human being'],
#  '149019Virg': ['v#01363279 to travel behind, go after, come after'],
#  '149322Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '149329Virg': ['n#08882567 any plant of the family Palmae'],
#  '150806Virg': ['v#00732096 oppose in hostility'],
#  '150812Virg': ['n#07567074 someone who serves in the armed forces',
#   'n#00004123 a human being'],
#  '153491Virg': ['n#00004123 a human being'],
#  '153531Virg': ['n#00760227 a powerful stroke with the fist or a weapon'],
#  '153567Virg': ['v#01437046 make a sudden movement in a new direction (as to evade a blow)'],
#  '154152Virg': ['v#01410345 run or move very quickly or hastily'],
#  '154161Virg': ['n#00004123 a human being'],
#  '155882Virg': ['v#01654097 collect in one place'],
#  '155892Virg': ['n#07391044 an adult male person (as opposed to a woman)',
#   'n#00004123 a human being'],
#  '155986Virg': ['v#01790544 happen or occur as a result of something'],
#  '155991Virg': ['n#00290820 the activity of doing something in an agreed succession'],
#  '157538Virg': ['n#06749007 outer space as viewed from the earth'],
#  '157561Virg': ['v#00320978 act or move at high speed'],
#  '157593Virg': ['n#06762045 (astronomy) a celestial body of hot gases that radiates energy derived from thermonuclear reactions in the interior'],
#  '158232Virg': ["v#01299603 use one's feet to advance; advance by steps"],
#  '159975Virg': ['v#00239960 take the first step or steps in carrying out an action'],
#  '159982Virg': ['n#0547949 a movement in a new direction'],
#  '161107Virg': ['n#06888584 a female deity'],
#  '161170Virg': ['v#01410345 run or move very quickly or hastily'],
#  '171786Virg': ['n#00461778 a specific piece of work required to be done as a duty or for a specific fee'],
#  '171793Virg': ['v#01658906 be in charge of, act on, or dispose of'],
#  '172573Virg': ['n#06700314 a steep high face of rock'],
#  '172598Virg': ['v#01262658 move toward, travel toward something or somebody or approach something or somebody'],
#  '173466Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '173482Virg': ['n#06242210 a small growth of trees without underbrush'],
#  '173500Virg': ['n#03483734 an edifice for the worship of a deity'],
#  '173507Virg': ['n#00004123 a human being'],
#  '173621Virg': ['v#01322256 travel through the air; be airborne'],
#  '175538Virg': ['v#01832678 to extend as far as'],
#  '175547Virg': ["n#06667942 the solid part of the earth's surface"],
#  '178074Virg': ['n#10019436 a region marking a boundary'],
#  '178081Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '178822Virg': ['n#06787575 a body of (usually fresh) water surrounded by land'],
#  '178845Virg': ['v#01006503 extend on all sides of simultaneously; encircle'],
#  '178923Virg': ['v#01261115 travel by ship on (a body of water)'],
#  '178930Virg': ['n#06787575 a body of (usually fresh) water surrounded by land'],
#  '179209Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '179216Virg': ['v#01356484 go under'],
#  '179898Virg': ['n#00004123 a human being'],
#  '179933Virg': ["v#01299603 use one's feet to advance; advance by steps"],
#  '180387Virg': ['n#00610417 a hostile meeting of opposing military forces in the course of a war'],
#  '180403Virg': ['v#00733885 become a participant; be involved in'],
#  '189487Virg': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '189518Virg': ['v#01261115 travel by ship on (a body of water)'],
# ...
#  '312935Virg': ['v#01410345 run or move very quickly or hastily'],
#  '313361Virg': ['n#04302029 the front part of the trunk from the neck to the abdomen'],
#  '313368Virg': ['v#01253107 change location; move, travel, or proceed'],
#  '314279Virg': ['r#L2533591 from any or all places'],
#  '314287Virg': ['v#01654097 collect in one place'],
#  '315131Virg': ['r#00041436 (archaic) from this place'],
#  '315136Virg': ['v#01376117 move out of; as of a room, a country, a bus, etc.'],
#  '315248Virg': ['v#01538749 come upon, as if by accident; meet with'],
#  '315273Virg': ['n#00004123 a human being'],
#  '315460Virg': ['n#03601056 weaponry used in fighting or hunting'],
#  '315495Virg': ['v#00551242 stay clear from; keep away from; keep out of the way of someone or something'],
#  '315921Virg': ['n#07665765 a combatant who is able to defeat rivals',
#   'n#00004123 a human being'],
#  '315933Virg': ['n#04492484 the content of cognition; the main thing you are thinking about'],
#  '315938Virg': ["v#00490178 come to one's mind; suggest itself"],
#  '316814Virg': ['n#07168973 an officer in command of a military unit'],
#  '316843Virg': ['v#01654097 collect in one place'],
#  '317846Virg': ['n#06089493 an organization of military land forces',
#   'n#00004123 a human being'],
#  '317854Virg': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '317870Virg': ['v#01654097 collect in one place'],
#  '317884Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '318972Virg': ['n#06299747 the territory occupied by a nation',
#   'n#06459750 a republic in S Europe; was the core of the Roman Republic and the Roman Empire between the 4th century BC and the 5th century AD'],
#  '318980Virg': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '318991Virg': ['n#00004123 a human being'],
#  '319097Virg': ['v#00236668 come to pass; arrive, as in due course'],
#  '319135Virg': ['n#10851114 some point or period in time'],
#  '323687Virg': ['n#06861200 the ultimate agency that predetermines the course of events (often personified as a woman)'],
#  '323692Virg': ['n#03856995 a manner of performance'],
#  '323697Virg': ['v#01515833 get something or somebody for a specific purpose'],
#  '325242Virg': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '325250Virg': ['v#01376901 to come or go into'],
#  '325269Virg': ['n#07354565 a male sovereign; ruler of a kingdom',
#   'n#00004123 a human being'],
#  '325275Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '328421Virg': ['n#06117068 an unofficial association of people or groups',
#   'n#00004123 a human being'],
#  '328440Virg': ['v#01382085 meet'],
#  '328458Virg': ['n#06897921 (classical mythology) a minor nature goddess usually depicted as a beautiful maiden'],
#  '328539Virg': ['v#01335172 travel through water'],
#  '330507Virg': ['n#01524724 large long-necked wading bird of marshes and plains in many parts of the world'],
#  '330519Virg': ['n#06749007 outer space as viewed from the earth'],
#  '330527Virg': ['v#01322256 travel through the air; be airborne'],
#  '331278Virg': ['v#01410345 run or move very quickly or hastily'],
#  '331292Virg': ['n#05472145 waves breaking on the shore'],
#  '331311Virg': ['v#01376459 leave a vehicle, aircraft, etc.'],
#  '333747Virg': ['n#00004123 a human being'],
#  '333759Virg': ['v#01737682 help in a difficult situation'],
#  '333765Virg': ['n#00004123 a human being'],
#  '334097Virg': ['n#00004123 a human being'],
#  '334105Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '334418Virg': ['v#01410345 run or move very quickly or hastily'],
#  '334427Virg': ['n#00004123 a human being'],
#  '334455Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '334490Virg': ['n#00004123 a human being'],
#  '334767Virg': ['n#06237025 a row or line of people (especially soldiers or police) standing abreast of one another',
#   'n#00004123 a human being'],
#  '334790Virg': ['v#01075789 crash together with violent impact'],
#  '335250Virg': ['n#05583906 a specific instance of feeling hopeful'],
#  '335260Virg': ['v#01790203 come into existence or develop'],
#  '337031Virg': ['n#03805961 a quality of spirit that enables you to face danger of pain without showing fear'],
#  '337038Virg': ['v#00946962 gather or bring together'],
#  '337052Virg': ['n#10044643 a specific identifiable position in a continuum or series or especially in a process'],
#  '337945Virg': ['n#06237025 a row or line of people (especially soldiers or police) standing abreast of one another',
#   'n#00004123 a human being'],
#  '337952Virg': ['v#01075789 crash together with violent impact'],
#  '338192Virg': ['n#00004123 a human being'],
#  '338198Virg': ['v#00739748 battle or contend against in or as if in a battle'],
#  '338908Virg': ['v#01252435 stop moving or become immobilized'],
#  '338916Virg': ['n#04112790 internal organs collectively (especially those in the abdominal cavity)'],
#  '338927Virg': ['n#04197156 the fluid (red in vertebrates) that is pumped by the heart'],
#  '338995Virg': ['n#01637880 large gregarious predatory feline of Africa and India having a tawny coat with a shaggy mane in the male'],
#  '339076Virg': ['v#01410345 run or move very quickly or hastily'],
#  '339296Virg': ['n#05621336 food or meals in general'],
#  '339308Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '339819Virg': ['n#10966461 the point in time at which something ends'],
#  '339833Virg': ['v#00378868 reach a state, relation, or condition'],
#  '340292Virg': ['n#03316835 armor carried on the arm to intercept blows'],
#  '340297Virg': ['n#10580335 the dressed skin of an animal (especially a large animal)'],
#  '340312Virg': ['v#00822267 form a cover over'],
#  '341523Virg': ['n#07406477 a person who carries a message',
#   'n#00004123 a human being'],
#  '341530Virg': ['v#01410345 run or move very quickly or hastily'],
#  '341538Virg': ['n#00004123 a human being'],
#  '341593Virg': ['v#01737682 help in a difficult situation'],
#  '341604Virg': ['n#00004123 a human being'],
#  '341782Virg': ['n#05621336 food or meals in general'],
#  '341806Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '342032Virg': ['n#00004123 a human being'],
#  '342042Virg': ['v#01411906 crouch or curl up'],
#  '342842Virg': ['v#01382085 meet'],
#  '344986Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '344992Virg': ['n#10018250 the shape of a raised edge of a more or less circular object'],
#  '344997Virg': ['n#03378030 a long pointed rod used as a weapon'],
#  '346282Virg': ['v#00250254 pass from physical life and lose all all bodily attributes and functions necessary to sustain life'],
#  '348655Virg': ['r#00041981 from what place or origin or source'],
#  '348660Virg': ['v#01371248 go away from a place'],
#  '349601Virg': ['v#01410345 run or move very quickly or hastily'],
#  '349622Virg': ['n#06237025 a row or line of people (especially soldiers or police) standing abreast of one another',
#   'n#00004123 a human being'],
#  '350829Virg': ['v#00739748 battle or contend against in or as if in a battle'],
#  '351569Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '352855Virg': ['n#00004123 a human being'],
#  '352881Virg': ["v#01299603 use one's feet to advance; advance by steps"],
#  '352892Virg': ['n#06727012 extensive tract of level open land'],
#  '353048Virg': ['v#01253107 change location; move, travel, or proceed'],
#  '353062Virg': ["n#06667942 the solid part of the earth's surface"],
#  '353854Virg': ['n#02913016 a single thickness of usually some homogeneous substance'],
#  '353870Virg': ['v#00988556 penetrate or cut through with a sharp instrument'],
#  '354451Virg': ['v#01340005 move upward'],
#  '354530Virg': ['n#07258194 a male parent (also used as a term of address to your father)',
#   'n#00004123 a human being'],
#  '354559Virg': ['v#01371248 go away from a place'],
#  '355579Virg': ['n#04351370 knowledge and intellectual ability'],
#  '355594Virg': ["v#00490178 come to one's mind; suggest itself"],
#  '355610Virg': ['n#03685812 the visual appearance of something or someone'],
#  '357186Virg': ['n#00626011 the waging of armed conflict against an enemy'],
#  '357204Virg': ['v#00297068 become known or apparent'],
#  '357988Virg': ['v#01262658 move toward, travel toward something or somebody or approach something or somebody'],
#  '358823Virg': ['v#01410345 run or move very quickly or hastily'],
#  '358831Virg': ['n#00004123 a human being'],
#  '364581Virg': ['n#00004123 a human being'],
#  '364594Virg': ['v#00739748 battle or contend against in or as if in a battle'],
#  '367798Virg': ['v#01410345 run or move very quickly or hastily'],
#  '367808Virg': ['n#05971194 wood heaped for burning a dead body as a funeral rite'],
#  '370405Virg': ['v#01376901 to come or go into'],
#  '372423Virg': ['n#03601056 weaponry used in fighting or hunting'],
#  '372429Virg': ['v#01075789 crash together with violent impact'],
#  '372440Virg': ['n#03601056 weaponry used in fighting or hunting'],
#  '374306Virg': ['n#10035141 the general state of things; the combination of circumstances at a given time'],
#  '374312Virg': ['v#01737682 help in a difficult situation'],
#  '375726Virg': ['v#01371248 go away from a place'],
#  '381217Virg': ['v#01410345 run or move very quickly or hastily'],
#  '381234Virg': ['n#02262475 a stronghold into which people could go for shelter during a battle'],
#  '381588Virg': ['n#00004123 a human being'],
#  '381596Virg': ['v#00320978 act or move at high speed'],
#  '381797Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '381807Virg': ['n#06210014 troops trained to fight on horseback',
#   'n#00004123 a human being'],
#  '382911Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '382921Virg': ['n#00610417 a hostile meeting of opposing military forces in the course of a war'],
#  '383814Virg': ['v#01335172 travel through water'],
#  '386460Virg': ['v#01360914 move ahead; travel onward'],
#  '386637Virg': ['n#00004123 a human being'],
#  '386655Virg': ['n#00004123 a human being'],
#  '386671Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '387178Virg': ['v#01340005 move upward'],
#  '387197Virg': ['n#06781925 a division of an ocean or a large body of salt water partially enclosed by land'],
#  '387496Virg': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '387738Virg': ['n#00004123 a human being'],
#  '387753Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '389348Virg': ['v#01737682 help in a difficult situation'],
#  '390022Virg': ['v#00236668 come to pass; arrive, as in due course'],
#  '390041Virg': ['n#10878282 a day assigned to a particular purpose or observance'],
#  '390807Virg': ['v#00239960 take the first step or steps in carrying out an action'],
#  '391430Virg': ['n#07387754 an unmarried girl (especially a virgin)',
#   'n#00004123 a human being'],
#  '391464Virg': ['v#01400792 travel past, as of a vehicle'],
#  '391472Virg': ['n#01875414 solid-hoofed herbivorous quadruped domesticated since prehistoric times'],
#  '391512Virg': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '392942Virg': ['n#00619852 an act of aggression (as one against a person who resists)'],
#  '392954Virg': ['v#00551242 stay clear from; keep away from; keep out of the way of someone or something'],
#  '393332Virg': ['n#00004123 a human being'],
#  '393342Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '393371Virg': ['n#00004123 a human being'],
#  '393413Virg': ['n#00004123 a human being'],
#  '393422Virg': ['v#01253107 change location; move, travel, or proceed'],
#  '393517Virg': ['r#00105416 in or at this place; where the speaker or writer is'],
#  '393528Virg': ['v#01358798 advance stealthily or unnoticed'],
#  '395407Virg': ['v#01410345 run or move very quickly or hastily'],
#  '395427Virg': ['n#07172243 a person who is frequently in the company of another',
#   'n#00004123 a human being'],
#  '395494Virg': ['n#00004123 a human being'],
#  '395561Virg': ['n#00760227 a powerful stroke with the fist or a weapon'],
#  '395567Virg': ['v#01410345 run or move very quickly or hastily'],
#  '396317Virg': ['v#01420490 to run away'],
#  '396723Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '397667Virg': ['v#01253107 change location; move, travel, or proceed'],
#  '397899Virg': ['v#01381620 get or come together'],
#  '397916Virg': ['n#06314878 either extremity of something that has length'],
#  '398815Virg': ['v#00550636 fail to experience'],
#  '398825Virg': ['n#07788946 the permanent end of all life functions in an organism or part of an organism'],
#  '399820Virg': ['v#01376117 move out of; as of a room, a country, a bus, etc.'],
#  '399857Virg': ['n#00004123 a human being'],
#  '399864Virg': ['n#06727012 extensive tract of level open land'],
#  '399871Virg': ['v#01376901 to come or go into'],
#  '400199Virg': ['v#00733885 become a participant; be involved in'],
#  '400206Virg': ['n#00610417 a hostile meeting of opposing military forces in the course of a war'],
#  '400912Virg': ['v#00738369 be engaged in a fight; carry on a fight'],
#  '404152Virg': ['n#10794215 a layer of snowflakes (white crystals of frozen water) covering the ground'],
#  '404158Virg': ['v#00748500 be or do something to a greater degree'],
#  '407030Virg': ['n#07692038 a young person (especially a young man or boy)',
#   'n#00004123 a human being'],
#  '407054Virg': ['v#00739748 battle or contend against in or as if in a battle'],
#  '407065Virg': ['n#05462231 an event (or course of events) that will inevitably happen in the future'],
#  '408595Virg': ['v#00471542 reach, make, or come to a decision about something'],
#  '410205Virg': ['v#01360914 move ahead; travel onward'],
#  '410260Virg': ['n#00004123 a human being'],
#  '412317Virg': ['v#01410345 run or move very quickly or hastily'],
#  '412904Virg': ['n#00004123 a human being'],
#  '412909Virg': ['n#06237025 a row or line of people (especially soldiers or police) standing abreast of one another',
#   'n#00004123 a human being'],
#  '412923Virg': ['v#00760988 to make a rush at or sudden attack upon, as in battle'],
#  '413525Virg': ['v#01410345 run or move very quickly or hastily'],
#  '413539Virg': ['n#00004123 a human being'],
#  '413679Virg': ['v#01654097 collect in one place'],
#  '413690Virg': ['n#00004123 a human being'],
#  '414488Virg': ['v#00739748 battle or contend against in or as if in a battle'],
#  '416037Virg': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '416065Virg': ['v#01368651 reach a destination; arrive by movement or by making progress'],
#  '418549Virg': ['n#06861622 any supernatural being worshipped as controlling some part of the world or some aspect of life or who is the personification of a force'],
#  '418556Virg': ['v#01737682 help in a difficult situation'],
#  '418671Virg': ['v#01262658 move toward, travel toward something or somebody or approach something or somebody'],
#  '419507Virg': ['n#03495843 an entity that is not named specifically'],
#  '419546Virg': ['v#01790203 come into existence or develop'],
#  '421254Virg': ['v#01381620 get or come together'],
#  '421500Virg': ['n#00004123 a human being'],
#  '421505Virg': ['v#01639012 take the place of'],
#  '421637Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '421643Virg': ['v#01322256 travel through the air; be airborne'],
#  '421681Virg': ['n#01116731 small long-winged songbird noted for swift graceful flight and the regularity of its migrations'],
#  '421860Virg': ['v#01304824 travel across or pass over'],
#  '421865Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '422984Virg': ['v#00739748 battle or contend against in or as if in a battle'],
#  '423019Virg': ['n#06069040 the body of citizens of a state or country',
#   'n#00004123 a human being'],
#  ...}

# %% [markdown]
# #### Creating DataFrame for Token Synsets

# %%
synsets_df = pd.DataFrame([(k,v) for k,v in pred2_synset.items()], columns=["ID", "VERB SEMANTICS"]) #where 'synsets_df' is a dataframe containing token IDs and synsets of all the tokens (verbs and nouns) annotated with a synset
synsets_df
# Out:
#               ID                                     VERB SEMANTICS
# 0       1466Caes    [n#06299747 the territory occupied by a nation]
# 1       1498Caes  [v#01376117 move out of; as of a room, a count...
# 2       4283Caes    [n#06299747 the territory occupied by a nation]
# 3       4296Caes  [v#01376117 move out of; as of a room, a count...
# 4       4569Caes                    [n#10428324 a source of danger]
# ...          ...                                                ...
# 1025  438653Virg   [v#01410345 run or move very quickly or hastily]
# 1026  440708Virg  [n#06669293 a lump of hard consolidated minera...
# 1027  440736Virg  [v#01343923 raise from a lower to a higher pos...
# 1028  441937Virg  [v#00988556 penetrate or cut through with a sh...
# 1029  441945Virg  [n#04309035 the part of the leg between the hi...
#
# [1030 rows x 2 columns]

# %% [markdown]
# #### Merging Preverb Semantics with Synsets DataFrames

# %%
id_synsets_df = id_preverb_semantics_df.merge(synsets_df, on='ID', how='left') #where 'id_synsets_df' merges 'id_preverb_semantics_df' and 'synsets_df', basically adding the synset to the other verb parameters contained in 'id_preverb_semantics_df'
id_synsets_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY  \
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
#             VERB CLASS  LITERAL MEANING     VERB STEM PREVERB  \
# 0          ESCAPE-51.1             True  present stem      ex
# 1          ESCAPE-51.1             True  present stem      ex
# 2          MARVEL-31.3            False  present stem     sub
# 3          ESCAPE-51.1             True  perfect stem   trans
# 4          ESCAPE-51.1             True  present stem      ex
# ..                 ...              ...           ...     ...
# 499         RUN-51.3.2             True  present stem     pro
# 500          HELP-72.1            False  present stem     sub
# 501         RUN-51.3.2            False  present stem      ob
# 502  PUT_DIRECTION-9.4            False  present stem     sub
# 503        ESCAPE-51.1             True  present stem   trans
#
#     PREVERB SEMANTICS                                     VERB SEMANTICS
# 0                 out  [v#01376117 move out of; as of a room, a count...
# 1                 out  [v#01376117 move out of; as of a room, a count...
# 2               under                     [v#01444459 undergo or suffer]
# 3              across  [v#01253107 change location; move, travel, or ...
# 4                 out                  [v#01371248 go away from a place]
# ..                ...                                                ...
# 499           forward   [v#01410345 run or move very quickly or hastily]
# 500             under         [v#01737682 help in a difficult situation]
# 501                to   [v#01410345 run or move very quickly or hastily]
# 502             under  [v#01343923 raise from a lower to a higher pos...
# 503            across  [v#00988556 penetrate or cut through with a sh...
#
# [504 rows x 12 columns]

# %% [markdown]
# ## Figure

# %% [markdown]
# #### Extracting and Storing Figure Synsets

# %%
list_figure_synsets = []  # Initializing an empty list to store figure synsets
tok2_figure_synsets = dict()  # Initializing an empty dictionary to store predicted figure synsets mapped to IDs
count= 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping fthrough each 'Figuresynset' annotation in the CAS
    for relation in cas.select('webanno.custom.Figuresynset'):
        # Looping through each token covered by the 'Figuresynset' annotation
        for token in cas.select_covered('webanno.custom.Figuresynset', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            figure_synset = relation.FigSyn  # Getting the figure synset value
            
            # Checking if the ID already exists in tok2_figure_synsets dictionary
            if id in tok2_figure_synsets:
                # If ID exists, append the new figure synset to the existing list of figure synsets
                list_figure_synsets = tok2_figure_synsets[id] + figure_synset
                tok2_figure_synsets[id] = list_figure_synsets
            else:
                # If ID doesn't exist, store the figure synset directly
                tok2_figure_synsets[id] = figure_synset 

print(tok2_figure_synsets)
# Out:
# {'1498Caes': uima_cas_StringArray(xmiID=None, elements=['n#06080139 the people who inhabit a territory or state'], type=Type(name=uima.cas.StringArray)), '4296Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '4578Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '4854Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '4978Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '5366Caes': uima_cas_StringArray(xmiID=None, elements=['n#06789983 a large natural stream of water (larger than a creek)'], type=Type(name=uima.cas.StringArray)), '5732Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '5997Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '6831Caes': uima_cas_StringArray(xmiID=None, elements=['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '7012Caes': uima_cas_StringArray(xmiID=None, elements=['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '7293Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '8498Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '9426Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '9649Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '10407Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '10617Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '10862Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '10890Caes': uima_cas_StringArray(xmiID=None, elements=['n#06095787 an army unit large enough to sustain combat', 'n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '10931Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '11152Caes': uima_cas_StringArray(xmiID=None, elements=['n#06296283 a small administrative division of a country'], type=Type(name=uima.cas.StringArray)), '11818Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '12323Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '21567Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '24504Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '24513Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '25610Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '26036Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '26225Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '26268Caes': uima_cas_StringArray(xmiID=None, elements=['n#07583414 a person who is owned by someone', 'n#00004123 a human being'], type=Type(name=uima.cas.StringArray)), '26640Caes': uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type ...

# %% [markdown]
# #### Extracting and Cleaning Figure Synsets

# %%
list2_figure_synsets = []  # Initializing an empty list to store figure synsets
count= 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Figuresynset' annotation in the CAS
    for relation in cas.select('webanno.custom.Figuresynset'):
        figure_synset = relation.FigSyn  # Getting the figure synset value
        list2_figure_synsets.append(str(figure_synset))  # Appending the figure synset to the list

# Removing unwanted characters from each element in list2_figure_synsets
list2_figure_synsets = [s.replace('u.c.StringArray(elements=', '') for s in list2_figure_synsets]

print(list2_figure_synsets)
# Out:
# ["['n#06080139 the people who inhabit a territory or state'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06789983 a large natural stream of water (larger than a creek)'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being'])", "['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06095787 an army unit large enough to sustain combat', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06296283 a small administrative division of a country'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#07583414 a person who is owned by someone', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06259974 a select company of people'])", "['n#07211391 a person appointed to represent or act on behalf of others', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['NA'])", "['n#00004123 a human being'])", "['*clause*'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06089493 an organization of military land forces', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#07242378 an armed adversary (especially a member of an opposing military force)', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#02304226 a small vessel for travel on water'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#10946199 the warmest season of the year'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06069615 assembly possessing high legislative powers', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#07242378 an armed adversary (especially a member of an opposing military force)', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06210014 troops trained to fight on horseback', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06082225 a large gathering of people', 'n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#06210014 troops trained to fight on horseback', 'n#00004123 a human being'])", "['n#10851114 some point or period in time'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['NA'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'])", "['n#00004123 a human being'
['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being']",
#  '7012Caes': "['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being']",
#  '7293Caes': "['n#00004123 a human being']",
#  '8498Caes': "['n#00004123 a human being']",
#  '9426Caes': "['n#00004123 a human being']",
#  '9649Caes': "['n#00004123 a human being']",
#  '10407Caes': "['n#00004123 a human being']",
#  '10617Caes': "['n#00004123 a human being']",
#  '10862Caes': "['n#00004123 a human being']",
#  '10890Caes': "['n#06095787 an army unit large enough to sustain combat', 'n#00004123 a human being']",
#  '10931Caes': "['n#00004123 a human being']",
#  '11152Caes': "['n#06296283 a small administrative division of a country']",
#  '11818Caes': "['n#00004123 a human being']",
#  '12323Caes': "['n#00004123 a human being']",
#  '21567Caes': "['n#00004123 a human being']",
#  '24504Caes': "['n#00004123 a human being']",
#  '24513Caes': "['n#00004123 a human being']",
#  '25610Caes': "['n#00004123 a human being']",
#  '26036Caes': "['n#00004123 a human being']",
#  '26225Caes': "['n#00004123 a human being']",
#  '26268Caes': "['n#07583414 a person who is owned by someone', 'n#00004123 a human being']",
#  '26640Caes': "['n#00004123 a human being']",
#  '27386Caes': "['n#00004123 a human being']",
#  '27831Caes': "['n#06259974 a select company of people']",
#  '28359Caes': "['n#07211391 a person appointed to represent or act on behalf of others', 'n#00004123 a human being']",
#  '29918Caes': "['n#00004123 a human being']",
#  '30767Caes': "['n#00004123 a human being']",
#  '31365Caes': "['n#00004123 a human being']",
#  '33967Caes': "['n#00004123 a human being']",
#  '34210Caes': "['n#00004123 a human being']",
#  '34348Caes': "['NA']",
#  '36546Caes': "['n#00004123 a human being']",
#  '36804Caes': "['*clause*']",
#  '37047Caes': "['n#00004123 a human being']",
#  '37157Caes': "['n#00004123 a human being']",
#  '37517Caes': "['n#00004123 a human being']",
#  '38986Caes': "['n#00004123 a human being']",
#  '41443Caes': "['n#00004123 a human being']",
#  '46744Caes': "['n#00004123 a human being']",
#  '46852Caes': "['n#00004123 a human being']",
#  '48088Caes': "['n#06089493 an organization of military land forces', 'n#00004123 a human being']",
#  '50312Caes': "['n#00004123 a human being']",
#  '52574Caes': "['n#00004123 a human being']",
#  '53622Caes': "['n#00004123 a human being']",
#  '56162Caes': "['n#07242378 an armed adversary (especially a member of an opposing military force', 'n#00004123 a human being']",
#  '56208Caes': "['n#00004123 a human being']",
#  '56243Caes': "['n#02304226 a small vessel for travel on water']",
#  '56345Caes': "['n#00004123 a human being']",
#  '56583Caes': "['n#00004123 a human being']",
#  '58654Caes': "['n#10946199 the warmest season of the year']",
#  '59161Caes': "['n#00004123 a human being']",
#  '60301Caes': "['n#00004123 a human being']",
#  '61670Caes': "['n#06069615 assembly possessing high legislative powers', 'n#00004123 a human being']",
#  '63933Caes': "['n#00004123 a human being']",
#  '64997Caes': "['n#07242378 an armed adversary (especially a member of an opposing military force', 'n#00004123 a human being']",
#  '65326Caes': "['n#00004123 a human being']",
#  '65391Caes': "['n#00004123 a human being']",
#  '65423Caes': "['n#00004123 a human being']",
#  '65528Caes': "['n#00004123 a human being']",
#  '66243Caes': "['n#00004123 a human being']",
#  '66324Caes': "['n#00004123 a human being']",
#  '66389Caes': "['n#00004123 a human being']",
#  '66411Caes': "['n#06210014 troops trained to fight on horseback', 'n#00004123 a human being']",
#  '66489Caes': "['n#00004123 a human being']",
#  '66567Caes': "['n#00004123 a human being']",
#  '66805Caes': "['n#00004123 a human being']",
#  '67219Caes': "['n#00004123 a human being']",
#  '67317Caes': "['n#00004123 a human being']",
#  '68853Caes': "['n#06082225 a large gathering of people', 'n#00004123 a human being']",
#  '69478Caes': "['n#00004123 a human being']",
#  '70242Caes': "['n#00004123 a human being']",
#  '70802Caes': "['n#00004123 a human being']",
#  '71412Caes': "['n#00004123 a human being']",
#  '72211Caes': "['n#00004123 a human being']",
#  '74081Caes': "['n#06210014 troops trained to fight on horseback', 'n#00004123 a human being']",
#  '74551Caes': "['n#10851114 some point or period in time']",
#  '74664Caes': "['n#00004123 a human being']",
#  '74785Caes': "['n#00004123 a human being']",
#  '75094Caes': "['NA']",
#  '75892Caes': "['n#00004123 a human being']",
#  '75926Caes': "['n#00004123 a human being']",
#  '76251Caes': "['n#00004123 a human being']",
#  '76487Caes': "['n#00004123 a human being']",
#  '77252Caes': "['n#00004123 a human being']",
#  '77316Caes': "['n#00004123 a human being']",
#  '77401Caes': "['n#00004123 a human being']",
#  '77454Caes': "['n#00004123 a human being']",
#  '77631Caes': "['n#00004123 a human being']",
#  '77984Caes': "['n#00004123 a human being']",
#  '78212Caes': "['n#06210014 troops trained to fight on horseback', 'n#00004123 a human being']",
#  '78345Caes': "['n#00004123 a human being']",
#  '78384Caes': "['n#00004123 a human being']",
#  '78841Caes': "['n#00004123 a human being']",
#  '79714Caes': "['n#00004123 a human being']",
#  '81306Caes': "['n#00004123 a human being']",
#  '81803Caes': "['n#00004123 a human being']",
#  '81859Caes': "['n#00004123 a human being']",
#  '85712Caes': "['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being']",
#  '85792Caes': "['n#00105760 the act of making up your mind about something']",
#  '86330Caes': "['NA']",
#  '87400Caes': "['n#10946199 the warmest season of the year']",
#  '88780Caes': "['n#10876395 time for Earth to make a complete rotation on its axis']",
#  '89385Caes': "['n#00004123 a human being']",
#  '90378Caes': "['n#00004123 a human being']",
#  '90684Caes': "['n#07242378 an armed adversary (especially a member of an opposing military force', 'n#00004123 a human being']",
#  '90903Caes': "['n#00004123 a human being']",
#  '91683Caes': "['n#00004123 a human being']",
#  '92258Caes': "['n#00004123 a human being']",
#  '92706Caes': "['n#00004123 a human being']",
#  '93136Caes': "['n#10946591 the coldest season of the year']",
#  '93203Caes': "['n#00004123 a human being']",
#  '95973Caes': "['n#00105760 the act of making up your mind about something']",
#  '97054Caes': "['n#00004123 a human being']",
#  '97169Caes': "['n#00004123 a human being']",
#  '97624Caes': "['n#03318070 a vessel that carries passengers or freight']",
#  '99409Caes': "['n#00004123 a human being']",
#  '100171Caes': "['n#06154325 a group of warships organized as a tactical unit']",
#  '102324Caes': "['n#00004123 a human being']",
#  '102818Caes': "['n#00004123 a human being']",
#  '103209Caes': "['n#06082225 a large gathering of people', 'n#00004123 a human being']",
#  '104069Caes': "['n#00004123 a human being']",
#  '105194Caes': "['n#00004123 a human being']",
#  '106032Caes': "['n#00004123 a human being']",
#  '106355Caes': "['n#00004123 a human being']",
#  '108403Caes': "['n#07591125 an enlisted man or woman who serves in an army', 'n#00004123 a human being']",
#  '110964Caes': "['n#02372560 temporary living quarters specially built by the army for soldiers']",
#  '111487Caes': "['n#00004123 a human being']",
#  '111782Caes': "['n#00004123 a human being']",
#  '111980Caes': "['n#00004123 a human being']",
#  '112893Caes': "['n#00004123 a human being']",
#  '113030Caes': "['n#00004123 a human being']",
#  '114154Caes': "['n#00004123 a human being']",
#  '114211Caes': "['n#00004123 a human being']",
#  '115967Caes': "['n#00004123 a human being']",
#  '117032Caes': "['n#00004123 a human being']",
#  '117294Caes': "['n#00004123 a human being']",
#  '117394Caes': "['n#00004123 a human being']",
#  '117506Caes': "['n#00004123 a human being']",
#  '117858Caes': "['n#00004123 a human being']",
#  '118479Caes': "['n#00004123 a human being']",
#  '118665Caes': "['n#00004123 a human being']",
#  '121658Caes': "['n#00004123 a human being']",
#  '121689Caes': "['n#00004123 a human being']",
#  '122305Caes': "['n#00004123 a human being']",
#  '123522Caes': "['n#00004123 a human being']",
#  '124898Caes': "['n#00004123 a human being']",
#  '125531Caes': "['n#00004123 a human being']",
#  '125781Caes': "['n#00004123 a human being']",
#  '125934Caes': "['n#00004123 a human being']",
#  '126380Caes': "['n#06789983 a large natural stream of water (larger than a creek']",
#  '126596Caes': "['n#06089493 an organization of military land forces', 'n#00004123 a human being']",
#  '126731Caes': "['n#00004123 a human being']",
#  '127053Caes': "['n#00004123 a human being']",
#  '127799Caes': "['n#00004123 a human being']",
#  '127832Caes': "['n#00004123 a human being']",
#  '130412Caes': "['n#00004123 a human being']",
#  '131258Caes': "['n#00004123 a human being']",
#  '131412Caes': "['n#00004123 a human being']",
#  '132195Caes': "['n#03318070 a vessel that carries passengers or freight']",
#  '132754Caes': "['n#00004123 a human being']",
#  '132936Caes': "['n#00004123 a human being']",
#  '134386Caes': "['n#06210014 troops trained to fight on horseback', 'n#00004123 a human being']",
#  '134764Caes': "['n#00004123 a human being']",
#  '134834Caes': "['n#03318070 a vessel that carries passengers or freight']",
#  '135306Caes': "['n#00004123 a human being']",
#  '135522Caes': "['n#00004123 a human being']",
#  '135874Caes': "['n#00004123 a human being']",
#  '136747Caes': "['n#05437110 an event']",
#  '137342Caes': "['n#00004123 a human being']",
#  '137469Caes': "['n#00004123 a human being']",
#  '138342Caes': "['n#00004123 a human being']",
#  '138943Caes': "['n#07311393 a person who is in charge', 'n#00004123 a human being']",
#  '140508Caes': "['n#00004123 a human being']",
#  '140959Caes': "['n#00004123 a human being']",
#  '142066Caes': "['n#00105760 the act of making up your mind about something']",
#  '143342Caes': "['n#00004123 a human being']",
#  '144404Caes': "['n#00004123 a human being']",
#  '145197Caes': "['n#03318070 a vessel that carries passengers or freight']",
#  '145680Caes': "['n#07391044 an adult male person (as opposed to a woman', 'n#00004123 a human being']",
#  '432Virg': "['n#00004123 a human being']",
#  '7706Virg': "['n#00004123 a human being']",
#  '7737Virg': "['n#00004123 a human being']",
#  '8862Virg': "['n#00004123 a human being']",
#  '11990Virg': "['n#10946591 the coldest season of the year']",
#  '13785Virg': "['n#00004123 a human being']",
#  '16238Virg': "['n#00004123 a human being']",
#  '17473Virg': "['n#00004123 a human being']",
#  '18006Virg': "['n#00004123 a human being']",
#  '18671Virg': "['n#06861622 any supernatural being worshipped as controlling some part of the world or some aspect of life or who is the personification of a force']",
#  '21365Virg': "['n#00004123 a human being']",
#  '22177Virg': "['n#07387754 an unmarried girl (especially a virgin', 'n#00004123 a human being']",
#  '23365Virg': "['n#00004123 a human being']",
#  '28254Virg': "['n#00004123 a human being']",
#  '29798Virg': "['n#06888584 a female deity']",
#  '30509Virg': "['n#00004123 a human being']",
#  '31255Virg': "['n#00004123 a human being']",
#  '34874Virg': "['n#00004123 a human being']",
#  '35620Virg': "['n#00004123 a human being']",
#  '37459Virg': "['n#04778525 a language unit by which a person or thing is known']",
#  '41276Virg': "['n#00004123 a human being']",
#  '43573Virg': "['n#00004123 a human being']",
#  '43993Virg': "['n#01247280 limbless scaly elongate reptile; some are venomous']",
#  '44602Virg': "['n#02202438 a device that very useful for a particular job']",
#  '48145Virg': "['n#03648811 an inclination or tendency of a certain kind']",
#  '48241Virg': "['*clause*']",
#  '49770Virg': "['n#00004123 a human being']",
#  '50132Virg': "['n#10885886 the time after sunset and before sunrise while it is dark outside']",
#  '51144Virg': "['n#00004123 a human being']",
#  '51805Virg': "['n#00004123 a human being']",
#  '52297Virg': "['n#00004123 a human being']",
#  '52346Virg': "['n#00004123 a human being']",
#  '53177Virg': "['n#00004123 a human being']",
#  '54217Virg': "['n#00004123 a human being']",
#  '54718Virg': "['n#00004123 a human being']",
#  '54916Virg': "['n#00004123 a human being']",
#  '56245Virg': "['n#06789983 a large natural stream of water (larger than a creek']",
#  '59141Virg': "['n#03685812 the visual appearance of something or someone']",
#  '59228Virg': "['n#00004123 a human being']",
#  '59803Virg': "['n#05588321 intense anger (usually on an epic scale']",
#  '62403Virg': "['NA']",
#  '62863Virg': "['n#00004123 a human being']",
#  '64240Virg': "['n#00004123 a human being']",
#  '64250Virg': "['n#00004123 a human being']",
#  '65760Virg': "['n#00004123 a human being']",
#  '65999Virg': "['n#00004123 a human being']",
#  '66493Virg': '["n#07681186 a married woman; a man\'s partner in marriage", \'n#00004123 a human being\']',
#  '68857Virg': "['n#05437110 an event']",
#  '69560Virg': "['n#03685812 the visual appearance of something or someone']",
#  '69709Virg': "['n#00004123 a human being']",
#  '70805Virg': "['n#00004123 a human being']",
#  '71379Virg': "['n#04197156 the fluid (red in vertebrates that is pumped by the heart']",
#  '71716Virg': "['n#00004123 a human being']",
#  '73590Virg': "['n#00004123 a human being']",
#  '73713Virg': "['n#00004123 a human being']",
#  '73793Virg': "['n#00004123 a human being']",
#  '80521Virg': "['n#05985893 a group of birds']",
#  '82245Virg': "['n#00004123 a human being']",
#  '83144Virg': "['n#00004123 a human being']",
#  '83462Virg': "['n#00004123 a human being']",
#  '86033Virg': "['n#00004123 a human being']",
#  '87458Virg': "['n#01893422 an adult female hog']",
#  '87664Virg': "['n#06861200 the ultimate agency that predetermines the course of events (often personified as a woman']",
#  '87795Virg': "['n#00004123 a human being']",
#  '88198Virg': "['n#06948078 (synecdoche a part of a person is used to refer to a person', 'n#00004123 a human being']",
#  '90216Virg': "['n#00004123 a human being']",
#  '90398Virg': "['n#00004123 a human being']",
#  '92904Virg': "['n#10885886 the time after sunset and before sunrise while it is dark outside']",
#  '97057Virg': "['n#00004123 a human being']",
#  '104583Virg': "['n#00004123 a human being']",
#  '106171Virg': "['n#06888584 a female deity']",
#  '106849Virg': "['n#06888584 a female deity']",
#  '107640Virg': "['n#00004123 a human being']",
#  '108134Virg': "['n#00004123 a human being']",
#  '108891Virg': "['n#01913145 any of numerous agile ruminants related to sheep but having a beard and straight horns']",
#  '109468Virg': "['n#00004123 a human being']",
#  '109948Virg': "['n#06888584 a female deity']",
#  '113059Virg': "['n#06861622 any supernatural being worshipped as controlling some part of the world or some aspect of life or who is the personification of a force']",
#  '114612Virg': "['n#00004123 a human being']",
#  '116498Virg': "['n#00004123 a human being']",
#  '123434Virg': "['n#00004123 a human being']",
#  '124355Virg': "['n#00004123 a human being']",
#  '133403Virg': "['n#00004123 a human being']",
#  '133638Virg': "['n#06888584 a female deity']",
#  '134189Virg': '["n#06667942 the solid part of the earth\'s surface"]',
#  '135444Virg': "['n#00004123 a human being']",
#  '138905Virg': "['n#00004123 a human being']",
#  '140556Virg': "['n#00004123 a human being']",
#  '141091Virg': "['n#00004123 a human being']",
#  '141273Virg': "['n#00004123 a human being']",
#  '141744Virg': "['n#00004123 a human being']",
#  '142211Virg': "['n#02840815 the frame or body of ship']",
#  '142989Virg': "['n#00004123 a human being']",
#  '143030Virg': "['n#06740258 a submerged ridge of rock or coral near the surface of the water']",
#  '143385Virg': "['n#00004123 a human being']",
#  '146166Virg': "['n#03609242 a simple machine consisting of a circular frame with spokes (or a solid disc that can rotate on a shaft or axle (as in vehicles or other machines']",
#  '146482Virg': "['n#00004123 a human being']",
#  '147001Virg': "['n#00004123 a human being']",
#  '147545Virg': "['n#00004123 a human being']",
#  '147939Virg': "['n#00004123 a human being']",
#  '148092Virg': "['n#00004123 a human being']",
#  '148425Virg': "['n#00004123 a human being']",
#  '149019Virg': "['n#00004123 a human being']",
#  '149322Virg': "['n#00004123 a human being']",
#  '150806Virg': "['n#00004123 a human being']",
#  '153567Virg': "['n#00004123 a human being']",
#  '154152Virg': "['n#00004123 a human being']",
#  '155882Virg': "['n#07391044 an adult male person (as opposed to a woman', 'n#00004123 a human being']",
#  '155986Virg': "['n#00290820 the activity of doing something in an agreed succession']",
#  '157561Virg': "['n#06762045 (astronomy a celestial body of hot gases that radiates energy derived from thermonuclear reactions in the interior']",
#  '158232Virg': "['n#00004123 a human being']",
#  '159975Virg': "['n#00004123 a human being']",
#  '161170Virg': "['n#06888584 a female deity']",
#  '171793Virg': "['n#00004123 a human being']",
#  '172598Virg': "['n#06154325 a group of warships organized as a tactical unit']",
#  '173466Virg': "['n#00004123 a human being']",
#  '173621Virg': "['n#00004123 a human being']",
#  '175538Virg': "['n#06781925 a division of an ocean or a large body of salt water partially enclosed by land']",
#  '178081Virg': "['n#00004123 a human being']",
#  '178845Virg': "['n#06787575 a body of (usually fresh water surrounded by land']",
#  '178923Virg': "['n#00004123 a human being']",
#  '179216Virg': "['n#00004123 a human being']",
#  '179933Virg': "['n#00004123 a human being']",
#  '180403Virg': "['n#00004123 a human being']",
#  '189518Virg': "['n#00004123 a human being']",
#  '189796Virg': "['n#00004123 a human being']",
#  '190311Virg': "['n#00004123 a human being']",
#  '194445Virg': "['n#00004123 a human being']",
#  '196965Virg': "['n#00004123 a human being']",
#  '199193Virg': "['n#00004123 a human being']",
#  '201167Virg': "['n#00004123 a human being']",
#  '201653Virg': "['n#00004123 a human being']",
#  '204262Virg': "['n#04533237 a mental representation of some haunting experience']",
#  '204513Virg': "['n#03685812 the visual appearance of something or someone']",
#  '209024Virg': "['n#00004123 a human being']",
#  '209511Virg': "['n#00004123 a human being']",
#  '211455Virg': "['n#00004123 a human being']",
#  '211949Virg': "['n#10885886 the time after sunset and before sunrise while it is dark outside']",
#  '211997Virg': "['n#00004123 a human being']",
#  '214128Virg': "['n#06888584 a female deity']",
#  '214495Virg': "['n#00004123 a human being']",
#  '217132Virg': "['n#07354565 a male sovereign; ruler of a kingdom', 'n#00004123 a human being']",
#  '219889Virg': "['n#10878282 a day assigned to a particular purpose or observance']",
#  '220630Virg': "['n#00004123 a human being']",
#  '220908Virg': "['n#07391044 an adult male person (as opposed to a woman', 'n#00004123 a human being']",
#  '222054Virg': "['n#00004123 a human being']",
#  '223419Virg': "['n#06684818 a part of the earth that can be considered separately']",
#  '225199Virg': "['n#00004123 a human being']",
#  '226630Virg': "['n#00004123 a human being']",
#  '227586Virg': "['n#00004123 a human being']",
#  '230693Virg': "['n#00004123 a human being']",
#  '232956Virg': "['n#04982831 new information about specific and timely events']",
#  '236580Virg': "['n#07256794 a person who operates a farm', 'n#00004123 a human being']",
#  '237732Virg': "['n#00004123 a human being']",
#  '239357Virg': "['n#00004123 a human being']",
#  '242250Virg': "['n#00004123 a human being']",
#  '243200Virg': "['n#00004123 a human being']",
#  '246097Virg': "['n#00004123 a human being']",
#  '249161Virg': "['n#00004123 a human being']",
#  '251661Virg': "['n#01893422 an adult female hog']",
#  '252649Virg': "['n#06276073 the source of water from which a stream arises']",
#  '253105Virg': "['n#06789983 a large natural stream of water (larger than a creek']",
#  '253927Virg': "['n#02304226 a small vessel for travel on water']",
#  '255168Virg': "['n#00004123 a human being']",
#  '255307Virg': "['n#00004123 a human being']",
#  '255317Virg': "['n#00004123 a human being']",
#  '263177Virg': "['n#00004123 a human being']",
#  '263464Virg': "['n#00004123 a human being']",
#  '264714Virg': "['n#00004123 a human being']",
#  '265711Virg': "['n#00004123 a human being']",
#  '265861Virg': "['n#00004123 a human being']",
#  '266821Virg': "['n#06069040 the body of citizens of a state or country', 'n#00004123 a human being']",
#  '267152Virg': "['n#05517934 a sudden flash (as of lightning']",
#  '270477Virg': "['n#00004123 a human being']",
#  '271603Virg': "['n#00004123 a human being']",
#  '272498Virg': "['n#00004123 a human being']",
#  '273887Virg': "['n#00004123 a human being']",
#  '274288Virg': "['n#10580335 the dressed skin of an animal (especially a large animal']",
#  '275733Virg': "['n#06210014 troops trained to fight on horseback', 'n#00004123 a human being']",
#  '278664Virg': "['n#00004123 a human being']",
#  '280427Virg': "['n#06741251 a land mass (smaller than a continent that is surrounded by water', 'n#L1371388 a group of over 200 islands in the southern Aegean']",
#  '280463Virg': "['n#06711088 a land mass that projects well above its surroundings; higher than a hill']",
#  '287152Virg': "['n#06749470 a visible mass of water or ice particles suspended at a considerable altitude']",
#  '295134Virg': "['n#00004123 a human being']",
#  '296146Virg': "['n#00004123 a human being']",
#  '296659Virg': "['n#00004123 a human being']",
#  '297527Virg': "['n#00004123 a human being']",
#  '298771Virg': "['n#00004123 a human being']",
#  '299424Virg': "['n#00004123 a human being']",
#  '299873Virg': "['n#05329674 loud and persistent outcry from many people']",
#  '300266Virg': "['n#06888584 a female deity']",
#  '300658Virg': "['n#03378030 a long pointed rod used as a weapon']",
#  '303460Virg': "['n#00004123 a human being']",
#  '307599Virg': "['n#00004123 a human being']",
#  '310327Virg': "['n#02212344 a projectile with a straight thin shaft and an arrowhead on one end and stabilizing vanes on the other; intended to be shot from a bow']",
#  '312935Virg': "['n#00004123 a human being']",
#  '313368Virg': "['n#03378030 a long pointed rod used as a weapon']",
#  '314287Virg': "['n#00004123 a human being']",
#  '315136Virg': "['n#00004123 a human being']",
#  '315248Virg': "['n#00004123 a human being']",
#  '315495Virg': "['n#00004123 a human being']",
#  '315938Virg': "['n#04492484 the content of cognition; the main thing you are thinking about']",
#  '316843Virg': "['n#07168973 an officer in command of a military unit']",
#  '317870Virg': "['n#06089493 an organization of military land forces', 'n#00004123 a human being']",
#  '318980Virg': "['n#06299747 the territory occupied by a nation', 'n#06459750 a republic in S Europe; was the core of the Roman Republic and the Roman Empire between the 4th century BC and the 5th century AD']",
#  '319097Virg': "['n#10851114 some point or period in time']",
#  '323697Virg': "['n#06861200 the ultimate agency that predetermines the course of events (often personified as a woman']",
#  '325250Virg': "['n#00004123 a human being']",
#  '325275Virg': "['n#00004123 a human being']",
#  '328440Virg': "['n#06117068 an unofficial association of people or groups', 'n#00004123 a human being']",
#  '328539Virg': "['n#06897921 (classical mythology a minor nature goddess usually depicted as a beautiful maiden']",
#  '330527Virg': "['n#01524724 large long-necked wading bird of marshes and plains in many parts of the world']",
#  '331278Virg': "['n#00004123 a human being']",
#  '331311Virg': "['n#00004123 a human being']",
#  '333759Virg': "['n#00004123 a human being']",
#  '334105Virg': "['n#00004123 a human being']",
#  '334418Virg': "['n#00004123 a human being']",
#  '334455Virg': "['n#00004123 a human being']",
#  '334790Virg': "['n#06237025 a row or line of people (especially soldiers or police standing abreast of one another', 'n#00004123 a human being']",
#  '335260Virg': "['n#05583906 a specific instance of feeling hopeful']",
#  '337038Virg': "['n#03805961 a quality of spirit that enables you to face danger of pain without showing fear']",
#  '337952Virg': "['n#06237025 a row or line of people (especially soldiers or police standing abreast of one another', 'n#00004123 a human being']",
#  '338198Virg': "['n#00004123 a human being']",
#  '338908Virg': "['n#04197156 the fluid (red in vertebrates that is pumped by the heart']",
#  '339076Virg': "['n#01637880 large gregarious predatory feline of Africa and India having a tawny coat with a shaggy mane in the male']",
#  '339308Virg': "['n#00004123 a human being']",
#  '339833Virg': "['n#00004123 a human being']",
#  '340312Virg': "['n#10580335 the dressed skin of an animal (especially a large animal']",
#  '341530Virg': "['n#07406477 a person who carries a message', 'n#00004123 a human being']",
#  '341593Virg': "['n#00004123 a human being']",
#  '341806Virg': "['n#00004123 a human being']",
#  '342042Virg': "['n#00004123 a human being']",
#  '342842Virg': "['n#00004123 a human being']",
#  '344986Virg': "['n#03378030 a long pointed rod used as a weapon']",
#  '346282Virg': "['n#00004123 a human being']",
#  '348660Virg': "['n#00004123 a human being']",
#  '349601Virg': "['n#06237025 a row or line of people (especially soldiers or police standing abreast of one another', 'n#00004123 a human being']",
#  '350829Virg': "['n#00004123 a human being']",
#  '351569Virg': "['n#00004123 a human being']",
#  '352881Virg': "['n#00004123 a human being']",
#  '353048Virg': "['n#06861622 any supernatural being worshipped as controlling some part of the world or some aspect of life or who is the personification of a force']",
#  '353870Virg': "['n#03378030 a long pointed rod used as a weapon']",
#  '354451Virg': "['n#04311223 the (prehensile extremity of the superior limb']",
#  '354559Virg': "['n#07258194 a male parent (also used as a term of address to your father', 'n#00004123 a human being']",
#  '355594Virg': "['n#03685812 the visual appearance of something or someone']",
#  '357204Virg': "['n#00004123 a human being']",
#  '357988Virg': "['n#00004123 a human being']",
#  '358823Virg': "['n#00004123 a human being']",
#  '364594Virg': "['n#00004123 a human being']",
#  '367798Virg': "['n#00004123 a human being']",
#  '370405Virg': "['n#00004123 a human being']",
#  '372429Virg': "['n#03601056 weaponry used in fighting or hunting']",
#  '374312Virg': "['n#00004123 a human being']",
#  '375726Virg': "['n#00004123 a human being']",
#  '381217Virg': "['n#00004123 a human being']",
#  '381596Virg': "['n#00004123 a human being']",
#  '381797Virg': "['n#00004123 a human being']",
#  '382911Virg': "['n#00004123 a human being']",
#  '383814Virg': "['n#00004123 a human being']",
#  '386460Virg': "['n#00004123 a human being']",
#  '386671Virg': "['n#00004123 a human being']",
#  '387178Virg': "['n#06781925 a division of an ocean or a large body of salt water partially enclosed by land']",
#  '387496Virg': "['n#00004123 a human being']",
#  '387753Virg': "['n#00004123 a human being']",
#  '389348Virg': "['n#00004123 a human being']",
#  '390022Virg': "['n#10878282 a day assigned to a particular purpose or observance']",
#  '390807Virg': "['n#00004123 a human being']",
#  '391464Virg': "['n#07387754 an unmarried girl (especially a virgin', 'n#00004123 a human being']",
#  '391512Virg': "['n#00004123 a human being']",
#  '392954Virg': "['n#00004123 a human being']",
#  '393342Virg': "['n#00004123 a human being']",
#  '393422Virg': "['n#00004123 a human being']",
#  '393528Virg': "['n#00004123 a human being']",
#  '395407Virg': "['n#07172243 a person who is frequently in the company of another', 'n#00004123 a human being']",
#  '395567Virg': "['n#00004123 a human being']",
#  '396317Virg': "['n#00004123 a human being']",
#  '396723Virg': "['n#00004123 a human being']",
#  '397667Virg': "['n#00004123 a human being']",
#  '397899Virg': "['n#06314878 either extremity of something that has length']",
#  '398815Virg': "['n#00004123 a human being']",
#  '399820Virg': "['n#00004123 a human being']",
#  '399871Virg': "['n#00004123 a human being']",
#  '400199Virg': "['n#00004123 a human being']",
#  '400912Virg': "['n#00004123 a human being']",
#  '404158Virg': "['n#01875414 solid-hoofed herbivorous quadruped domesticated since prehistoric times']",
#  '407054Virg': "['n#07692038 a young person (especially a young man or boy', 'n#00004123 a human being']",
#  '408595Virg': "['*clause*']",
#  '410205Virg': "['n#00004123 a human being']",
#  '412317Virg': "['n#00004123 a human being']",
#  '412923Virg': "['n#06237025 a row or line of people (especially soldiers or police standing abreast of one another', 'n#00004123 a human being']",
#  '413525Virg': "['n#00004123 a human being']",
#  '413679Virg': "['n#00004123 a human being']",
#  '414488Virg': "['n#00004123 a human being']",
#  '416065Virg': "['n#00004123 a human being']",
#  '418556Virg': "['n#06861622 any supernatural being worshipped as controlling some part of the world or some aspect of life or who is the personification of a force']",
#  '418671Virg': "['n#07144504 a soldier mounted on horseback', 'n#00004123 a human being']",
#  '419546Virg': "['n#03495843 an entity that is not named specifically']",
#  '421254Virg': "['n#00004123 a human being']",
#  '421505Virg': "['n#00004123 a human being']",
#  '421643Virg': "['n#01116731 small long-winged songbird noted for swift graceful flight and the regularity of its migrations']",
#  '421860Virg': "['n#00004123 a human being']",
#  '422984Virg': "['n#06069040 the body of citizens of a state or country', 'n#00004123 a human being']",
#  '423273Virg': "['n#00004123 a human being']",
#  '424445Virg': "['n#00004123 a human being']",
#  '425637Virg': "['n#06141923 a large military unit', 'n#00004123 a human being']",
#  '426027Virg': "['n#00004123 a human being']",
#  '428401Virg': "['n#00004123 a human being']",
#  '432530Virg': "['n#01900416 uncastrated adult male of domestic cattle']",
#  '432841Virg': "['n#00004123 a human being']",
#  '433256Virg': "['n#00032687 the act of escaping physically']",
#  '434538Virg': "['n#00004123 a human being']",
#  '434996Virg': "['n#00004123 a human being']",
#  '435595Virg': "['n#06888584 a female deity']",
#  '436869Virg': "['n#06888584 a female deity']",
#  '438653Virg': "['n#10169961 a serious (sometimes fatal infection transmitted by the bite of an infected rat flea (especially bubonic plague']",
#  '440736Virg': "['n#00004123 a human being']",
#  '441937Virg': "['n#03378030 a long pointed rod used as a weapon']"}

# %% [markdown]
# #### Creating Figure Synsets DataFrame

# %%
figure_synsets_df = pd.DataFrame([(k,v) for k,v in tok2_figure_synsets.items()], columns=["ID", "FIGURE SEMANTICS"]) #where 'figure_synsets_df' is a dataframe containing token IDs and figure synsets of all the tokens annotated with a figure 
figure_synsets_df
# Out:
#              ID                                   FIGURE SEMANTICS
# 0      1498Caes  ['n#06080139 the people who inhabit a territor...
# 1      4296Caes                       ['n#00004123 a human being']
# 2      4578Caes                       ['n#00004123 a human being']
# 3      4854Caes                       ['n#00004123 a human being']
# 4      4978Caes                       ['n#00004123 a human being']
# ..          ...                                                ...
# 499  435595Virg                      ['n#06888584 a female deity']
# 500  436869Virg                      ['n#06888584 a female deity']
# 501  438653Virg  ['n#10169961 a serious (sometimes fatal infect...
# 502  440736Virg                       ['n#00004123 a human being']
# 503  441937Virg  ['n#03378030 a long pointed rod used as a weap...
#
# [504 rows x 2 columns]

# %% [markdown]
# #### Merging Synsets and Figure Synsets DataFrame

# %%
id_figure_synsets_df = id_synsets_df.merge(figure_synsets_df, on='ID', how='left') #where 'id_figure_synsets_df' merges 'id_synsets_df' and 'figure_synsets_df', basically adding the figure synset to the other parameters contained in 'id_synsets_df'
id_figure_synsets_df
# Out:
#              ID   VERB TOKEN  \
# 0      1498Caes      exirent
# 1      4296Caes       exeant
# 2      4578Caes     subeunda
# 3      4854Caes  transierant
# 4      4978Caes        exire
# ..          ...          ...
# 499  435595Virg    procurrit
# 500  436869Virg   succurrere
# 501  438653Virg    occurrere
# 502  440736Virg     subirent
# 503  441937Virg      transit
#
#                                 MORPHOLOGICAL FEATURES     LEMMA  \
# 0    Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      exeo
# 1    Mood=Subj|Number=Plur|Person=3|Tense=Pres|Verb...      exeo
# 2    Case=Nom|Gender=Neut|Number=Plur|Tense=Pres|Ve...     subeo
# 3    Mood=Ind|Number=Plur|Person=3|Tense=Pqp|VerbFo...   transeo
# 4                    Tense=Pres|VerbForm=Inf|Voice=Act      exeo
# ..                                                 ...       ...
# 499  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  procurro
# 500                  Tense=Pres|VerbForm=Inf|Voice=Act  succurro
# 501                  Tense=Pres|VerbForm=Inf|Voice=Act   occurro
# 502  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...     subeo
# 503  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   transeo
#
#                                               SENTENCE     ACTIONALITY  \
# 0    Pisone consulibus regni cupiditate inductus co...        Activity
# 1    Post eius mortem nihilo minus Helvetii id quod...        Activity
# 2    frumentum omne, praeter quod secum portaturi e...     Achievement
# 3    Persuadent Rauracis et Tulingis et Latobrigis ...     Achievement
# 4    Erant omnino itinera duo, quibus itineribus do...        Activity
# ..                                                 ...             ...
# 499  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 500  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 501  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 502  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 503                  Per medium stridens transit femur  Accomplishment
#
#             VERB CLASS  LITERAL MEANING     VERB STEM PREVERB  \
# 0          ESCAPE-51.1             True  present stem      ex
# 1          ESCAPE-51.1             True  present stem      ex
# 2          MARVEL-31.3            False  present stem     sub
# 3          ESCAPE-51.1             True  perfect stem   trans
# 4          ESCAPE-51.1             True  present stem      ex
# ..                 ...              ...           ...     ...
# 499         RUN-51.3.2             True  present stem     pro
# 500          HELP-72.1            False  present stem     sub
# 501         RUN-51.3.2            False  present stem      ob
# 502  PUT_DIRECTION-9.4            False  present stem     sub
# 503        ESCAPE-51.1             True  present stem   trans
#
#     PREVERB SEMANTICS                                     VERB SEMANTICS  \
# 0                 out  [v#01376117 move out of; as of a room, a count...
# 1                 out  [v#01376117 move out of; as of a room, a count...
# 2               under                     [v#01444459 undergo or suffer]
# 3              across  [v#01253107 change location; move, travel, or ...
# 4                 out                  [v#01371248 go away from a place]
# ..                ...                                                ...
# 499           forward   [v#01410345 run or move very quickly or hastily]
# 500             under         [v#01737682 help in a difficult situation]
# 501                to   [v#01410345 run or move very quickly or hastily]
# 502             under  [v#01343923 raise from a lower to a higher pos...
# 503            across  [v#00988556 penetrate or cut through with a sh...
#
#                                       FIGURE SEMANTICS
# 0    ['n#06080139 the people who inhabit a territor...
# 1                         ['n#00004123 a human being']
# 2                         ['n#00004123 a human being']
# 3                         ['n#00004123 a human being']
# 4                         ['n#00004123 a human being']
# ..                                                 ...
# 499                      ['n#06888584 a female deity']
# 500                      ['n#06888584 a female deity']
# 501  ['n#10169961 a serious (sometimes fatal infect...
# 502                       ['n#00004123 a human being']
# 503  ['n#03378030 a long pointed rod used as a weap...
#
# [504 rows x 13 columns]

# %% [markdown]
# ## Ground synset

# %% [markdown]
# #### Extracting Ground Synsets

# %%
list_ground_synsets = []  # Initializing an empty list to store ground synsets
tok2_ground_synsets = dict()  # Initializing an empty dictionary to store predicted ground synsets mapped to IDs
count= 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Groundsynset' annotation in the CAS
    for relation in cas.select('webanno.custom.Groundsynset'):
        # Looping through each token covered by the 'Groundsynset' annotation
        for token in cas.select_covered('webanno.custom.Groundsynset', relation):
            tok = token.get_covered_text()  # Getting the text covered by the current token
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            ground_synset = relation.GroundSyn  # Getting the ground synset value
            
            # Checking if the ID already exists in tok2_ground_synsets dictionary
            if id in tok2_ground_synsets:
                # If ID exists, append the new ground synset to the existing list of ground synsets
                list_ground_synsets = tok2_ground_synsets[id] + [ground_synset]
                tok2_ground_synsets[id] = list_ground_synsets
            else:
                # If ID doesn't exist, store the ground synset directly
                tok2_ground_synsets[id] = [ground_synset]

print(tok2_ground_synsets)
# Out:
# {'1498Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray))], '4296Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray))], '4578Caes': [uima_cas_StringArray(xmiID=None, elements=['n#10428324 a source of danger'], type=Type(name=uima.cas.StringArray))], '4854Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray))], '4978Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06277165 the country where you were born'], type=Type(name=uima.cas.StringArray))], '5732Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06800223 sloping land (especially the slope beside a body of water)'], type=Type(name=uima.cas.StringArray))], '5997Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06287351 a large and densely populated urban area; may include several independent administrative districts'], type=Type(name=uima.cas.StringArray))], '9426Caes': [uima_cas_StringArray(xmiID=None, elements=[], type=Type(name=uima.cas.StringArray))], '9649Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray))], '10407Caes': [uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '10617Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06789983 a large natural stream of water (larger than a creek)'], type=Type(name=uima.cas.StringArray))], '10862Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06095787 an army unit large enough to sustain combat', 'n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '10890Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06789983 a large natural stream of water (larger than a creek)'], type=Type(name=uima.cas.StringArray))], '10931Caes': [uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '11152Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06277165 the country where you were born'], type=Type(name=uima.cas.StringArray))], '11818Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06789983 a large natural stream of water (larger than a creek)'], type=Type(name=uima.cas.StringArray))], '12323Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06789983 a large natural stream of water (larger than a creek)'], type=Type(name=uima.cas.StringArray))], '21567Caes': [uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '24504Caes': [uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '25610Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray))], '26036Caes': [uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '26268Caes': [uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '26640Caes': [uima_cas_StringArray(xmiID=None, elements=['n#02372560 temporary living quarters specially built by the army for soldiers'], type=Type(name=uima.cas.StringArray))], '27386Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06299747 the territory occupied by a nation'], type=Type(name=uima.cas.StringArray))], '27831Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06277165 the country where you were born'], type=Type(name=uima.cas.StringArray))], '28359Caes': [uima_cas_StringArray(xmiID=None, elements=['n#00004123 a human being'], type=Type(name=uima.cas.StringArray))], '29918Caes': [uima_cas_StringArray(xmiID=None, elements=['n#06789983 a large natural stream of water (larger than a creek)'], type=Type(name=uima.cas.StringArray))], '30767 ...

# %% [markdown]
# #### Extracting and Cleaning Ground Synsets

# %%
list_ground_synsets = []  # Initializing an empty list to store ground synsets

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Groundsynset' annotation in the CAS
    for relation in cas.select('webanno.custom.Groundsynset'):
        ground_synset = relation.GroundSyn  # Getting the ground synset value
        # Extracting the useful information from the StringArray elements
        ground_synset_values = [element.strip().strip("'") for element in ground_synset.elements]
        # Appending the ground synset values as a sublist
        list_ground_synsets.append(ground_synset_values)

print(list_ground_synsets)
# Out:
# [['n#06299747 the territory occupied by a nation'], ['n#06299747 the territory occupied by a nation'], ['n#10428324 a source of danger'], ['n#06299747 the territory occupied by a nation'], ['n#06277165 the country where you were born'], ['n#06800223 sloping land (especially the slope beside a body of water)'], ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'], [], ['n#06299747 the territory occupied by a nation'], ['n#00004123 a human being'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06095787 an army unit large enough to sustain combat', 'n#00004123 a human being'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#00004123 a human being'], ['n#06277165 the country where you were born'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#00004123 a human being'], ['n#00004123 a human being'], ['n#06299747 the territory occupied by a nation'], ['n#00004123 a human being'], ['n#00004123 a human being'], ['n#02372560 temporary living quarters specially built by the army for soldiers'], ['n#06299747 the territory occupied by a nation'], ['n#06277165 the country where you were born'], ['n#00004123 a human being'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06299747 the territory occupied by a nation'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#09535912 a territorial possession controlled by a ruling state'], ['n#02837386 a dwelling that serves as living quarters for one or more families'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#10019535 an international boundary or the area along such a boundary'], ['n#02372560 temporary living quarters specially built by the army for soldiers'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06299747 the territory occupied by a nation'], ['n#10019535 an international boundary or the area along such a boundary'], ['n#00004123 a human being'], ['n#06786830 low-lying wet land with grassy vegetation; usually is a transition zone between land and water'], ['n#06088783 an opposing military force', 'n#00004123 a human being'], ['n#04056524 the dead body of a human being'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06381267 a point located with respect to surface features of some region'], ['n#02372560 temporary living quarters specially built by the army for soldiers'], ['n#06262813 the country or state or city where you live'], ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'], ['n#06382213 an urban area with a fixed boundary that is smaller than a city'], ['n#06299747 the territory occupied by a nation'], ['n#06299747 the territory occupied by a nation'], ['n#00004123 a human being'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#03601056 weaponry used in fighting or hunting'], ['n#06141923 a large military unit'], ['n#00004123 a human being'], ['n#06381267 a point located with respect to surface features of some region'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#06381267 a point located with respect to surface features of some region'], ['n#07242378 an armed adversary (especially a member of an opposing military force)', 'n#00004123 a human being'], ['n#06789983 a large natural stream of water (larger than a creek)'], ['n#07242378 an armed adversary (especially a member o ...

# %% [markdown]
# #### Extracting and Mapping Ground Synset Annotations from CAS Files

# %%
list_token_ground_synset_ids = []  # Initializing an empty list to store IDs of tokens annotated with a ground 
count= 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Groundsynset' annotation in the CAS
    for relation in cas.select('webanno.custom.Groundsynset'):
        # Looping through each token covered by the 'Groundsynset' annotation
        for token in cas.select_covered('webanno.custom.Groundsynset', relation):
            id = token.begin  # Getting the beginning offset of the token
            id = str(id) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            list_token_ground_synset_ids.append(id)  # Appending the token ID to the list

print(list_token_ground_synset_ids)
# Out:
# ['1498Caes', '4296Caes', '4578Caes', '4854Caes', '4978Caes', '5732Caes', '5997Caes', '9426Caes', '9649Caes', '10407Caes', '10617Caes', '10862Caes', '10890Caes', '10931Caes', '11152Caes', '11818Caes', '12323Caes', '21567Caes', '24504Caes', '25610Caes', '26036Caes', '26268Caes', '26640Caes', '27386Caes', '27831Caes', '28359Caes', '29918Caes', '30767Caes', '31365Caes', '33967Caes', '34210Caes', '37157Caes', '37517Caes', '46744Caes', '46852Caes', '48088Caes', '53622Caes', '56162Caes', '59161Caes', '60301Caes', '61670Caes', '65326Caes', '66243Caes', '66324Caes', '66489Caes', '66567Caes', '67219Caes', '67317Caes', '68853Caes', '69478Caes', '70242Caes', '70802Caes', '72211Caes', '74081Caes', '74785Caes', '75094Caes', '75926Caes', '76251Caes', '76487Caes', '77316Caes', '77401Caes', '77454Caes
tok2_ground_synset = {list_token_ground_synset_ids[i]: list_ground_synsets[i] for i in range(len(list_token_ground_synset_ids))}

tok2_ground_synset
# Out:
# {'1498Caes': ['n#06299747 the territory occupied by a nation'],
#  '4296Caes': ['n#06299747 the territory occupied by a nation'],
#  '4578Caes': ['n#10428324 a source of danger'],
#  '4854Caes': ['n#06299747 the territory occupied by a nation'],
#  '4978Caes': ['n#06277165 the country where you were born'],
#  '5732Caes': ['n#06800223 sloping land (especially the slope beside a body of water)'],
#  '5997Caes': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '9426Caes': [],
#  '9649Caes': ['n#06299747 the territory occupied by a nation'],
#  '10407Caes': ['n#00004123 a human being'],
#  '10617Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '10862Caes': ['n#06095787 an army unit large enough to sustain combat',
#   'n#00004123 a human being'],
#  '10890Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '10931Caes': ['n#00004123 a human being'],
#  '11152Caes': ['n#06277165 the country where you were born'],
#  '11818Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '12323Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '21567Caes': ['n#00004123 a human being'],
#  '24504Caes': ['n#00004123 a human being'],
#  '25610Caes': ['n#06299747 the territory occupied by a nation'],
#  '26036Caes': ['n#00004123 a human being'],
#  '26268Caes': ['n#00004123 a human being'],
#  '26640Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '27386Caes': ['n#06299747 the territory occupied by a nation'],
#  '27831Caes': ['n#06277165 the country where you were born'],
#  '28359Caes': ['n#00004123 a human being'],
#  '29918Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '30767Caes': ['n#06299747 the territory occupied by a nation'],
#  '31365Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '33967Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '34210Caes': ['n#09535912 a territorial possession controlled by a ruling state'],
#  '37157Caes': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '37517Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '46744Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '46852Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '48088Caes': ['n#10019535 an international boundary or the area along such a boundary'],
#  '53622Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '56162Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '59161Caes': ['n#06299747 the territory occupied by a nation'],
#  '60301Caes': ['n#10019535 an international boundary or the area along such a boundary'],
#  '61670Caes': ['n#00004123 a human being'],
#  '65326Caes': ['n#06786830 low-lying wet land with grassy vegetation; usually is a transition zone between land and water'],
#  '66243Caes': ['n#06088783 an opposing military force',
#   'n#00004123 a human being'],
#  '66324Caes': ['n#04056524 the dead body of a human being'],
#  '66489Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '66567Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '67219Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '67317Caes': ['n#06262813 the country or state or city where you live'],
#  '68853Caes': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '69478Caes': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'],
#  '70242Caes': ['n#06299747 the territory occupied by a nation'],
#  '70802Caes': ['n#06299747 the territory occupied by a nation'],
#  '72211Caes': ['n#00004123 a human being'],
#  '74081Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '74785Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '75094Caes': ['n#03601056 weaponry used in fighting or hunting'],
#  '75926Caes': ['n#06141923 a large military unit'],
#  '76251Caes': ['n#00004123 a human being'],
#  '76487Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '77316Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '77401Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '77454Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '78212Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '78345Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '81306Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '81803Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '81859Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '85712Caes': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'],
#  '86330Caes': ['n#02741769 a fortified place where troops are stationed'],
#  '89385Caes': ['n#06730976 a long depression in the surface of the land that usually contains a river'],
#  '90684Caes': ['n#06370070 a place within a region identified relative to a center or reference location'],
#  '91683Caes': ['n#00004123 a human being'],
#  '92706Caes': ['n#05437110 an event'],
#  '93203Caes': ['n#06080139 the people who inhabit a territory or state'],
#  '97054Caes': ['n#00004123 a human being'],
#  '97169Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '97624Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '102818Caes': ['n#06299747 the territory occupied by a nation'],
#  '104069Caes': ['n#07242378 an armed adversary (especially a member of an opposing military force)',
#   'n#00004123 a human being'],
#  '106032Caes': ['n#06358701 the extended spatial location of something'],
#  '108403Caes': ['n#03601056 weaponry used in fighting or hunting'],
#  '111487Caes': ['n#02715844 walls or mounds used around a stronghold to strengthen it'],
#  '111980Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '112893Caes': ['n#04515071 the first part or section of something'],
#  '113030Caes': ['n#06684175 a portion of a natural object'],
#  '114154Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '115967Caes': ['n#00004123 a human being'],
#  '117032Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '117506Caes': ['n#06348591 an established line of travel or access'],
#  '117858Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '118479Caes': ['n#00105760 the act of making up your mind about something'],
#  '118665Caes': ['n#00626011 the waging of armed conflict against an enemy'],
#  '124898Caes': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '125531Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '125781Caes': ['n#06297988 a place where two things come together'],
#  '126596Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '126731Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '127053Caes': ['n#06299747 the territory occupied by a nation'],
#  '127799Caes': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '130412Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '131258Caes': ['n#06741251 a land mass (smaller than a continent) that is surrounded by water'],
#  '132195Caes': ['n#06381267 a point located with respect to surface features of some region'],
#  '132754Caes': ['n#06299747 the territory occupied by a nation'],
#  '132936Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '134386Caes': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '135306Caes': ['n#06351684 the precise location of something; a spatially limited location'],
#  '135522Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '135874Caes': ['n#10650211 a clear colorless odorless tasteless liquid'],
#  '136747Caes': ['n#06141923 a large military unit'],
#  '137342Caes': ['n#03401168 any distinctive flag'],
#  '137469Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '138342Caes': ['n#03318070 a vessel that carries passengers or freight'],
#  '140508Caes': ['n#00004123 a human being'],
#  '140959Caes': ['n#06299747 the territory occupied by a nation'],
#  '142066Caes': ['n#00004123 a human being'],
#  '143342Caes': ['n#03152394 a long (usually round) rod of wood or metal or plastic'],
#  '144404Caes': ['n#10427326 the condition of being susceptible to harm or injury'],
#  '145197Caes': ['n#06401522 the European mainland'],
#  '432Virg': ['n#10096231 temporary loss of strength and energy resulting from hard physical or mental work'],
#  '18006Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '18671Virg': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'],
#  '21365Virg': ['n#00004123 a human being'],
#  '22177Virg': ['n#07391044 an adult male person (as opposed to a woman)',
#   'n#00004123 a human being'],
#  '28254Virg': ['n#00004123 a human being'],
#  '29798Virg': ['n#06861622 any supernatural being worshipped as controlling some part of the world or some aspect of life or who is the personification of a force'],
#  '35620Virg': ['n#02262475 a stronghold into which people could go for shelter during a battle'],
#  '37459Virg': ['n#04128276 the sense organ for hearing and equilibrium'],
#  '43993Virg': ['n#03331403 a place of worship hallowed by association with some sacred thing or person'],
#  '48145Virg': ['n#02262475 a stronghold into which people could go for shelter during a battle'],
#  '49770Virg': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '54217Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '54718Virg': ['n#03523510 a structure taller than its diameter; can stand alone or be attached to a larger building'],
#  '62403Virg': ['n#02590878 a horizontal piece of wood or stone that forms the bottom of a doorway and offer support when passing through a doorway'],
#  '62863Virg': ['n#10867742 the end of life; continuing until dead'],
#  '65999Virg': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '69560Virg': ['n#04311223 the (prehensile) extremity of the superior limb'],
#  '71716Virg': ['n#03308216 a long rod or pole (especially the handle of an implement or the body of a weapon like a spear or arrow)'],
#  '73793Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '80521Virg': ['n#01661246 animal hunted or caught for food'],
#  '82245Virg': ['n#06700541 a steep rugged rock or cliff'],
#  '83144Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '83462Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '86033Virg': ['n#07668085 a person with unusual powers of foresight',
#   'n#00004123 a human being'],
#  '87458Virg': ['n#08572627 a deciduous tree of the genus Quercus; has acorns and lobed leaves'],
#  '87664Virg': ['n#03856995 a manner of performance'],
#  '87795Virg': ['n#06299747 the territory occupied by a nation'],
#  '90398Virg': ['n#07506812 a woman prophet', 'n#00004123 a human being'],
#  '92904Virg': ['n#06249735 a connected series of events or actions or developments'],
#  '104583Virg': ['n#03331403 a place of worship hallowed by association with some sacred thing or person'],
#  '106171Virg': ['n#06888584 a female deity'],
#  '107640Virg': ['n#06737795 an underground enclosure with access from the surface of the ground or from the sea'],
#  '108891Virg': ['n#06726012 a long narrow range of hills'],
#  '109468Virg': ['n#06737795 an underground enclosure with access from the surface of the ground or from the sea'],
#  '109948Virg': ["n#06667942 the solid part of the earth's surface"],
#  '113059Virg': ['n#06749470 a visible mass of water or ice particles suspended at a considerable altitude'],
#  '116498Virg': ['n#06761922 any celestial body visible (as a point of light) from the Earth at night'],
#  '123434Virg': ['n#07579801 a female person who has the same parents as another person',
#   'n#00004123 a human being'],
#  '133638Virg': ['n#06749007 outer space as viewed from the earth'],
#  '138905Virg': ['n#00757193 a struggle between rivals'],
#  '141744Virg': ['n#02814667 a mechanical device by which a vessel is steered'],
#  '142989Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '143385Virg': ['n#06781925 a division of an ocean or a large body of salt water partially enclosed by land'],
#  '146166Virg': ['n#01247280 limbless scaly elongate reptile; some are venomous'],
#  '146482Virg': ['n#06362245 a place where ships can take on or discharge cargo'],
#  '149322Virg': ['n#08882567 any plant of the family Palmae'],
#  '150806Virg': ['n#07567074 someone who serves in the armed forces',
#   'n#00004123 a human being'],
#  '153567Virg': ['n#00760227 a powerful stroke with the fist or a weapon'],
#  '157561Virg': ['n#06749007 outer space as viewed from the earth'],
#  '159975Virg': ['n#0547949 a movement in a new direction'],
#  '171793Virg': ['n#00461778 a specific piece of work required to be done as a duty or for a specific fee'],
#  '172598Virg': ['n#06700314 a steep high face of rock'],
#  '173466Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '175538Virg': ["n#06667942 the solid part of the earth's surface"],
#  '178081Virg': ['n#10019436 a region marking a boundary'],
#  '178845Virg': ['n#06241974 the trees and other plants in a large densely wooded area'],
#  '178923Virg': ['n#06787575 a body of (usually fresh) water surrounded by land'],
#  '179216Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '180403Virg': ['n#00610417 a hostile meeting of opposing military forces in the course of a war'],
#  '189518Virg': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '189796Virg': ['n#06800223 sloping land (especially the slope beside a body of water)'],
#  '194445Virg': ['n#00004123 a human being'],
#  '196965Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '201653Virg': ['n#06358701 the extended spatial location of something'],
#  '204513Virg': ['n#04311223 the (prehensile) extremity of the superior limb'],
#  '209024Virg': ['n#06667120 a wide and open space or area as of surface or land or sky'],
#  '214128Virg': ['n#03497295 a fine cord of twisted fibers (of cotton or silk or wool or nylon etc.) used in sewing and weaving'],
#  '214495Virg': ['n#06801063 the land along the edge of a body of water (a lake or ocean or river)'],
#  '217132Virg': ['n#05058245 a prophecy (usually obscure or allegorical) revealed by a priest or priestess; believed to be infallible'],
#  '220630Virg': ['n#03211321 an embankment built around a space for defensive purposes'],
#  '226630Virg': ['n#03600463 any road or path affording passage from one place to another'],
#  '230693Virg': ['n#06241974 the trees and other plants in a large densely wooded area'],
#  '232956Virg': ['n#04406756 attention to what is said'],
#  '237732Virg': ['n#10038317 the state of being friends'],
#  '242250Virg': ['n#00626011 the waging of armed conflict against an enemy'],
#  '243200Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '246097Virg': ['n#04807372 a composition written in metrical feet forming rhythmical lines'],
#  '251661Virg': ['n#08572627 a deciduous tree of the genus Quercus; has acorns and lobed leaves'],
#  '252649Virg': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'],
#  '253105Virg': ['n#06668569 what plants grow in (especially with reference to its quality or use)'],
#  '253927Virg': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '255317Virg': ['n#06242210 a small growth of trees without underbrush'],
#  '263177Virg': ['n#00004123 a human being'],
#  '265711Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '265861Virg': ['n#02590878 a horizontal piece of wood or stone that forms the bottom of a doorway and offer support when passing through a doorway'],
#  '267152Virg': ['n#06749470 a visible mass of water or ice particles suspended at a considerable altitude'],
#  '271603Virg': ['n#06299747 the territory occupied by a nation'],
#  '273887Virg': ['n#02848651 a material object that is worshipped as a god'],
#  '274288Virg': ['n#00004123 a human being'],
#  '278664Virg': ['n#06789983 a large natural stream of water (larger than a creek)'],
#  '280427Virg': ['n#06781925 a division of an ocean or a large body of salt water partially enclosed by land'],
#  '280463Virg': ['n#06711088 a land mass that projects well above its surroundings; higher than a hill'],
#  '287152Virg': ['n#06749007 outer space as viewed from the earth'],
#  '295134Virg': ['n#00004123 a human being'],
#  '296659Virg': ['n#00004123 a human being'],
#  '297527Virg': ['n#06082225 a large gathering of people',
#   'n#00004123 a human being'],
#  '298771Virg': ['n#03211321 an embankment built around a space for defensive purposes'],
#  '299873Virg': ['n#04128276 the sense organ for hearing and equilibrium'],
#  '300266Virg': ['n#00503108 a purposeful or industrious undertaking (especially one that requires effort or boldness)'],
#  '300658Virg': ['n#04112790 internal organs collectively (especially those in the abdominal cavity)'],
#  '307599Virg': ['n#02747160 a door-like movable barrier in a fence or wall'],
#  '313368Virg': ['n#04302029 the front part of the trunk from the neck to the abdomen'],
#  '315495Virg': ['n#03601056 weaponry used in fighting or hunting'],
#  '315938Virg': ['n#07665765 a combatant who is able to defeat rivals',
#   'n#00004123 a human being'],
#  '317870Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '318980Virg': ['n#00004123 a human being'],
#  '323697Virg': ['n#03856995 a manner of performance'],
#  '325250Virg': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '325275Virg': ['n#07354565 a male sovereign; ruler of a kingdom',
#   'n#00004123 a human being'],
#  '330527Virg': ['n#06749007 outer space as viewed from the earth'],
#  '331278Virg': ['n#05472145 waves breaking on the shore'],
#  '333759Virg': ['n#00004123 a human being'],
#  '337038Virg': ['n#10044643 a specific identifiable position in a continuum or series or especially in a process'],
#  '338908Virg': ['n#04112790 internal organs collectively (especially those in the abdominal cavity)'],
#  '339308Virg': ['n#05621336 food or meals in general'],
#  '339833Virg': ['n#10966461 the point in time at which something ends'],
#  '340312Virg': ['n#03316835 armor carried on the arm to intercept blows'],
#  '341530Virg': ['n#00004123 a human being'],
#  '341593Virg': ['n#00004123 a human being'],
#  '341806Virg': ['n#05621336 food or meals in general'],
#  '344986Virg': ['n#10018250 the shape of a raised edge of a more or less circular object'],
#  '352881Virg': ['n#06727012 extensive tract of level open land'],
#  '353048Virg': ["n#06667942 the solid part of the earth's surface"],
#  '353870Virg': ['n#02913016 a single thickness of usually some homogeneous substance'],
#  '355594Virg': ['n#04351370 knowledge and intellectual ability'],
#  '357204Virg': ['n#00626011 the waging of armed conflict against an enemy'],
#  '364594Virg': ['n#00004123 a human being'],
#  '367798Virg': ['n#05971194 wood heaped for burning a dead body as a funeral rite'],
#  '372429Virg': ['n#03601056 weaponry used in fighting or hunting'],
#  '374312Virg': ['n#10035141 the general state of things; the combination of circumstances at a given time'],
#  '381217Virg': ['n#02262475 a stronghold into which people could go for shelter during a battle'],
#  '381797Virg': ['n#06210014 troops trained to fight on horseback',
#   'n#00004123 a human being'],
#  '382911Virg': ['n#00610417 a hostile meeting of opposing military forces in the course of a war'],
#  '387753Virg': ['n#00004123 a human being'],
#  '391464Virg': ['n#01875414 solid-hoofed herbivorous quadruped domesticated since prehistoric times'],
#  '392954Virg': ['n#00619852 an act of aggression (as one against a person who resists)'],
#  '393422Virg': ['n#00004123 a human being'],
#  '395567Virg': ['n#00760227 a powerful stroke with the fist or a weapon'],
#  '398815Virg': ['n#07788946 the permanent end of all life functions in an organism or part of an organism'],
#  '399871Virg': ['n#06727012 extensive tract of level open land'],
#  '400199Virg': ['n#00610417 a hostile meeting of opposing military forces in the course of a war'],
#  '404158Virg': ['n#10794215 a layer of snowflakes (white crystals of frozen water) covering the ground'],
#  '407054Virg': ['n#05462231 an event (or course of events) that will inevitably happen in the future'],
#  '412923Virg': ['n#00004123 a human being'],
#  '416065Virg': ['n#02372560 temporary living quarters specially built by the army for soldiers'],
#  '421643Virg': ['n#02837386 a dwelling that serves as living quarters for one or more families'],
#  '421860Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '424445Virg': ['n#00004123 a human being'],
#  '428401Virg': ['n#00004123 a human being'],
#  '436869Virg': ['n#07127521 a male with the same parents as someone else',
#   'n#00004123 a human being'],
#  '438653Virg': ['n#06381267 a point located with respect to surface features of some region'],
#  '440736Virg': ['n#06669293 a lump of hard consolidated mineral matter'],
#  '441937Virg': ['n#04309035 the part of the leg between the hip and the knee']}

# %% [markdown]
# #### Creating Token IDs and Ground Synsets DataFrame

# %%
ground_synsets_df = pd.DataFrame([(k,v) for k,v in tok2_ground_synset.items()], columns=["ID", "GROUND SEMANTICS"]) #where 'ground_synsets_df' is a dataframe containing token IDs and ground synsets of all the tokens annotated with a ground 
ground_synsets_df
# Out:
#              ID                                   GROUND SEMANTICS
# 0      1498Caes    [n#06299747 the territory occupied by a nation]
# 1      4296Caes    [n#06299747 the territory occupied by a nation]
# 2      4578Caes                    [n#10428324 a source of danger]
# 3      4854Caes    [n#06299747 the territory occupied by a nation]
# 4      4978Caes       [n#06277165 the country where you were born]
# ..          ...                                                ...
# 267  428401Virg                         [n#00004123 a human being]
# 268  436869Virg  [n#07127521 a male with the same parents as so...
# 269  438653Virg  [n#06381267 a point located with respect to su...
# 270  440736Virg  [n#06669293 a lump of hard consolidated minera...
# 271  441937Virg  [n#04309035 the part of the leg between the hi...
#
# [272 rows x 2 columns]

# %% [markdown]
# #### Merging Ground Semantics with Figure Semantics DataFrames

# %%
id_ground_synsets_df = id_figure_synsets_df.merge(ground_synsets_df, on='ID', how='left') #where 'id_ground_synsets_df' merges 'id_figure_synsets_df' and 'ground_synsets_df', basically adding the ground synset to the other parameters contained in 'id_figure_synsets_df'
id_ground_synsets_df
# Out:
#               ID  VERB TOKEN  \
# 0        7504Aen      perire
# 1        7614Aen  Concurrunt
# 2        7807Aen  conveniunt
# 3          627Ap   praeeunte
# 4          638Ap   aggressus
# ...          ...         ...
# 1478  435595Verg   procurrit
# 1479  436869Verg  succurrere
# 1480  438653Verg   occurrere
# 1481  440736Verg    subirent
# 1482  441937Verg     transit
#
#                                  MORPHOLOGICAL FEATURES      LEMMA  \
# 0                     Tense=Pres|VerbForm=Inf|Voice=Act      pereo
# 1     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   concurro
# 2     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   convenio
# 3     Case=Abl|Gender=Masc|Number=Sing|Tense=Pres|Ve...     praeeo
# 4     Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Ve...  adgredior
# ...                                                 ...        ...
# 1478  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   procurro
# 1479                  Tense=Pres|VerbForm=Inf|Voice=Act   succurro
# 1480                  Tense=Pres|VerbForm=Inf|Voice=Act    occurro
# 1481  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      subeo
# 1482  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...    transeo
#
#                                                SENTENCE     ACTIONALITY  \
# 0     Quae neque Dardaniis campis potuere perire,   ...     Achievement
# 1     Concurrunt vel uti venti cum spiritus austri  ...     Achievement
# 2          Undique conveniunt vel ut imber tela tribuno        Activity
# 3     Mox in urbe Latia advena studiorum, Quiritium ...           State
# 4     Mox in urbe Latia advena studiorum, Quiritium ...  Accomplishment
# ...                                                 ...             ...
# 1478  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 1479  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 1480  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 1481  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 1482                  Per medium stridens transit femur  Accomplishment
#
#              VERB CLASS  LITERAL MEANING     VERB STEM PREVERB  \
# 0            DIE-42.4.1            False  present stem     per
# 1           BUMP-18.4-1             True  present stem     cum
# 2           HERD-47.5.2             True  present stem     cum
# 3        ACCOMPANY-51.7            False  present stem    prae
# 4            BEGIN-55.1            False   supine stem      ad
# ...                 ...              ...           ...     ...
# 1478         RUN-51.3.2             True  present stem     pro
# 1479          HELP-72.1            False  present stem     sub
# 1480         RUN-51.3.2            False  present stem      ob
# 1481  PUT_DIRECTION-9.4            False  present stem     sub
# 1482        ESCAPE-51.1             True  present stem   trans
#
#                         PREVERB SEMANTICS  \
# 0     (idea of destruction/death), across
# 1                                together
# 2                                together
# 3                                  before
# 4                                      to
# ...                                   ...
# 1478                              forward
# 1479                                under
# 1480                                   to
# 1481                                under
# 1482                               across
#
#                                          VERB SEMANTICS  \
# 0     [v#00250254 pass from physical life and lose a...
# 1       [v#01075789 crash together with violent impact]
# 2                     [v#01654097 collect in one place]
# 3     [v#01661609 be a guiding force, as with direct...
# 4                       [v#01661230 begin to deal with]
# ...                                                 ...
# 1478   [v#01410345 run or move very quickly or hastily]
# 1479         [v#01737682 help in a difficult situation]
# 1480   [v#01410345 run or move very quickly or hastily]
# 1481  [v#01343923 raise from a lower to a higher pos...
# 1482  [v#00988556 penetrate or cut through with a sh...
#
#                                        FIGURE SEMANTICS  \
# 0                          ['n#00004123 a human being']
# 1                          ['n#00004123 a human being']
# 2     ['n#03176413 a body that is thrown or projected']
# 3     ['n#07632177 a person whose occupation is teac...
# 4                          ['n#00004123 a human being']
# ...                                                 ...
# 1478                      ['n#06888584 a female deity']
# 1479                      ['n#06888584 a female deity']
# 1480  ['n#10169961 a serious (sometimes fatal infect...
# 1481                       ['n#00004123 a human being']
# 1482  ['n#03378030 a long pointed rod used as a weap...
#
#                                        GROUND SEMANTICS
# 0                                                   NaN
# 1                                                   NaN
# 2     [n#07168973 an officer in command of a militar...
# 3                                                   NaN
# 4     [n#05167497 a human written or spoken language...
# ...                                                 ...
# 1478                                                NaN
# 1479  [n#07127521 a male with the same parents as so...
# 1480  [n#06381267 a point located with respect to su...
# 1481  [n#06669293 a lump of hard consolidated minera...
# 1482  [n#04309035 the part of the leg between the hi...
#
# [1483 rows x 14 columns]

# %%
#Exporting id_ground_synsets_df to csv
id_ground_synsets_df.to_csv('title.csv')

# %% [markdown]
# ### Obtaining participants (Figure, Ground) lemmas

# %%
#Mapping verb token IDs to participants IDs

list_participants = []  # Initializing an empty list to store participants
tok2_participants = dict()  # Initializing an empty dictionary to store tokens mapped to their corresponding participants
count = 0  # Initializing a count variable

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Participants' annotation in the CAS
    for relation in cas.select('webanno.custom.Paticipants'):
        dep = relation.Dependent  # Dependent token of the participant relation
        tokdep = dep.get_covered_text()  # Covered text of the dependent token
        id = str(dep.begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
        list_participants.append(str(tokdep))  # Appending the covered text of the dependent token to srlist

        gov = relation.Governor  # Governor token of the participant relation
        toksr = gov.get_covered_text()  # Covered text of the governor token
        id2 = str(gov.begin) + file_input_abbr  # Creating a unique identifier by appending the file abbreviation to the offset of the governor token
        
        # Checking if the ID already exists in tok2_participants
        if id in tok2_participants:
            list_participants = tok2_participants[id] + [id2]  # If so, append the participant token ID to the existing list
            tok2_participants[id] = list_participants  # Update the dictionary with the appended list
        else:
            tok2_participants[id] = [id2]  # If not, create a new entry with a list containing the participant token ID

print(tok2_participants)
# Out:
# {'7807Aen': ['7831Aen', '7836Aen', 'praeeunte', 'aggressus', 'perveneritis', 'obiturus', 'provenire', 'convenire', 'transeas', 'aufugi', 'abierunt', 'pervenimus', 'exire', 'evolo', 'occurrit', 'occurrit'], '627Ap': ['618Ap'], '638Ap': ['583Ap'], '4001Ap': ['3991Ap'], '6965Ap': ['6953Ap'], '11895Ap': ['11872Ap'], '13304Ap': ['13271Ap'], '14102Ap': ['14094Ap'], '20808Ap': ['20796Ap'], '21919Ap': ['21891Ap'], '31740Ap': ['31723Ap'], '32491Ap': ['32474Ap'], '34900Ap': ['34879Ap'], '37524Ap': ['37451Ap', '37514Ap', 'occurrens', 'advenit', 'subit', 'adire', 'aufugere', 'obeas', 'abis', 'accurro', 'Occurrit', 'convenissent', 'advenit',
enit', 'transierat', 'adgressus', 'exisset', 'exisset'], '10862Caes': ['10855Caes'], '10890Caes': ['10883Caes'], '10931Caes': ['10902Caes'], '11152Caes': ['11147Caes', '11131Caes', 'transirent', 'transissent', 'transissent'], '11818Caes': ['11811Caes'], '12323Caes': ['12312Caes', '12316Caes', 'accurrit', 'accurrit'], '21567Caes': ['21563Caes', '21537Caes', 'adgressi', 'pervenerunt', 'convenissent', 'perfugissent', 'perfugissent'], '24504Caes': ['24479Caes'], '25610Caes': ['25584Caes'], '26036Caes': ['26021Caes'], '26268Caes': ['26264Caes', '26257Caes', 'egressi', 'transirent', 'transirent'], '26640Caes': ['26620Caes'], '27386Caes': ['27313Caes', '27380Caes', 'exisset', 'exisset'], '27831Caes': ['27818Caes', '27826Caes', 'convenerunt', 'convenerunt'], '28359Caes': ['28307Caes', '28339Caes', 'transisse',  ...

# %%
participants_df = pd.DataFrame([(k,v) for k,v in tok2_participants.items()], columns=["ID", "PARTICIPANT ID"])  #where 'part_df' is a dataframe containing token IDs and IDs of all the tokens annotated with a participant relation (i.e., Figure/Ground)
participants_df
# Out:
#              ID                                     PARTICIPANT ID
# 0       7807Aen  [7831Aen, 7836Aen, praeeunte, aggressus, perve...
# 1         627Ap                                            [618Ap]
# 2         638Ap                                            [583Ap]
# 3        4001Ap                                           [3991Ap]
# 4        6965Ap                                           [6953Ap]
# ..          ...                                                ...
# 906  435595Verg                                       [435621Verg]
# 907  436869Verg  [436844Verg, 436880Verg, occurrere, subirent, ...
# 908  438653Verg                                       [438644Verg]
# 909  440736Verg                                       [440708Verg]
# 910  441937Verg                                       [441945Verg]
#
# [911 rows x 2 columns]

# %%
list_participant_lemmas = []  # Initializing an empty list to store participant lemmas
tok2_participant_lemmas = dict()  # Initializing an empty dictionary to map tokens to their participant lemmas
count = 0  # Initializing a count variable

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Lemma' annotation in the CAS
    for relation in cas.select('de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Lemma'):
        # Looping through each token covered by 'Lemma' annotation
        for token in cas.select_covered('de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Lemma', relation):
            tok = token.get_covered_text()  # Covered text of the token
            id = str(token.begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            lemma = relation.value  # Value of the lemma relation
            
            # Checking if the ID already exists in tok2_participant_lemmas
            if id in tok2_participant_lemmas:
                list_lemmas = tok2_participant_lemmas[id] + lemma  # If so, append the value to the existing list of lemma fillers
                tok2_participant_lemmas[id] = list_lemmas  # Update the dictionary with the appended list
            else:
                tok2_participant_lemmas[id] = lemma  # If not, create a new entry with the lemma filler value

print(tok2_participant_lemmas)
# Out:
# {'7489Aen': 'campus', '7504Aen': 'pereo', '7614Aen': 'concurro', '7799Aen': 'undique', '7807Aen': 'convenio', '7831Aen': 'telum', '7836Aen': 'tribunus', '583Ap': 'sermo', '618Ap': 'magister', '627Ap': 'praeeo', '638Ap': 'adgredior', '2954Ap': 'intereo', '3256Ap': 'bacillum', '3278Ap': 'ad', '3281Ap': 'occipitium', '3292Ap': 'per', '3296Ap': 'ingluvies', '3306Ap': 'subeo', '3991Ap': 'civitas', '4001Ap': 'pervenio', '6953Ap': 'spectaculum', '6965Ap': 'obeo', '9077Ap': 'provenio', '11123Ap': 'aufugio
subvenio', '93169Ap': 'ad', '93172Ap': 'auxilium', '93188Ap': 'decurro', '95888Ap': 'conatus', '95910Ap': 'scaevitas', '95922Ap': 'anteeo', '96565Ap': 'iuvenis', '96697Ap': 'decurro', '98497Ap': 'ingredior', '99825Ap': 'pervenio', '99836Ap': 'ad', '99839Ap': 'locus', '102323Ap': 'iuvenis', '102331Ap': 'advenio', '105548Ap': 'decurro', '105732Ap': 'manus', '105738Ap': 'humerus', '105746Ap': 'subeo', '109709Ap': 'apparatus', '109735Ap': 'effugio', '109743Ap': 'oculus', '110010Ap': 'vulgus', '110161Ap': 'epulae', '110168Ap': 'accurro', '110868Ap': 'subeo', '110876Ap': 'effigies', '111352Ap': 'ad', '111361Ap': 'confinium', '111426Ap': 'caput', '111432Ap': 'subeo', '113574Ap': 'porta', '113591Ap': 'egredior', '115140Ap': 'occurro', '115157Ap': 'eventus', '116018Ap': 'vita', '116024Ap': 'meta', '116038Ap': 'obeo', '117014Ap': 'quidam', '117021Ap': 'procurro', '117032Ap': 'ex', '117034Ap': 'domus', '122130Ap': 'pereo', '125448Ap': 'in', '125451Ap': 'voluptas', '125471Ap': 'convenio', '1 ...

# %%
participant_lemmas_df = pd.DataFrame([(k,v) for k,v in tok2_participant_lemmas.items()], columns=["PARTICIPANT ID", "PARTICIPANT LEMMA"]) #where 'part_lem_df' is a dataframe containing IDs of all the tokens annotated with a participant relation (i.e., Figure/Ground) and their lemma
participant_lemmas_df
# Out:
#      PARTICIPANT ID PARTICIPANT LEMMA
# 0           7489Aen            campus
# 1           7504Aen             pereo
# 2           7614Aen          concurro
# 3           7799Aen           undique
# 4           7807Aen          convenio
# ...             ...               ...
# 3282     440708Verg              ille
# 3283     440736Verg             subeo
# 3284     441917Verg               per
# 3285     441937Verg           transeo
# 3286     441945Verg             femur
#
# [3287 rows x 2 columns]

# %%
# Initialize a new dictionary to store the mapping of IDs to lemmas
pred2_participant_lemma = {}

# Iterate over the keys of pred2_lemmas
for id, lemma in pred2_lemmas.items():
    # Check if the ID exists in tok2_participants
    if id in tok2_participants:
        # If so, find the corresponding participant IDs
        participant_ids = tok2_participants[id]
        # Check if there are participant IDs
        if participant_ids:
            # Initialize a list to store the lemmas corresponding to the participant IDs
            participant_lemmas = []
            for participant_id in participant_ids:
                # Lookup the lemma corresponding to the participant ID
                if participant_id in pred2_lemmas:
                    participant_lemma = pred2_lemmas[participant_id]
                    participant_lemmas.append(participant_lemma)
            # Store the list of lemmas corresponding to the participant IDs
            pred2_participant_lemma[id] = participant_lemmas

print(pred2_participant_lemma)
# Out:
# {'7807Aen': ['telum', 'tribunus'], '627Ap': ['magister'], '638Ap': ['sermo'], '4001Ap': ['civitas'], '6965Ap': ['spectaculum'], '11895Ap': ['affectus'], '13304Ap': ['nomen'], '14102Ap': ['fluvius'], '20808Ap': ['solitudo'], '21919Ap': ['villula'], '31740Ap': ['domus'], '32491Ap': ['fauces'], '34900Ap': ['hospitium'], '37524Ap': ['pars', 'lumen'], '38710Ap': ['oculus'], '40602Ap': ['Li
'], '66489Caes': ['flumen'], '66567Caes': ['locus'], '67219Caes': ['castrum'], '67317Caes': ['domus'], '68853Caes': ['oppidum'], '69478Caes': ['oppidum'], '70242Caes': ['Britannia'], '72211Caes': ['Nervius'], '74081Caes': ['eques', 'flumen'], '74785Caes': ['flumen'], '75094Caes': ['arma'], '75892Caes': ['Caesar'], '75926Caes': ['Caesar', 'legio'], '76487Caes': ['quisque', 'pars'], '77401Caes': ['flumen'], '77454Caes': ['locus'], '78212Caes': ['eques', 'hostis'], '78345Caes': ['flumen'], '78841Caes': ['legio'], '81306Caes': ['armo', 'Calo'], '81803Caes': ['flumen'], '81859Caes': ['locus'], '85712Caes': ['oppidum', 'miles'], '85792Caes': ['consilium'], '86330Caes': ['castellum'], '87400Caes': ['aestas'], '88780Caes': ['dies'], '90684Caes': ['pars', 'hostis'], '91683Caes': ['Volusenus', 'Galba'], '92706Caes': ['res'], '93136Caes': ['hiems'], '95973Caes': ['consilium'], '97054Caes': ['Remus'], '97169Caes': ['flumen'], '97624Caes': ['qui', 'Picto', 'regio', 'Santon ...

# %%
id_pred2_token_participant_df = pd.DataFrame([(k,v) for k,v in pred2_participant_lemma.items()], columns=["ID", "PARTICIPANT LEMMA"]) #where 'id_pred2_token_participant_df' is a dataframe containing token IDs and IDs of all the tokens annotated with a Spatial relation
id_pred2_token_participant_df
# Out:
#              ID  PARTICIPANT LEMMA
# 0       7807Aen  [telum, tribunus]
# 1         627Ap         [magister]
# 2         638Ap            [sermo]
# 3        4001Ap          [civitas]
# 4        6965Ap      [spectaculum]
# ..          ...                ...
# 906  435595Verg              [dea]
# 907  436869Verg  [Iuturna, frater]
# 908  438653Verg          [Iuturna]
# 909  440736Verg             [ille]
# 910  441937Verg            [femur]
#
# [911 rows x 2 columns]

# %% [markdown]
# ### Participant role

# %%
list_participant_role = []  # Initializing an empty list to store frames
tok2_participant_role = dict()  # Initializing an empty dictionary to map tokens to their frames
count = 0  # Initializing a count variable

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Participants' annotation in the CAS
    for relation in cas.select('webanno.custom.Paticipants'):
        dep = relation.Dependent  # Dependent token of the participant relation
        tokdep = dep.get_covered_text()  # Covered text of the dependent token
        id = str(dep.begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
        list_participants.append(str(tokdep))  # Appending the covered text of the dependent token to sptlist

        role = relation.Frame  # Frame associated with the participant relation
        
        # Checking if the ID already exists in tok2_participant_role
        if id in tok2_participant_role:
            list_participant_role = tok2_participant_role[id] + [role]  # If so, append the frame to the existing list of frames
            tok2_participant_role[id] = list_participant_role  # Update the dictionary with the appended list
        else:
            tok2_participant_role[id] = [role]  # If not, create a new entry with a list containing the frame

print(tok2_participant_role)
# Out:
# {'7807Aen': ['Ground', 'Figure'], '627Ap': ['Figure'], '638Ap': ['Ground'], '4001Ap': ['Ground'], '6965Ap': ['Ground'], '11895Ap': ['Figure'], '13304Ap': ['Figure'], '14102Ap': ['Ground'], '20808Ap': ['Ground'], '21919Ap': ['Ground'], '31740Ap': ['Ground'], '32491Ap': ['Figure'], '34900Ap': ['Ground'], '37524Ap': ['Ground', 'Figure'], '38710Ap': ['Ground'], '40602Ap': ['Figure'], '46705
Figure'], '66489Caes': ['Ground'], '66567Caes': ['Ground'], '67219Caes': ['Ground'], '67317Caes': ['Ground'], '68853Caes': ['Ground'], '69478Caes': ['Ground'], '70242Caes': ['Ground'], '72211Caes': ['Ground'], '74081Caes': ['Figure', 'Ground'], '74785Caes': ['Ground'], '75094Caes': ['Ground'], '75892Caes': ['Figure'], '75926Caes': ['Ground', 'Figure'], '76487Caes': ['Ground', 'Figure'], '77401Caes': ['Ground'], '77454Caes': ['Ground'], '78212Caes': ['Figure', 'Ground'], '78345Caes': ['Ground'], '78841Caes': ['Ground'], '81306Caes': ['Figure', 'Ground'], '81803Caes': ['Ground'], '81859Caes': ['Ground'], '85712Caes': ['Figure', 'Ground'], '85792Caes': ['Figure'], '86330Caes': ['Ground'], '87400Caes': ['Figure'], '88780Caes': ['Figure'], '90684Caes': ['Figure', 'Ground'], '91683Caes': ['Figure', 'Ground'], '92706Caes': ['Ground'], '93136Caes': ['Figure'], '95973Caes': ['Figure'], '97054Caes': ['Ground'], '97169Caes': ['Ground'], '97624Caes': ['Figure ...

# %%
participant_role_df = pd.DataFrame([(k,v) for k,v in tok2_participant_role.items()], columns=["ID", "PARTICIPANT ROLE"]) #where 'participant_role_df' is a dataframe containing IDs of all the tokens annotated with a participant relation (i.e., Figure/Ground) and their role
participant_role_df
# Out:
#              ID  PARTICIPANT ROLE
# 0       7807Aen  [Ground, Figure]
# 1         627Ap          [Figure]
# 2         638Ap          [Ground]
# 3        4001Ap          [Ground]
# 4        6965Ap          [Ground]
# ..          ...               ...
# 906  435595Verg          [Figure]
# 907  436869Verg  [Ground, Figure]
# 908  438653Verg          [Ground]
# 909  440736Verg          [Ground]
# 910  441937Verg          [Ground]
#
# [911 rows x 2 columns]

# %%
id_participant_role_lemma_df = id_pred2_token_participant_df.merge(participant_role_df, on='ID', how='left')
id_participant_role_lemma_df
# Out:
#              ID  PARTICIPANT LEMMA  PARTICIPANT ROLE
# 0       7807Aen  [telum, tribunus]  [Ground, Figure]
# 1         627Ap         [magister]          [Figure]
# 2         638Ap            [sermo]          [Ground]
# 3        4001Ap          [civitas]          [Ground]
# 4        6965Ap      [spectaculum]          [Ground]
# ..          ...                ...               ...
# 906  435595Verg              [dea]          [Figure]
# 907  436869Verg  [Iuturna, frater]  [Ground, Figure]
# 908  438653Verg          [Iuturna]          [Ground]
# 909  440736Verg             [ille]          [Ground]
# 910  441937Verg            [femur]          [Ground]
#
# [911 rows x 3 columns]

# %%
verb_with_participant_roles_lemmas_df = id_ground_synsets_df.merge(id_participant_role_lemma_df, on='ID', how='left')
verb_with_participant_roles_lemmas_df
# Out:
#               ID  VERB TOKEN  \
# 0        7504Aen      perire
# 1        7614Aen  Concurrunt
# 2        7807Aen  conveniunt
# 3          627Ap   praeeunte
# 4          638Ap   aggressus
# ...          ...         ...
# 1478  435595Verg   procurrit
# 1479  436869Verg  succurrere
# 1480  438653Verg   occurrere
# 1481  440736Verg    subirent
# 1482  441937Verg     transit
#
#                                  MORPHOLOGICAL FEATURES      LEMMA  \
# 0                     Tense=Pres|VerbForm=Inf|Voice=Act      pereo
# 1     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   concurro
# 2     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   convenio
# 3     Case=Abl|Gender=Masc|Number=Sing|Tense=Pres|Ve...     praeeo
# 4     Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Ve...  adgredior
# ...                                                 ...        ...
# 1478  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   procurro
# 1479                  Tense=Pres|VerbForm=Inf|Voice=Act   succurro
# 1480                  Tense=Pres|VerbForm=Inf|Voice=Act    occurro
# 1481  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      subeo
# 1482  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...    transeo
#
#                                                SENTENCE     ACTIONALITY  \
# 0     Quae neque Dardaniis campis potuere perire,   ...     Achievement
# 1     Concurrunt vel uti venti cum spiritus austri  ...     Achievement
# 2          Undique conveniunt vel ut imber tela tribuno        Activity
# 3     Mox in urbe Latia advena studiorum, Quiritium ...           State
# 4     Mox in urbe Latia advena studiorum, Quiritium ...  Accomplishment
# ...                                                 ...             ...
# 1478  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 1479  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 1480  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 1481  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 1482                  Per medium stridens transit femur  Accomplishment
#
#              VERB CLASS  LITERAL MEANING     VERB STEM PREVERB  \
# 0            DIE-42.4.1            False  present stem     per
# 1           BUMP-18.4-1             True  present stem     cum
# 2           HERD-47.5.2             True  present stem     cum
# 3        ACCOMPANY-51.7            False  present stem    prae
# 4            BEGIN-55.1            False   supine stem      ad
# ...                 ...              ...           ...     ...
# 1478         RUN-51.3.2             True  present stem     pro
# 1479          HELP-72.1            False  present stem     sub
# 1480         RUN-51.3.2            False  present stem      ob
# 1481  PUT_DIRECTION-9.4            False  present stem     sub
# 1482        ESCAPE-51.1             True  present stem   trans
#
#                         PREVERB SEMANTICS  \
# 0     (idea of destruction/death), across
# 1                                together
# 2                                together
# 3                                  before
# 4                                      to
# ...                                   ...
# 1478                              forward
# 1479                                under
# 1480                                   to
# 1481                                under
# 1482                               across
#
#                                          VERB SEMANTICS  \
# 0     [v#00250254 pass from physical life and lose a...
# 1       [v#01075789 crash together with violent impact]
# 2                     [v#01654097 collect in one place]
# 3     [v#01661609 be a guiding force, as with direct...
# 4                       [v#01661230 begin to deal with]
# ...                                                 ...
# 1478   [v#01410345 run or move very quickly or hastily]
# 1479         [v#01737682 help in a difficult situation]
# 1480   [v#01410345 run or move very quickly or hastily]
# 1481  [v#01343923 raise from a lower to a higher pos...
# 1482  [v#00988556 penetrate or cut through with a sh...
#
#                                        FIGURE SEMANTICS  \
# 0                          ['n#00004123 a human being']
# 1                          ['n#00004123 a human being']
# 2     ['n#03176413 a body that is thrown or projected']
# 3     ['n#07632177 a person whose occupation is teac...
# 4                          ['n#00004123 a human being']
# ...                                                 ...
# 1478                      ['n#06888584 a female deity']
# 1479                      ['n#06888584 a female deity']
# 1480  ['n#10169961 a serious (sometimes fatal infect...
# 1481                       ['n#00004123 a human being']
# 1482  ['n#03378030 a long pointed rod used as a weap...
#
#                                        GROUND SEMANTICS  PARTICIPANT LEMMA  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2     [n#07168973 an officer in command of a militar...  [telum, tribunus]
# 3                                                   NaN         [magister]
# 4     [n#05167497 a human written or spoken language...            [sermo]
# ...                                                 ...                ...
# 1478                                                NaN              [dea]
# 1479  [n#07127521 a male with the same parents as so...  [Iuturna, frater]
# 1480  [n#06381267 a point located with respect to su...          [Iuturna]
# 1481  [n#06669293 a lump of hard consolidated minera...             [ille]
# 1482  [n#04309035 the part of the leg between the hi...            [femur]
#
#       PARTICIPANT ROLE
# 0                  NaN
# 1                  NaN
# 2     [Ground, Figure]
# 3             [Figure]
# 4             [Ground]
# ...                ...
# 1478          [Figure]
# 1479  [Ground, Figure]
# 1480          [Ground]
# 1481          [Ground]
# 1482          [Ground]
#
# [1483 rows x 16 columns]

# %%
verb_with_participant_roles_lemmas_df.to_csv('Latin_with_participants_without_spatial_relations.csv')

# %% [markdown]
# ### Mapping IDs of verb tokens onto IDs of spatial relations

# %%
# Initializing an empty list to store spatial relations covered text
list_spatial_relations = []

# Initializing an empty dictionary to map tokens to their spatial relations with unique identifiers
tok2_spatial_relations = dict()

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Current file name
    file_input_abbr = files_abbreviated[i]  # Abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file

    # Looping through each 'Spatiality' annotation in the CAS
    for relation in cas.select('webanno.custom.Spatiality'):
        dep = relation.Dependent  # Dependent token of the spatial relation
        tokdep = dep.get_covered_text()  # Covered text of the dependent token
        id = str(dep.begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
        list_spatial_relations.append(str(tokdep))  # Appending the covered text of the dependent token to list_spatial_relations

        gov = relation.Governor  # Governor token of the spatial relation
        tokgov = gov.get_covered_text()  # Covered text of the governor token
        id2 = str(gov.begin) + file_input_abbr # Creating a unique identifier by appending the file abbreviation to the offset of the governor token
        
        if id in tok2_spatial_relations:  # Checking if the ID already exists in tok2_spatial_relations
            tok2_spatial_relations[id].append(id2)  # If so, append the unique identifier to the existing list
        else:
            tok2_spatial_relations[id] = [id2]  # If not, create a new entry with a list containing the unique identifier

print(tok2_spatial_relations)
# Out:
# {'7504Aen': ['7489Aen'], '7807Aen': ['7836Aen', '7799Aen'], '638Ap': ['583Ap'], '3306Ap': ['3296Ap', '3281Ap'], '4001Ap': ['3991Ap'], '6965Ap': ['6953Ap'], '11123Ap': ['11134Ap'], '11895Ap': ['11884Ap'], '14102Ap': ['14094Ap'], '20808Ap': ['20796Ap'], '21919Ap': ['21891Ap'], '31740Ap': ['31723Ap'], '32491Ap': ['32474Ap'], '34900Ap': ['34879Ap'], '37524Ap': ['37514Ap'], '38710Ap': ['38703Ap'], '46705Ap': ['46697Ap'], '51135Ap': ['51105Ap'], '55702Ap': ['55694Ap'], '63203Ap': ['63194Ap'], '69546Ap': ['69535Ap'], '71331Ap': ['71247Ap'], '71779Ap': ['71770Ap'], '74642Ap': ['74628Ap'], '84767Ap': ['84764Ap'], '87247Ap': ['87232Ap'], '93188Ap': ['93172Ap'], '99825Ap': ['99839Ap'], '105746Ap': ['105738Ap'], '110168Ap': ['110161Ap'], '111432Ap': ['111361Ap'], '113591Ap': ['113574Ap'], '116038Ap': ['116024Ap'], '117021Ap': ['117034Ap'], '125471Ap': ['125451Ap'], '133136Ap': ['133128Ap'], '134636Ap': ['134653Ap'], '140607Ap': ['140619Ap'], '149618Ap': ['149592Ap'], '150834Ap': ['150825Ap'], '158305Ap': ['158314Ap'], '161942Ap
# %%
tok2_spatial_relations_id_df = pd.DataFrame([(k,v) for k,v in tok2_spatial_relations.items()], columns=["ID", "SPATIAL RELATION ID"]) #where 'tok2_spatial_relations_id_df' is a dataframe containing token IDs and IDs of all the tokens annotated with a Spatial relation
tok2_spatial_relations_id_df
# Out:
#              ID SPATIAL RELATION ID
# 0       7504Aen           [7489Aen]
# 1       7807Aen  [7836Aen, 7799Aen]
# 2         638Ap             [583Ap]
# 3        3306Ap    [3296Ap, 3281Ap]
# 4        4001Ap            [3991Ap]
# ..          ...                 ...
# 683  424445Verg        [424413Verg]
# 684  428401Verg        [428307Verg]
# 685  436869Verg        [436880Verg]
# 686  438653Verg        [438644Verg]
# 687  441937Verg        [441945Verg]
#
# [688 rows x 2 columns]

# %%
pred2_spatial_relation_lemmas = dict()  # Initialize an empty dictionary to store mappings between predicate IDs and their spatial relation lemmas

# Iterate through each predicate ID in the dictionary tok2_spatial_relations
for pred_id in tok2_spatial_relations:
    spatial_relation_ids = tok2_spatial_relations[pred_id]  # Retrieve the list of spatial relation IDs associated with the current predicate ID
    spatial_relation_lemmas = list()  # Initialize an empty list to store lemmas corresponding to spatial relations
    
    # Iterate through each spatial relation ID in the list of IDs
    for spatial_relation in spatial_relation_ids:
        spatial_relation_lemma = pred2_lemmas[spatial_relation]  # Retrieve the lemma associated with the current spatial relation ID from pred2_lemmas dictionary
        spatial_relation_lemmas.append(spatial_relation_lemma)  # Append the retrieved lemma to the list of lemmas for the current predicate ID
        pred2_spatial_relation_lemmas[pred_id] = spatial_relation_lemmas  # Assign the list of lemmas to the current predicate ID in the pred2_spatial_relation_lemmas dictionary

print(pred2_spatial_relation_lemmas)
# Out:
# {'7504Aen': ['campus'], '7807Aen': ['tribunus', 'undique'], '638Ap': ['sermo'], '3306Ap': ['ingluvies', 'occipitium'], '4001Ap': ['civitas'], '6965Ap': ['spectaculum'], '11123Ap': ['istinc'], '11895Ap': ['contrarius'], '14102Ap': ['fluvius'], '20808Ap': ['solitudo'], '21919Ap': ['villula'], '31740Ap': ['domus'], '32491Ap': ['fauces'], '34900Ap': ['hospitium'], '37524Ap': ['lumen'], '38710Ap': ['oculus'], '46705Ap': ['fluctus'], '51135Ap': ['locus'], '55702Ap': ['cadaver'], '63203Ap': ['latro'], '69546Ap': ['ego'], '71331Ap': ['theatrum'], '71779Ap': ['fortuna'], '74642Ap': ['domus'], '84767Ap': ['ego'], '87247Ap': ['cogitatio'], '93188Ap': ['auxilium'], '99825Ap': ['locus'], '105746Ap': ['humerus'], '110168Ap': ['epulae'], '111432Ap': ['confinium'], '113591Ap': ['porta'], '116038Ap': ['meta'], '117021Ap': ['domus'], '125471Ap': ['voluptas'], '133136Ap': ['nuptiae'], '134636Ap': ['os'], '140607Ap': ['domus'], '149618Ap': ['unde'
# %%
spatial_relation_lemma_df = pd.DataFrame([(k,v) for k,v in pred2_spatial_relation_lemmas.items()], columns=["ID", "SPATIAL RELATION LEMMA"]) #where 'spatial_relation_lemma_df' is a dataframe containing token IDs and IDs of all the tokens annotated with a Spatial relation
spatial_relation_lemma_df
# Out:
#              ID   SPATIAL RELATION LEMMA
# 0       7504Aen                 [campus]
# 1       7807Aen      [tribunus, undique]
# 2         638Ap                  [sermo]
# 3        3306Ap  [ingluvies, occipitium]
# 4        4001Ap                [civitas]
# ..          ...                      ...
# 683  424445Verg                 [Hyllus]
# 684  428401Verg                    [hic]
# 685  436869Verg                 [frater]
# 686  438653Verg                [Iuturna]
# 687  441937Verg                  [femur]
#
# [688 rows x 2 columns]

# %%
list_spatial_relation_roles = []  # Initializing an empty list to store frames
tok2_spatial_relation_roles = dict()  # Initializing an empty dictionary to map tokens to their frames
count = 0  # Initializing a count variable

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Getting the current file name
    file_input_abbr = files_abbreviated[i]  # Getting the abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Participants' annotation in the CAS
    for relation in cas.select('webanno.custom.Spatiality'):
        dep = relation.Dependent  # Dependent token of the participant relation
        tokdep = dep.get_covered_text()  # Covered text of the dependent token
        id = str(dep.begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
        list_participants.append(str(tokdep))  # Appending the covered text of the dependent token to sptlist

        spatial_relation = relation.Spatials  # Frame associated with the participant relation
        
        # Checking if the ID already exists in tok2_spatial_relation_roles
        if id in tok2_spatial_relation_roles:
            list_spatial_relation_roles = tok2_spatial_relation_roles[id] + [spatial_relation]  # If so, append the frame to the existing list of frames
            tok2_spatial_relation_roles[id] = list_spatial_relation_roles  # Update the dictionary with the appended list
        else:
            tok2_spatial_relation_roles[id] = [spatial_relation]  # If not, create a new entry with a list containing the frame

print(tok2_spatial_relation_roles)
# Out:
# {'7504Aen': ['LOCATION'], '7807Aen': ['GOAL', 'SOURCE'], '638Ap': ['GOAL'], '3306Ap': ['PATH', 'GOAL'], '4001Ap': ['GOAL'], '6965Ap': ['GOAL'], '11123Ap': ['SOURCE'], '11895Ap': ['GOAL'], '14102Ap': ['PATH'], '20808Ap': ['PATH'], '21919Ap': ['GOAL'], '31740Ap': ['GOAL'], '32491Ap': ['SOURCE'], '34900Ap': ['GOAL'], '37524Ap': ['GOAL'], '38710Ap': ['GOAL'], '46705Ap': ['GOAL'], '51135Ap': ['GOAL'], '55702Ap': ['GOAL'], '63203Ap': ['GOAL'], '69546Ap': ['GOAL'], '71331Ap': ['PATH'], '71779Ap': ['GOAL'], '74642Ap': ['GOAL'], '84767Ap': ['GOAL'], '87247Ap': ['GOAL'], '93188Ap': ['GOAL'], '99825Ap': ['GOAL'], '105746Ap': ['GOAL'], '110168Ap': ['GOAL'], '111432Ap': ['GOAL'], '113591Ap': ['GOAL'], '116038Ap': ['GOA
'], '106032Caes': ['GOAL'], '108403Caes': ['GOAL'], '111487Caes': ['GOAL'], '111980Caes': ['SOURCE'], '112893Caes': ['GOAL'], '113030Caes': ['SOURCE'], '114154Caes': ['PATH'], '115967Caes': ['GOAL'], '117032Caes': ['GOAL'], '117506Caes': ['PATH'], '117858Caes': ['PATH'], '118479Caes': ['GOAL'], '118665Caes': ['GOAL'], '124898Caes': ['GOAL'], '125531Caes': ['PATH'], '125781Caes': ['GOAL'], '126596Caes': ['PATH'], '126731Caes': ['PATH'], '127053Caes': ['GOAL'], '127799Caes': ['PATH'], '130412Caes': ['GOAL'], '131258Caes': ['GOAL'], '131412Caes': ['GOAL'], '132195Caes': ['SOURCE', 'GOAL', 'SOURCE'], '132754Caes': ['GOAL'], '132936Caes': ['SOURCE'], '134386Caes': ['GOAL'], '134834Caes': ['GOAL'], '135306Caes': ['SOURCE'], '135522Caes': ['SOURCE'], '135874Caes': ['GOAL'], '137342Caes': ['GOAL'], '137469Caes': ['SOURCE'], '138943Caes': ['SOURCE'], '140508Caes': ['GOAL'], '140959Caes': ['GOAL'], '143342Cae ...

# %%
spatial_relation_role_df = pd.DataFrame([(k,v) for k,v in tok2_spatial_relation_roles.items()], columns=["ID", "SPATIAL RELATION ROLE"]) #where 'spatial_relation_role_df' is a dataframe containing token IDs and IDs of all the tokens annotated with a Spatial relation
spatial_relation_role_df
# Out:
#              ID SPATIAL RELATION ROLE
# 0       7504Aen            [LOCATION]
# 1       7807Aen        [GOAL, SOURCE]
# 2         638Ap                [GOAL]
# 3        3306Ap          [PATH, GOAL]
# 4        4001Ap                [GOAL]
# ..          ...                   ...
# 683  424445Verg                [GOAL]
# 684  428401Verg                [GOAL]
# 685  436869Verg                [GOAL]
# 686  438653Verg                [GOAL]
# 687  441937Verg                [PATH]
#
# [688 rows x 2 columns]

# %%
id_spatial_relation_roles_lemmas_df = spatial_relation_role_df.merge(spatial_relation_lemma_df, on='ID', how='left') #where 'id_spatial_relation_roles_lemmas_df' merges 'spatial_relation_lemma_df' and 'spatial_relation_role_df'
id_spatial_relation_roles_lemmas_df
# Out:
#              ID SPATIAL RELATION ROLE   SPATIAL RELATION LEMMA
# 0       7504Aen            [LOCATION]                 [campus]
# 1       7807Aen        [GOAL, SOURCE]      [tribunus, undique]
# 2         638Ap                [GOAL]                  [sermo]
# 3        3306Ap          [PATH, GOAL]  [ingluvies, occipitium]
# 4        4001Ap                [GOAL]                [civitas]
# ..          ...                   ...                      ...
# 683  424445Verg                [GOAL]                 [Hyllus]
# 684  428401Verg                [GOAL]                    [hic]
# 685  436869Verg                [GOAL]                 [frater]
# 686  438653Verg                [GOAL]                [Iuturna]
# 687  441937Verg                [PATH]                  [femur]
#
# [688 rows x 3 columns]

# %%
pred2_spatial_relation_synsets = dict()  # Initialize an empty dictionary to store mappings between predicate IDs and their spatial relation lemmas

# Iterate through each predicate ID in the dictionary tok2_spatial_relations
for pred_id in tok2_spatial_relations:
    spatial_relation_ids = tok2_spatial_relations[pred_id]  # Retrieve the list of spatial relation IDs associated with the current predicate ID
    spatial_relation_synsets = list()  # Initialize an empty list to store lemmas corresponding to spatial relations
    
    # Iterate through each spatial relation ID in the list of IDs
    for spatial_relation in spatial_relation_ids:
        spatial_relation_synset = tok2_synsets[spatial_relation]  # Retrieve the lemma associated with the current spatial relation ID from pred2_lemmas dictionary
        # Extract only the lemma string from the object and append it to the list of lemmas for the current predicate ID
        spatial_relation_synsets.append(spatial_relation_synset.elements[0])  
    pred2_spatial_relation_synsets[pred_id] = spatial_relation_synsets  # Assign the list of lemmas to the current predicate ID in the pred2_spatial_relation_synsets dictionary
        
print(pred2_spatial_relation_synsets)
# Out:
# {'7504Aen': ['n#06727012 extensive tract of level open land'], '7807Aen': ['n#07168973 an officer in command of a military unit', 'r#L2533591 from any or all places'], '638Ap': ['n#05167497 a human written or spoken language used by a community; opposed to e.g. a computer language'], '3306Ap': ['n#04296952 the passage to the stomach and lungs; in the front part of the neck below the chin and above the collarbone', 'n#04292200 back part of the head or skull'], '4001Ap': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'], '6965Ap': ['n#04964487 a public exhibition or entertainment'], '11123Ap': ['r#00041436 (archaic) from this place'], '11895Ap': ['n#09984290 a relation of direct opposition'], '14102Ap': ['n#06789983 a large natural stream of water (larger than a creek)'], '20808Ap': ['n#06391772 a wild and uninhabited area'], '21919Ap': ['n#02666884 a house for the farmer and family'], '31740Ap': ['n#02837386 a dwelling that serves as living quarters for one or more families'], '32491Ap': ['n#04295972 the part of the skull of a vertebrate that frames the mouth and holds the teeth'], '34900Ap': ['n#02837386 a dwelling that serves as living quarters for one or more families'], '37524Ap': ['n#04122028 the organ of sight (\\"peeper\\" is an informal term for \\"eye\\")'], '38710Ap': ['n#04122028 the organ of sight (\\"peeper\\" is an informal term for \\"eye\\")'], '46705Ap': ['n#05477241 one of a series of ridges that moves across the surface of a liquid (especially across a large body of water)+'], '51135Ap': ['n#06381267 a point located with respect to surface features of some region'], '55702Ap': ['n#04056524 the dead body of a human being'], '63203Ap': ['n#07422992 a thief who takes property by threatening (or performing) violence on the person who is robbed'], '69546Ap': ['n#00004123 a human being'], '71331Ap': ['n#03491295 a building where theatrical performances or motion-picture shows can be presented'], '71779Ap': ['n#10035141 the general state of things; the combination of circumstances at a given time'], '74642Ap': ['n#02837386 a dwelling that serves as living quarters for one or more families'], '84767Ap': ['n#00004123 a human being'], '87247Ap': ['n#04450733 the process of thinking (especially thinking carefully)'], '93188Ap': ['n#07087094 a person who contributes to the fulfillment of a need or furtherance of an effort or purpose'], '99825Ap': ['n#06381267 a point located with respect to surface features of some region'], '105746Ap': ['n#04297840 the part of the body between the neck and the upper arm'], '110168Ap': ['n#05631002 a meal that is well prepared and greatly enjoyed'], '111432Ap': ['n#02621671 a strip near the boundary of an object'], '113591Ap': ['n#02747160 a door-like movable barrier in a fence or wall'], '116038Ap': ['n#10442122 a final state'], '117021Ap': ['n#02837386 a dwelling that serves as living quarters for one or more families'], '125471Ap': ['n#00543267 sexual gratification'], '133136Ap': ['n#00669775 the act of marrying; the nuptial ceremony'], '134636Ap': ['n#04340595 the front of the head from the forehead to the chin and ear to ear'], '140607Ap': ['n#02837386 a dwelling that serves as living quarters for one or more families'], '149618Ap': ['r#00041981 from what place or origin or source'], '150834Ap': ['n#06700314 a steep high face of rock'], '158305Ap': ['n#00004123 a human being'], '161942Ap': ['n#06381267 a point located with respect to surface features of some region'], '162189Ap': ['n#06287351 a large and densely populated urban area; may include several independent administrative districts'], '162465Ap': ['n#06382213 an urban area with a fixed boundary that is smaller than a city'], '1498Caes': ['n#06299747 the territory occupied by a nation'], '4296Caes': ['n#06299747 the territory occupied by a nation'], '4578Caes': ['n#10428324 a source of danger'], '4854Caes': ['n#06299747 the territory occupied by a nation'], '4978Caes': ['n#03243979 an open way (ge ...

# %%
spatial_relation_synset_df = pd.DataFrame([(k,v) for k,v in pred2_spatial_relation_synsets.items()], columns=["ID", "SPATIAL RELATION SEMANTICS"]) #where 'spatial_relation_synset_df' is a dataframe containing verb IDs and semantics of all the tokens annotated with a Spatial relation
spatial_relation_synset_df
# Out:
#              ID                         SPATIAL RELATION SEMANTICS
# 0       7504Aen    [n#06727012 extensive tract of level open land]
# 1       7807Aen  [n#07168973 an officer in command of a militar...
# 2         638Ap  [n#05167497 a human written or spoken language...
# 3        3306Ap  [n#04296952 the passage to the stomach and lun...
# 4        4001Ap  [n#06382213 an urban area with a fixed boundar...
# ..          ...                                                ...
# 683  424445Verg                         [n#00004123 a human being]
# 684  428401Verg                         [n#00004123 a human being]
# 685  436869Verg  [n#07127521 a male with the same parents as so...
# 686  438653Verg  [n#06381267 a point located with respect to su...
# 687  441937Verg  [n#04309035 the part of the leg between the hi...
#
# [688 rows x 2 columns]

# %%
id_spatial_relation_roles_lemmas_synsets_df = id_spatial_relation_roles_lemmas_df.merge(spatial_relation_synset_df, on='ID', how='left') #where 'id_spatial_relation_roles_lemmas_synsets_df' merges 'id_spatial_relation_roles_lemmas_df' and 'spatial_relation_synset_df'
id_spatial_relation_roles_lemmas_synsets_df
# Out:
#              ID SPATIAL RELATION ROLE   SPATIAL RELATION LEMMA  \
# 0       7504Aen            [LOCATION]                 [campus]
# 1       7807Aen        [GOAL, SOURCE]      [tribunus, undique]
# 2         638Ap                [GOAL]                  [sermo]
# 3        3306Ap          [PATH, GOAL]  [ingluvies, occipitium]
# 4        4001Ap                [GOAL]                [civitas]
# ..          ...                   ...                      ...
# 683  424445Verg                [GOAL]                 [Hyllus]
# 684  428401Verg                [GOAL]                    [hic]
# 685  436869Verg                [GOAL]                 [frater]
# 686  438653Verg                [GOAL]                [Iuturna]
# 687  441937Verg                [PATH]                  [femur]
#
#                             SPATIAL RELATION SEMANTICS
# 0      [n#06727012 extensive tract of level open land]
# 1    [n#07168973 an officer in command of a militar...
# 2    [n#05167497 a human written or spoken language...
# 3    [n#04296952 the passage to the stomach and lun...
# 4    [n#06382213 an urban area with a fixed boundar...
# ..                                                 ...
# 683                         [n#00004123 a human being]
# 684                         [n#00004123 a human being]
# 685  [n#07127521 a male with the same parents as so...
# 686  [n#06381267 a point located with respect to su...
# 687  [n#04309035 the part of the leg between the hi...
#
# [688 rows x 4 columns]

# %%
# Initializing an empty list to store spatial relations covered text
list_spatial_relations = []

# Initializing an empty dictionary to map tokens to their spatial relations with unique identifiers
tok2_spatial_relations = dict()

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Current file name
    file_input_abbr = files_abbreviated[i]  # Abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file

    # Looping through each 'Spatiality' annotation in the CAS
    for relation in cas.select('webanno.custom.Spatiality'):
        dep = relation.Dependent  # Dependent token of the spatial relation
        tokdep = dep.get_covered_text()  # Covered text of the dependent token
        id = str(dep.begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
        list_spatial_relations.append(str(tokdep))  # Appending the covered text of the dependent token to list_spatial_relations

        gov = relation.Governor  # Governor token of the spatial relation
        tokgov = gov.get_covered_text()  # Covered text of the governor token
        id2 = str(gov.begin) + file_input_abbr # Creating a unique identifier by appending the file abbreviation to the offset of the governor token
        
        if id in tok2_spatial_relations:  # Checking if the ID already exists in tok2_spatial_relations
            tok2_spatial_relations[id].append(id2)  # If so, append the unique identifier to the existing list
        else:
            tok2_spatial_relations[id] = [id2]  # If not, create a new entry with a list containing the unique identifier

print(tok2_spatial_relations)
# Out:
# {'7504Aen': ['7489Aen'], '7807Aen': ['7836Aen', '7799Aen'], '638Ap': ['583Ap'], '3306Ap': ['3296Ap', '3281Ap'], '4001Ap': ['3991Ap'], '6965Ap': ['6953Ap'], '11123Ap': ['11134Ap'], '11895Ap': ['11884Ap'], '14102Ap': ['14094Ap'], '20808Ap': ['20796Ap'], '21919Ap': ['21891Ap'], '31740Ap': ['31723Ap'], '32491Ap': ['32474Ap'], '34900Ap': ['34879Ap'], '37524Ap': ['37514Ap'], '38710Ap': ['38703Ap'], '46705Ap': ['46697Ap'], '51135Ap': ['51105Ap'], '55702Ap': ['55694Ap'], '63203Ap': ['63194Ap'], '69546Ap': ['69535Ap'], '71331Ap': ['71247Ap'], '71779Ap': ['71770Ap'], '74642Ap': ['74628Ap'], '84767Ap': ['84764Ap'], '87247Ap': ['87232Ap'], '93188Ap': ['93172Ap'], '99825Ap': ['99839Ap'], '105746Ap': ['105738Ap'], '110168Ap': ['110161Ap'], '111432Ap': ['111361Ap'], '113591Ap': ['113574Ap'], '116038Ap': ['116024Ap'], '117021Ap': ['117034Ap'], '125471Ap': ['125451Ap'], '133136Ap': ['133128Ap'], '134636Ap': ['134653Ap'], '140607Ap': ['140619Ap'], '149618Ap': ['149592Ap'], '150834Ap': ['150825Ap'], '158305Ap': ['158314Ap'], '161942Ap': ['161918Ap'], '162189Ap': ['162201Ap'], '162465Ap': ['162457Ap'], '1498Caes': ['1466Caes'], '4296Caes': ['4283Caes'], '4578Caes': ['4569Caes'], '4854Caes': ['4840Caes'], '4978Caes': ['4973Caes', '4962Caes'], '5732Caes': ['5712Caes'], '5997Caes': ['5989Caes'], '7012Caes': ['7002Caes'], '9426Caes': ['9374Caes'], '9649Caes': ['9643Caes'], '10407Caes': ['10389Caes'], '10617Caes': ['10576Caes'], '10862Caes': ['10855Caes'], '10890Caes': ['10883Caes'], '10931Caes': ['10902Caes'], '11152Caes': ['11147Caes'], '11818Caes': ['11811Caes'], '12323Caes': ['12316Caes'], '21567Caes': ['21
begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            spatial_relation_expression = relation.preposition  # Preposition associated with the expression
            
            # Checking if the ID already exists in tok2_spatial_relation_expression
            if id in tok2_spatial_relation_expression:
                tok2_spatial_relation_expression = tok2_spatial_relation_expression[id] + [spatial_relation_expression]
                tok2_spatial_relation_expression[id] = list_spatial_relation_expressions
                #tok2_spatial_relation_expression[id].append(spatial_relation_expression)  # If so, append the preposition to the existing list of expressions
            else:
                tok2_spatial_relation_expression[id] = [spatial_relation_expression]  # If not, create a new entry with the expression list

print(tok2_spatial_relation_expression)
# Out:
# {'7489Aen': ['ABL'], '7799Aen': ['adverb'], '7836Aen': ['DAT'], '583Ap': ['ACC'], '3281Ap': ['ad + ACC'], '3296Ap': ['per + ACC'], '3991Ap': ['ACC'], '6953Ap': ['ACC'], '11134Ap': ['adverb'], '11884Ap': ['in + ACC'], '14094Ap': ['per + ACC'], '20796Ap': ['per + ACC'], '21891Ap': ['ad + ACC'], '31723Ap': ['ad + ACC'], '32474Ap': ['de + ABL'], '34879Ap': ['ad + ACC'], '37514Ap': ['DAT'], '38703Ap': ['DAT'], '46697Ap': ['ACC'], '51105Ap': ['ACC'], '53484Ap': ['ACC'], '55694Ap': ['ACC'], '63194Ap': ['ACC'], '69535Ap': ['ACC'], '71247Ap': ['per + ACC'], '71770Ap': ['DAT'], '74628Ap': ['ACC'], '84764Ap': ['ACC'], '87232Ap': ['DAT'], '93172Ap': ['ad + ACC'], '99839Ap': ['ad + ACC'], '105738Ap': ['ACC'], '109743Ap': ['ACC'], '110161Ap': ['ACC'], '110876Ap': ['ACC'], '111361Ap': ['ad + ACC'], '113574Ap': ['ACC'], '116024Ap': ['ACC'], '117034Ap': ['ex + ABL'], '125451Ap': ['in + ACC'], '133128Ap': ['ACC'], '134492Ap': ['ACC'], '134653Ap': ['ob + ACC'], '140619Ap': ['ex + ABL'], '149592Ap': ['adverb'], '150825Ap': ['ACC'], '158314Ap': ['DAT'], '161918Ap': ['ad + ACC'], '162201Ap': ['ad + ACC'], '162457Ap': ['ACC'], '1466Caes': ['de + ABL'], '4283Caes': ['ex + ABL'], '4569Caes': ['ad + ACC'], '4840Caes': ['in + ACC'], '4962Caes': ['ABL'], '4973Caes': ['ABL'], '5712Caes': ['ad + ACC'], '5989Caes': ['ad + ACC'], '7002Caes': ['ex + ABL'], '9374Caes': ['in + ACC'], '9643Caes': ['in + ACC'], '10389Caes': ['in + ACC'], '10576Caes': ['ACC'], '10855Caes': ['ad + ACC'], '10883Caes': ['ACC'], '10902Caes': ['ACC'], '11147Caes': ['ABL'], '11811Caes': ['ACC'], '12316Caes': ['ACC'], '21563Caes': ['ad + ACC'], '24479Caes': ['ACC'], '24490Caes': ['ab + ABL'], '25584Caes': ['in + ACC'], '26206Caes': ['adverb'], '26264Caes': ['ad + ACC'], '26620Caes': ['ex + ABL'], '27357Caes': ['ex + ABL'], '27380Caes': ['in + ACC'], '27826Caes': ['ABL'], '28339Caes': ['ad + ACC'], '29911Caes': ['ACC'], '30758Caes': ['ex + ABL'], '31358Caes': ['ACC'], '33960Caes': ['ACC'], '34199Caes': ['in + ACC'], '37146Caes': ['ACC'], '37510Caes': ['ACC'], '46737Caes': ['ACC'], '46862Caes': ['ACC'], '48080Caes': ['ABL'], '53614Caes': ['ab + ABL'], '56119Caes': ['ad + ACC'], '56146Caes': ['ex + ABL'], '56342Caes': ['adverb'], '59146Caes': ['ad + ACC'], '60295Caes': ['intra + ACC'], '61667Caes': ['ad + ACC'], '63929Caes': ['adverb'], '64992Caes': ['ACC'], '65311Caes': ['ACC'], '66208Caes': ['ACC'], '66235Caes': ['in + ABL'], '66295Caes': ['per + ACC'], '66550Caes': ['in + ACC'], '66797Caes': ['adverb'], '67211Caes': ['ABL'], '67311Caes': ['ACC'], '68831Caes': ['in + ACC'], '69471Caes': ['ex + ABL'], '70231Caes': ['in + ACC'], '70785Caes': ['in + ACC'], '72203Caes': ['ad + ACC'], '74074Caes': ['ACC'], '74778Caes': ['ad + ACC'], '75089Caes': ['ad + ACC'], '75909Caes': ['ad + ACC'], '76239Caes': ['DAT'], '76475Caes': ['in + ACC'], '77410Caes': ['ACC'], '77440Caes': ['in + ACC'], '77975Caes': ['ACC'], '78203Caes': ['DAT'], '78338Caes': ['ACC'], '79709Caes': ['ex + ABL'], '81298Caes': ['DAT'], '81823Caes': ['ACC'], '81879Caes': ['ACC'], '85705Caes': ['ex + ABL'], '86317Caes': ['ex + ABL'], '86327Caes': ['adverb'], '89366Caes': ['ex + ABL'], '89378Caes': ['in + ACC'], '90375Caes': ['adverb'], '90664Caes': ['ex + ABL'], '90900Caes': ['adverb'], '91676Caes': ['ad + ACC'], '92717Caes': ['DAT'], '93194Caes': ['ACC'], '97029Caes': ['ACC'], '97162Caes': ['ACC'], '97570Caes': ['ex + ABL'], '102321Caes': ['adverb'], '102801Caes': ['in + ACC'], '103160Caes': ['adverb'], '104062Caes': ['ad + ACC'], '106021Caes': ['in + ACC'], '108390Caes': ['ad + ACC'], '111476Caes': ['ad + ACC'], '111957Caes': ['ex + ABL'], '112865Caes': ['ad + ACC'], '113014Caes': ['ex + ABL'], '114147Caes': ['ACC'], '115923Caes': ['ad + ACC'], '117025Caes': ['ad + ACC'], '117501Caes': ['ACC'], '117851Caes': ['ACC'], '118470Caes': ['ACC'], '118658Caes': ['DAT'], '124891Caes': ['ad + ACC'], '125524Caes': ['ACC'], '125754Caes': ['ad + ACC'], '126589Caes': ['ACC'], '126725Caes': ['ACC'], '127045Caes': ['in + ACC'], '127792Caes': ['ACC'], ...

# %%
# Initialize a new dictionary to store the mapping of identifiers to expressions
pred2_spatial_relation_expression = {}

# Iterate over the keys and values of tok2_spatial_relations
for identifier, ids in tok2_spatial_relations.items():
    expressions = []  # Initialize an empty list to store expressions for the current identifier
    for id in ids:
        # Check if the id exists in tok2_spatial_relation_expression
        if id in tok2_spatial_relation_expression:
            expressions.extend(tok2_spatial_relation_expression[id])  # Extend the expressions list with expressions for the current id
    
    # Add the list of expressions to the combined dictionary only if it's not empty
adverb'], '67219Caes': ['ABL'], '67317Caes': ['ACC'], '68853Caes': ['in + ACC'], '69478Caes': ['ex + ABL'], '70242Caes': ['in + ACC'], '70802Caes': ['in + ACC'], '72211Caes': ['ad + ACC'], '74081Caes': ['ACC'], '74785Caes': ['ad + ACC'], '75094Caes': ['ad + ACC'], '75926Caes': ['ad + ACC'], '76251Caes': ['DAT'], '76487Caes': ['in + ACC'], '77401Caes': ['ACC'], '77454Caes': ['in + ACC'], '77984Caes': ['ACC'], '78212Caes': ['DAT'], '78345Caes': ['ACC'], '79714Caes': ['ex + ABL'], '81306Caes': ['DAT'], '81803Caes': ['ACC'], '81859Caes': ['ACC'], '85712Caes': ['ex + ABL'], '86330Caes': ['adverb', 'ex + ABL'], '89385Caes': ['ex + ABL', 'in + ACC'], '90378Caes': ['adverb'], '90684Caes': ['ex + ABL'], '90903Caes': ['adverb'], '91683Caes': ['ad + ACC'], '92706Caes': ['DAT'], '93203Caes': ['ACC'], '97054Caes': ['ACC'], '97169Caes': ['ACC'], '97624Caes': ['ex + ABL'], '102324Caes': ['adverb'], '102818Caes': ['in + ACC'], '103209Caes': ['adverb'], '104069Caes': ['ad + ACC'], '106032Caes': ['in + ACC'], '108403Caes': ['ad + ACC'], '111487Caes': ['ad + ACC'], '111980Caes': ['ex + ABL'], '112893Caes': ['ad + ACC'], '113030Caes': ['ex + ABL'], '114154Caes': ['ACC'], '115967Caes': ['ad + ACC'], '117032Caes': ['ad + ACC'], '117506Caes': ['ACC'], '117858Caes': ['ACC'], '118479Caes': ['ACC'], '118665Caes': ['DAT'], '124898Caes': ['ad + ACC'], '125531Caes': ['ACC'], '125781Caes': ['ad + ACC'], '126596Caes': ['ACC'], '126731Caes': ['ACC'], '127053Caes': ['in + ACC'], '127799Caes': ['ACC'], '130412Caes': ['in + ACC'], '131258Caes': ['ACC'], '131412Caes': ['adverb'], '132195Caes': ['adverb', 'ex + ABL', 'adverb'], '132754Caes': ['ACC'], '132936Caes': ['ABL'], '134386Caes': ['in + ACC'], '134834Caes' ...

# %%
# Find the missing key-value pair (if needed)
missing_key = None
for key in tok2_spatial_relations:
    if key not in pred2_spatial_relation_expression:
        missing_key = key
        break

print("Missing key:", missing_key)
# Out:
# Missing key: None

# %%
spatial_relation_expression_df = pd.DataFrame([(k,v) for k,v in pred2_spatial_relation_expression.items()], columns=["ID", "SPATIAL RELATION EXPRESSION"]) #where 'tok2sr_df' is a dataframe containing token IDs and IDs of all the tokens annotated with a Spatial relation
spatial_relation_expression_df
# Out:
#              ID SPATIAL RELATION EXPRESSION
# 0       7504Aen                       [ABL]
# 1       7807Aen               [DAT, adverb]
# 2         638Ap                       [ACC]
# 3        3306Ap       [per + ACC, ad + ACC]
# 4        4001Ap                       [ACC]
# ..          ...                         ...
# 683  424445Verg                       [DAT]
# 684  428401Verg                       [DAT]
# 685  436869Verg                       [DAT]
# 686  438653Verg                       [DAT]
# 687  441937Verg                 [per + ACC]
#
# [688 rows x 2 columns]

# %%
id_spatial_relation_expression_df = spatial_relation_expression_df.merge(id_spatial_relation_roles_lemmas_synsets_df, on='ID', how='left')
id_spatial_relation_expression_df
# Out:
#              ID SPATIAL RELATION EXPRESSION SPATIAL RELATION ROLE  \
# 0       7504Aen                       [ABL]            [LOCATION]
# 1       7807Aen               [DAT, adverb]        [GOAL, SOURCE]
# 2         638Ap                       [ACC]                [GOAL]
# 3        3306Ap       [per + ACC, ad + ACC]          [PATH, GOAL]
# 4        4001Ap                       [ACC]                [GOAL]
# ..          ...                         ...                   ...
# 683  424445Verg                       [DAT]                [GOAL]
# 684  428401Verg                       [DAT]                [GOAL]
# 685  436869Verg                       [DAT]                [GOAL]
# 686  438653Verg                       [DAT]                [GOAL]
# 687  441937Verg                 [per + ACC]                [PATH]
#
#       SPATIAL RELATION LEMMA  \
# 0                   [campus]
# 1        [tribunus, undique]
# 2                    [sermo]
# 3    [ingluvies, occipitium]
# 4                  [civitas]
# ..                       ...
# 683                 [Hyllus]
# 684                    [hic]
# 685                 [frater]
# 686                [Iuturna]
# 687                  [femur]
#
#                             SPATIAL RELATION SEMANTICS
# 0      [n#06727012 extensive tract of level open land]
# 1    [n#07168973 an officer in command of a militar...
# 2    [n#05167497 a human written or spoken language...
# 3    [n#04296952 the passage to the stomach and lun...
# 4    [n#06382213 an urban area with a fixed boundar...
# ..                                                 ...
# 683                         [n#00004123 a human being]
# 684                         [n#00004123 a human being]
# 685  [n#07127521 a male with the same parents as so...
# 686  [n#06381267 a point located with respect to su...
# 687  [n#04309035 the part of the leg between the hi...
#
# [688 rows x 5 columns]

# %%
verbs_with_participants_and_spatial_relations = verb_with_participant_roles_lemmas_df.merge(id_spatial_relation_expression_df, on='ID', how='left')
verbs_with_participants_and_spatial_relations
# Out:
#               ID  VERB TOKEN  \
# 0        7504Aen      perire
# 1        7614Aen  Concurrunt
# 2        7807Aen  conveniunt
# 3          627Ap   praeeunte
# 4          638Ap   aggressus
# ...          ...         ...
# 1478  435595Verg   procurrit
# 1479  436869Verg  succurrere
# 1480  438653Verg   occurrere
# 1481  440736Verg    subirent
# 1482  441937Verg     transit
#
#                                  MORPHOLOGICAL FEATURES      LEMMA  \
# 0                     Tense=Pres|VerbForm=Inf|Voice=Act      pereo
# 1     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   concurro
# 2     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   convenio
# 3     Case=Abl|Gender=Masc|Number=Sing|Tense=Pres|Ve...     praeeo
# 4     Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Ve...  adgredior
# ...                                                 ...        ...
# 1478  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   procurro
# 1479                  Tense=Pres|VerbForm=Inf|Voice=Act   succurro
# 1480                  Tense=Pres|VerbForm=Inf|Voice=Act    occurro
# 1481  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      subeo
# 1482  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...    transeo
#
#                                                SENTENCE     ACTIONALITY  \
# 0     Quae neque Dardaniis campis potuere perire,   ...     Achievement
# 1     Concurrunt vel uti venti cum spiritus austri  ...     Achievement
# 2          Undique conveniunt vel ut imber tela tribuno        Activity
# 3     Mox in urbe Latia advena studiorum, Quiritium ...           State
# 4     Mox in urbe Latia advena studiorum, Quiritium ...  Accomplishment
# ...                                                 ...             ...
# 1478  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 1479  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 1480  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 1481  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 1482                  Per medium stridens transit femur  Accomplishment
#
#              VERB CLASS  LITERAL MEANING     VERB STEM PREVERB  \
# 0            DIE-42.4.1            False  present stem     per
# 1           BUMP-18.4-1             True  present stem     cum
# 2           HERD-47.5.2             True  present stem     cum
# 3        ACCOMPANY-51.7            False  present stem    prae
# 4            BEGIN-55.1            False   supine stem      ad
# ...                 ...              ...           ...     ...
# 1478         RUN-51.3.2             True  present stem     pro
# 1479          HELP-72.1            False  present stem     sub
# 1480         RUN-51.3.2            False  present stem      ob
# 1481  PUT_DIRECTION-9.4            False  present stem     sub
# 1482        ESCAPE-51.1             True  present stem   trans
#
#                         PREVERB SEMANTICS  \
# 0     (idea of destruction/death), across
# 1                                together
# 2                                together
# 3                                  before
# 4                                      to
# ...                                   ...
# 1478                              forward
# 1479                                under
# 1480                                   to
# 1481                                under
# 1482                               across
#
#                                          VERB SEMANTICS  \
# 0     [v#00250254 pass from physical life and lose a...
# 1       [v#01075789 crash together with violent impact]
# 2                     [v#01654097 collect in one place]
# 3     [v#01661609 be a guiding force, as with direct...
# 4                       [v#01661230 begin to deal with]
# ...                                                 ...
# 1478   [v#01410345 run or move very quickly or hastily]
# 1479         [v#01737682 help in a difficult situation]
# 1480   [v#01410345 run or move very quickly or hastily]
# 1481  [v#01343923 raise from a lower to a higher pos...
# 1482  [v#00988556 penetrate or cut through with a sh...
#
#                                        FIGURE SEMANTICS  \
# 0                          ['n#00004123 a human being']
# 1                          ['n#00004123 a human being']
# 2     ['n#03176413 a body that is thrown or projected']
# 3     ['n#07632177 a person whose occupation is teac...
# 4                          ['n#00004123 a human being']
# ...                                                 ...
# 1478                      ['n#06888584 a female deity']
# 1479                      ['n#06888584 a female deity']
# 1480  ['n#10169961 a serious (sometimes fatal infect...
# 1481                       ['n#00004123 a human being']
# 1482  ['n#03378030 a long pointed rod used as a weap...
#
#                                        GROUND SEMANTICS  PARTICIPANT LEMMA  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2     [n#07168973 an officer in command of a militar...  [telum, tribunus]
# 3                                                   NaN         [magister]
# 4     [n#05167497 a human written or spoken language...            [sermo]
# ...                                                 ...                ...
# 1478                                                NaN              [dea]
# 1479  [n#07127521 a male with the same parents as so...  [Iuturna, frater]
# 1480  [n#06381267 a point located with respect to su...          [Iuturna]
# 1481  [n#06669293 a lump of hard consolidated minera...             [ille]
# 1482  [n#04309035 the part of the leg between the hi...            [femur]
#
#       PARTICIPANT ROLE SPATIAL RELATION EXPRESSION SPATIAL RELATION ROLE  \
# 0                  NaN                       [ABL]            [LOCATION]
# 1                  NaN                         NaN                   NaN
# 2     [Ground, Figure]               [DAT, adverb]        [GOAL, SOURCE]
# 3             [Figure]                         NaN                   NaN
# 4             [Ground]                       [ACC]                [GOAL]
# ...                ...                         ...                   ...
# 1478          [Figure]                         NaN                   NaN
# 1479  [Ground, Figure]                       [DAT]                [GOAL]
# 1480          [Ground]                       [DAT]                [GOAL]
# 1481          [Ground]                         NaN                   NaN
# 1482          [Ground]                 [per + ACC]                [PATH]
#
#      SPATIAL RELATION LEMMA                         SPATIAL RELATION SEMANTICS
# 0                  [campus]    [n#06727012 extensive tract of level open land]
# 1                       NaN                                                NaN
# 2       [tribunus, undique]  [n#07168973 an officer in command of a militar...
# 3                       NaN                                                NaN
# 4                   [sermo]  [n#05167497 a human written or spoken language...
# ...                     ...                                                ...
# 1478                    NaN                                                NaN
# 1479               [frater]  [n#07127521 a male with the same parents as so...
# 1480              [Iuturna]  [n#06381267 a point located with respect to su...
# 1481                    NaN                                                NaN
# 1482                [femur]  [n#04309035 the part of the leg between the hi...
#
# [1483 rows x 20 columns]

# %%
verbs_with_participants_and_spatial_relations.to_csv('Latin_with_participants_and_spatial_relations.csv')

# %% [markdown]
# ### Places (WHG)

# %%
list_places = []  # Initializing an empty list to store places
pred2_place = dict()  # Initializing an empty dictionary to map tokens to their places
count = 0  # Initializing a count variable to keep track of iterations

# Looping through each file in the list of all_files
for i in range(len(all_files)):
    file_input = all_files[i]  # Current file name
    file_input_abbr = files_abbreviated[i]  # Abbreviated name for the current file
    xml = get_xml(file_input)  # Retrieving XML content from the current file
    cas = load_cas(file_input)  # Loading CAS from the current file
    
    # Looping through each 'Place' annotation in the CAS
    for relation in cas.select('webanno.custom.Place'):
        # Looping through each token covered by 'Place' annotation
        for token in cas.select_covered('webanno.custom.Place', relation):
            tok = token.get_covered_text()  # Covered text of the token
            id = str(token.begin) + file_input_abbr  # Creating a unique ID for the token based on its offset and file abbreviation
            place = relation.Places  # Places associated with the token
            
            # Checking if the ID already exists in pred2_place
            if id in pred2_place:
                list_place = pred2_place[id] + place  # If so, append the places to the existing list of places
                pred2_place[id] = list_place  # Update the dictionary with the appended list
            else:
                pred2_place[id] = place  # If not, create a new entry with a list containing the places

print(pred2_place)
# Out:
# {'4840Caes': 'https://whgazetteer.org/places/14153618/portal', '5323Caes': 'https://whgazetteer.org/places/12347418/portal', '5989Caes': 'https://whgazetteer.org/places/84296/detail', '29911Caes': 'https://whgazetteer.org/places/12347419/portal', '31358Caes': 'https://whgazetteer.org/places/12347419/portal', '33960Caes': 'https://whgazetteer.org/places/12347419/portal', '37510Caes': 'https://whgazetteer.org/places/12347419/portal', '46737Caes': 'https://whgazetteer.org/places/12347419/portal', '46862Caes': 'https://whgazetteer.org/places/12347419/portal', '56119Caes': 'https://whgazetteer.org/places/12347419/portal', '70231Caes': 'https://whgazetteer.org/places/12636696/portal', '106021Caes': 'https://whgazetteer.org/places/6465620/detail', '111957Caes': 'https://whgazetteer.org/places/81460/detail', '111967Caes': 'https://whgazetteer.org/places/82552/detail', '114147Caes': 'https://whgazetteer.org/places/12347419/portal', '117025Caes': 'https://whgazetteer.org/places/12347419/portal', '125524Caes': 'https://whgazetteer.org/places/12347419/portal', '126368Caes': 'https://whgazetteer.org/places/12347419/portal', '126589Caes': 'https://whgazetteer.org/places/12347419/portal', '126725Caes': 'https://whgazetteer.org/places/12347644/portal', '127045Caes': 'https://whgazetteer.org/places/14142755/portal', '127792Caes': 'https://whgazetteer.org/places/12347419/portal', '140948Caes': 'https://whgazetteer.org/places/12636696/portal', '5318Cic_Cat': 'https://whgazetteer.org/places/12346170/portal', '68938Cic
# %%
id_places_df = pd.DataFrame([(k,v) for k,v in pred2_url_relations.items()], columns=["ID", "WHG URL"]) #where 'id_places_df' is a dataframe containing verb IDs and WHG URLs
id_places_df
# Out:
#              ID WHG URL
# 0       7504Aen    None
# 1       7807Aen    None
# 2         638Ap    None
# 3        3306Ap    None
# 4        4001Ap    None
# ..          ...     ...
# 683  424445Verg    None
# 684  428401Verg    None
# 685  436869Verg    None
# 686  438653Verg    None
# 687  441937Verg    None
#
# [688 rows x 2 columns]

# %% [markdown]
# ### Getting the final CSV for Latin

# %%
Latin_full = verbs_with_participants_and_spatial_relations.merge(id_places_df, on='ID', how='left')
Latin_full
# Out:
#               ID  VERB TOKEN  \
# 0        7504Aen      perire
# 1        7614Aen  Concurrunt
# 2        7807Aen  conveniunt
# 3          627Ap   praeeunte
# 4          638Ap   aggressus
# ...          ...         ...
# 1478  435595Verg   procurrit
# 1479  436869Verg  succurrere
# 1480  438653Verg   occurrere
# 1481  440736Verg    subirent
# 1482  441937Verg     transit
#
#                                  MORPHOLOGICAL FEATURES      LEMMA  \
# 0                     Tense=Pres|VerbForm=Inf|Voice=Act      pereo
# 1     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   concurro
# 2     Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   convenio
# 3     Case=Abl|Gender=Masc|Number=Sing|Tense=Pres|Ve...     praeeo
# 4     Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Ve...  adgredior
# ...                                                 ...        ...
# 1478  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...   procurro
# 1479                  Tense=Pres|VerbForm=Inf|Voice=Act   succurro
# 1480                  Tense=Pres|VerbForm=Inf|Voice=Act    occurro
# 1481  Mood=Subj|Number=Plur|Person=3|Tense=Imp|VerbF...      subeo
# 1482  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...    transeo
#
#                                                SENTENCE     ACTIONALITY  \
# 0     Quae neque Dardaniis campis potuere perire,   ...     Achievement
# 1     Concurrunt vel uti venti cum spiritus austri  ...     Achievement
# 2          Undique conveniunt vel ut imber tela tribuno        Activity
# 3     Mox in urbe Latia advena studiorum, Quiritium ...           State
# 4     Mox in urbe Latia advena studiorum, Quiritium ...  Accomplishment
# ...                                                 ...             ...
# 1478  Dum nititur acer et instat, rursus in aurigae ...     Achievement
# 1479  Iuturnam misero, fateor, succurrere fratri sua...        Activity
# 1480  Harum unam celerem demisit ab aethere summo Iu...  Accomplishment
# 1481  Vix illud lecti bis sex cervice subirent, qual...     Achievement
# 1482                  Per medium stridens transit femur  Accomplishment
#
#              VERB CLASS  LITERAL MEANING     VERB STEM PREVERB  ...  \
# 0            DIE-42.4.1            False  present stem     per  ...
# 1           BUMP-18.4-1             True  present stem     cum  ...
# 2           HERD-47.5.2             True  present stem     cum  ...
# 3        ACCOMPANY-51.7            False  present stem    prae  ...
# 4            BEGIN-55.1            False   supine stem      ad  ...
# ...                 ...              ...           ...     ...  ...
# 1478         RUN-51.3.2             True  present stem     pro  ...
# 1479          HELP-72.1            False  present stem     sub  ...
# 1480         RUN-51.3.2            False  present stem      ob  ...
# 1481  PUT_DIRECTION-9.4            False  present stem     sub  ...
# 1482        ESCAPE-51.1             True  present stem   trans  ...
#
#                                          VERB SEMANTICS  \
# 0     [v#00250254 pass from physical life and lose a...
# 1       [v#01075789 crash together with violent impact]
# 2                     [v#01654097 collect in one place]
# 3     [v#01661609 be a guiding force, as with direct...
# 4                       [v#01661230 begin to deal with]
# ...                                                 ...
# 1478   [v#01410345 run or move very quickly or hastily]
# 1479         [v#01737682 help in a difficult situation]
# 1480   [v#01410345 run or move very quickly or hastily]
# 1481  [v#01343923 raise from a lower to a higher pos...
# 1482  [v#00988556 penetrate or cut through with a sh...
#
#                                        FIGURE SEMANTICS  \
# 0                          ['n#00004123 a human being']
# 1                          ['n#00004123 a human being']
# 2     ['n#03176413 a body that is thrown or projected']
# 3     ['n#07632177 a person whose occupation is teac...
# 4                          ['n#00004123 a human being']
# ...                                                 ...
# 1478                      ['n#06888584 a female deity']
# 1479                      ['n#06888584 a female deity']
# 1480  ['n#10169961 a serious (sometimes fatal infect...
# 1481                       ['n#00004123 a human being']
# 1482  ['n#03378030 a long pointed rod used as a weap...
#
#                                        GROUND SEMANTICS  PARTICIPANT LEMMA  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2     [n#07168973 an officer in command of a militar...  [telum, tribunus]
# 3                                                   NaN         [magister]
# 4     [n#05167497 a human written or spoken language...            [sermo]
# ...                                                 ...                ...
# 1478                                                NaN              [dea]
# 1479  [n#07127521 a male with the same parents as so...  [Iuturna, frater]
# 1480  [n#06381267 a point located with respect to su...          [Iuturna]
# 1481  [n#06669293 a lump of hard consolidated minera...             [ille]
# 1482  [n#04309035 the part of the leg between the hi...            [femur]
#
#       PARTICIPANT ROLE SPATIAL RELATION EXPRESSION SPATIAL RELATION ROLE  \
# 0                  NaN                       [ABL]            [LOCATION]
# 1                  NaN                         NaN                   NaN
# 2     [Ground, Figure]               [DAT, adverb]        [GOAL, SOURCE]
# 3             [Figure]                         NaN                   NaN
# 4             [Ground]                       [ACC]                [GOAL]
# ...                ...                         ...                   ...
# 1478          [Figure]                         NaN                   NaN
# 1479  [Ground, Figure]                       [DAT]                [GOAL]
# 1480          [Ground]                       [DAT]                [GOAL]
# 1481          [Ground]                         NaN                   NaN
# 1482          [Ground]                 [per + ACC]                [PATH]
#
#      SPATIAL RELATION LEMMA  \
# 0                  [campus]
# 1                       NaN
# 2       [tribunus, undique]
# 3                       NaN
# 4                   [sermo]
# ...                     ...
# 1478                    NaN
# 1479               [frater]
# 1480              [Iuturna]
# 1481                    NaN
# 1482                [femur]
#
#                              SPATIAL RELATION SEMANTICS WHG URL
# 0       [n#06727012 extensive tract of level open land]    None
# 1                                                   NaN    None
# 2     [n#07168973 an officer in command of a militar...    None
# 3                                                   NaN    None
# 4     [n#05167497 a human written or spoken language...    None
# ...                                                 ...     ...
# 1478                                                NaN     NaN
# 1479  [n#07127521 a male with the same parents as so...     NaN
# 1480  [n#06381267 a point located with respect to su...     NaN
# 1481                                                NaN     NaN
# 1482  [n#04309035 the part of the leg between the hi...     NaN
#
# [1483 rows x 21 columns]

# %%
Latin_full.to_csv('Latin_FULL.csv')
